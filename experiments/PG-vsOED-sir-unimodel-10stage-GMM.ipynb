# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,inspect
# current_dir = '/home/jiayuand/seqOED_variational/examples/location'
# parent_dir = '/home/jiayuand/seqOED_variational'

# current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
# parent_dir = os.path.dirname(os.path.dirname(current_dir))
parent_dir = '/scratch/xhuan_root/xhuan1/wgshen/vsOED/'
sys.path.insert(0, parent_dir) 

import numpy as np
# from scipy.stats import norm, beta, dirichlet
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from   torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
if torch.cuda.is_available():  
    dev = "cuda:0" 
else:  
    dev = "cpu"  
device = torch.device(dev) 
torch.set_default_device(device)
dtype = torch.float32
torch.set_default_dtype(dtype)

from vsOED import VSOED, PGvsOED, GMM_NET, NFs, POST_APPROX
from vsOED.utils import *
from vsOED.models import *

import dowel

# %%
n_stage      = 5       # Number of stages.
n_design     = 1        # Number of design variables.
n_obs        = 1        # Number of observations.
n_pois       = [2]        # Number of parameters.
n_nuisps     = None
n_goals      = None
model_weight = 0
poi_weight   = 1
goal_weight  = 0

random_state  = TRAIN_SEEDS[0]
set_random_seed(random_state)

data_folder = '/scratch/xhuan_root/xhuan1/wgshen/vsOED/SIR/sir_sde_data/'
model = SIR(data_folder)
prior = model

mu_bounds = {}
mu_bounds['poi'] = []
for n_poi in n_pois:
    mu_bounds['poi'].append([[-6, 4]] * n_poi)
if n_goals is not None:
    mu_bounds['goal'] = []
    for n_goal in n_goals:
        mu_bounds['goal'].append([[0, 3]] * n_goal)
max_sigmas = {}
max_sigmas['poi'] = []
for n_poi in n_pois:
    max_sigmas['poi'].append([0.5] * n_poi)
if n_goals is not None:
    max_sigmas['goal'] = []
    for n_goal in n_goals:
        max_sigmas['goal'].append([1.0] * n_goal)
truncnorm_info = {}
truncnorm_info['poi'] = [None] * len(n_pois)
if n_goals is not None:
    truncnorm_info['goal'] = []
    for n_goal in n_goals:
        info = []
        for i in range(n_goal):
            info.append([i, 0, 4])
            
n_incre = 1
share_interm_net = False

candidate_lrs = [[1e-3] * n_incre, [1e-5] * (n_incre - 1) + [1e-4]]
candidate_gammas = [[0.9999] * n_incre, [0.999999] * (n_incre - 1) + [0.99999]]
model_post_lrs = candidate_lrs[share_interm_net]
model_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]
poi_post_lrs = candidate_lrs[share_interm_net]
poi_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]
goal_post_lrs = candidate_lrs[share_interm_net]
goal_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]

use_NFs = False
n_mixture = 8
activate = nn.ReLU

log_every = 100
folder = parent_dir + f'experiments/sir_{len(n_pois)}model_{n_stage}stage_{n_incre}incre_GMM/'
try:
    os.remove(folder + 'progress.csv')
except:
    pass
try:
    os.remove(folder + 'progress.txt')
except:
    pass
try:
    dowel.logger.remove_all()
except:
    pass
dowel.logger.add_output(dowel.StdOutput())
dowel.logger.add_output(dowel.CsvOutput(folder + 'progress.csv'))
dowel.logger.add_output(dowel.TextOutput(folder + 'progress.txt'))

try:
    for _ in range(100):
        dowel.logger.pop_prefix()
except:
    pass
dowel.logger.push_prefix('[SIR] ')
dowel.logger.log('Stored at ' + folder)
dowel.logger.log('Random seed:  ' + str(random_state))
dowel.logger.log('Device: ' + str(device))
dowel.logger.log('dtype: ' + str(dtype))

post_approx_params = {
    'n_stage': n_stage, 
    'n_design': n_design, 
    'n_obs': n_obs, 
    'n_pois': n_pois,
    'n_nuisps': n_nuisps,
    'n_goals': n_goals,
    'model_weight': model_weight,
    'poi_weight': poi_weight,
    'goal_weight': goal_weight,
    'mu_bounds': mu_bounds,
    'max_sigmas': max_sigmas,
    'truncnorm_info': truncnorm_info,
    'n_mixture': n_mixture,
    'activate': activate,
    'prior': prior,
    'n_incre': n_incre,
    'share_interm_net': share_interm_net,
    'model_post_lrs': model_post_lrs,
    'model_post_lr_scheduler_gammas': model_post_lr_scheduler_gammas,
    'poi_post_lrs': poi_post_lrs,
    'poi_post_lr_scheduler_gammas': poi_post_lr_scheduler_gammas,
    'goal_post_lrs': goal_post_lrs,
    'goal_post_lr_scheduler_gammas': goal_post_lr_scheduler_gammas,
    'use_NFs': use_NFs,
    'log_every': log_every,
    'dowel': dowel}

dowel.logger.log('Post_approx_params: ' + str(post_approx_params))

dowel.logger.dump_all()
# dowel.logger.remove_all()

post_approx = POST_APPROX(**post_approx_params)
dowel.logger.dump_all()
# Out:
# 2023-05-02 15:43:52 | [CES] Stored at /scratch/xhuan_root/xhuan1/wgshen/vsOED/experiments/ces_1model_5stage_1incre_GMM/
# 2023-05-02 15:43:52 | [CES] Random seed:  48563549
# 2023-05-02 15:43:52 | [CES] Device: cuda:0
# 2023-05-02 15:43:52 | [CES] dtype: torch.float32
# 2023-05-02 15:43:52 | [CES] Post_approx_params: {'n_stage': 5, 'n_design': 1, 'n_obs': 1, 'n_pois': [2], 'n_nuisps': None, 'n_goals': None, 'model_weight': 0, 'poi_weight': 1, 'goal_weight': 0, 'mu_bounds': {'poi': [[[-6, 4], [-6, 4]]]}, 'max_sigmas': {'poi': [[0.5, 0.5]]}, 'truncnorm_info': {'poi': [None]}, 'n_mixture': 8, 'activate': <class 'torch.nn.modules.activation.ReLU'>, 'prior': <vsOED.models.SIR object at 0x14f28a277520>, 'n_incre': 1, 'share_interm_net': False, 'model_post_lrs': [0.001], 'model_post_lr_scheduler_gammas': [0.9999], 'poi_post_lrs': [0.001], 'poi_post_lr_scheduler_gammas': [0.9999], 'goal_post_lrs': [0.001], 'goal_post_lr_scheduler_gammas': [0.9999], 'use_NFs': False, 'log_every': 100, 'dowel': <module 'dowel' from '/home/wgshen/.local/lib/python3.9/site-packages/dowel/__init__.py'>}
# 2023-05-02 15:43:52 | [CES] Learn the posterior approximator at stages: [4]

# %%
n_param = len(n_pois) > 1
try:
    n_param += max(n_pois)
except:
    pass
try:
    n_param += max(n_nuisps)
except:
    pass
try:
    n_param += max(n_goals)
except:
    pass

design_bounds = [(0.1, 99.9)] * n_design # lower and upper bounds of design variables.
nkld_reward_fun = model.reward_fun
kld_reward_fun = post_approx.reward_fun
# Physical state
n_xp = 1
init_xp = [0.0]
phys_state_info = (n_xp, init_xp, model.xp_f)
post_approx = post_approx
encoder_dimns = None
backend_dimns = None
actor_dimns = [256, 256, 256]
critic_dimns = [256, 256, 256]

vsoed_params = {
    'n_stage': n_stage,
    'n_param': n_param,
    'n_design': n_design,
    'n_obs': n_obs,
    'model': model,
    'prior': prior,
    'design_bounds': design_bounds,
    'nkld_reward_fun': nkld_reward_fun,
    'kld_reward_fun': kld_reward_fun,
    'phys_state_info': phys_state_info,
    'post_approx': post_approx,
    'encoder_dimns': encoder_dimns,
    'backend_dimns': backend_dimns,
    'actor_dimns': actor_dimns,
    'critic_dimns': critic_dimns,
    'activate': activate
}
dowel.logger.log('vsoed_params: ' + str(vsoed_params))

vsoed = PGvsOED(**vsoed_params)
# Out:
# 2023-05-02 15:43:54 | [CES] vsoed_params: {'n_stage': 5, 'n_param': 2, 'n_design': 1, 'n_obs': 1, 'model': <vsOED.models.SIR object at 0x14f28a277520>, 'prior': <vsOED.models.SIR object at 0x14f28a277520>, 'design_bounds': [(0.1, 99.9)], 'nkld_reward_fun': <bound method SIR.reward_fun of <vsOED.models.SIR object at 0x14f28a277520>>, 'kld_reward_fun': <bound method POST_APPROX.reward_fun of <vsOED.post_approx.POST_APPROX object at 0x14f133958fa0>>, 'phys_state_info': (1, [0.0], <bound method SIR.xp_f of <vsOED.models.SIR object at 0x14f28a277520>>), 'post_approx': <vsOED.post_approx.POST_APPROX object at 0x14f133958fa0>, 'encoder_dimns': None, 'backend_dimns': None, 'actor_dimns': [256, 256, 256], 'critic_dimns': [256, 256, 256], 'activate': <class 'torch.nn.modules.activation.ReLU'>}

# %%
actor_lr = 3e-4
actor_lr_scheduler_gamma = 0.9999
critic_lr = 1e-3
critic_lr_scheduler_gamma = 0.9999
    
n_update = 10001
n_newtraj = 1000
n_batch = 10000
n_buffer_init = n_batch * 2
n_buffer_max = int(1e6)
buffer_device = torch.device('cuda')
discount = 1 if n_incre == 1 else 0.9
encoder_actor_optimizer = None
encoder_actor_lr_scheduler = None
encoder_critic_optimizer = None
encoder_critic_lr_scheduler = None
actor_optimizer = optim.Adam(vsoed.actor_net.parameters(), lr=actor_lr)
actor_lr_scheduler = optim.lr_scheduler.ExponentialLR(actor_optimizer, gamma=actor_lr_scheduler_gamma)
n_critic_update = 5
critic_optimizer = optim.Adam(vsoed.critic_net.parameters(), lr=critic_lr)
critic_lr_scheduler = optim.lr_scheduler.ExponentialLR(critic_optimizer, gamma=critic_lr_scheduler_gamma)
n_post_approx_update = 5
lr_target = 0.1
design_noise_scale = 5
design_noise_decay = 0.9999
on_policy = False
use_PCE = False
use_PCE_incre = None
n_contrastive_sample = None
transition = 10000 if n_incre == 1 else 0
frozen = -1
save_every = 10000
save_path = folder
restart = False

vsoed_train_params = {
    'n_update': n_update,
    'n_newtraj': n_newtraj,
    'n_batch': n_batch,
    'n_buffer_init': n_buffer_init,
    'n_buffer_max': n_buffer_max,
    'buffer_device': buffer_device,
    'discount': discount,
    'encoder_actor_optimizer': encoder_actor_optimizer,
    'encoder_actor_lr_scheduler': encoder_actor_lr_scheduler,
    'encoder_critic_optimizer': encoder_critic_optimizer,
    'encoder_critic_lr_scheduler': encoder_critic_lr_scheduler,
    'actor_lr': actor_lr,
    'actor_optimizer': actor_optimizer,
    'actor_lr_scheduler_gamma': actor_lr_scheduler_gamma, 
    'actor_lr_scheduler': actor_lr_scheduler,
    'n_critic_update': n_critic_update,
    'critic_lr': critic_lr,
    'critic_optimizer': critic_optimizer,
    'critic_lr_scheduler_gamma': critic_lr_scheduler_gamma,
    'critic_lr_scheduler': critic_lr_scheduler,
    'n_post_approx_update': n_post_approx_update,
    'lr_target': lr_target,
    'design_noise_scale': design_noise_scale,
    'design_noise_decay': design_noise_decay,
    'on_policy': on_policy,
    'use_PCE': use_PCE,
    'use_PCE_incre': use_PCE_incre,
    'n_contrastive_sample': n_contrastive_sample,
    'transition': transition,
    'frozen': frozen,
    'log_every': log_every,
    'dowel': dowel,
    'save_every': save_every,
    'save_path': save_path,
    'restart': restart
}

dowel.logger.log('vsoed_train_params: ' + str(vsoed_train_params))

del vsoed_train_params['actor_lr']
del vsoed_train_params['actor_lr_scheduler_gamma']
del vsoed_train_params['critic_lr']
del vsoed_train_params['critic_lr_scheduler_gamma']
# Out:
# 2023-05-02 15:43:54 | [CES] vsoed_train_params: {'n_update': 10001, 'n_newtraj': 1000, 'n_batch': 10000, 'n_buffer_init': 20000, 'n_buffer_max': 1000000, 'buffer_device': device(type='cuda'), 'discount': 1, 'encoder_actor_optimizer': None, 'encoder_actor_lr_scheduler': None, 'encoder_critic_optimizer': None, 'encoder_critic_lr_scheduler': None, 'actor_lr': 0.0003, 'actor_optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.0003
#     lr: 0.0003
#     maximize: False
#     weight_decay: 0
# ), 'actor_lr_scheduler_gamma': 0.9999, 'actor_lr_scheduler': <torch.optim.lr_scheduler.ExponentialLR object at 0x14f137d28f10>, 'n_critic_update': 5, 'critic_lr': 0.001, 'critic_optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# ), 'critic_lr_scheduler_gamma': 0.9999, 'critic_lr_scheduler': <torch.optim.lr_scheduler.ExponentialLR object at 0x14f137d28d60>, 'n_post_approx_update': 5, 'lr_target': 0.1, 'design_noise_scale': 5, 'design_noise_decay': 0.9999, 'on_policy': False, 'use_PCE': False, 'use_PCE_incre': None, 'n_contrastive_sample': None, 'transition': 10000, 'frozen': -1, 'log_every': 100, 'dowel': <module 'dowel' from '/home/wgshen/.local/lib/python3.9/site-packages/dowel/__init__.py'>, 'save_every': 10000, 'save_path': '/scratch/xhuan_root/xhuan1/wgshen/vsOED/experiments/ces_1model_5stage_1incre_GMM/', 'restart': False}

# %%
try:
    for _ in range(100):
        dowel.logger.pop_prefix()
except:
    pass
dowel.logger.push_prefix('[SIR] ')
vsoed.train(**vsoed_train_params)
# Out:
# 2023-05-02 15:44:00 | [SIR] epoch #0 | log param_of_interest post after training: -5.2659382820129395
# 2023-05-02 15:44:05 | [SIR] epoch #0 | Checkpoint saved
# 2023-05-02 15:44:05 | [SIR] epoch #0 | Total time 10.83 s
# 2023-05-02 15:44:05 | [SIR] epoch #0 | Epoch time 5.71 s
# ------------------------  -------------------
# Design/MeanDesign         [36.7159538269043]
# Design/StdDesign          [9.402817726135254]
# Epoch                     0
# ReplayBuffer/buffer_size  20000
# Reward/MeanReward         -12.27627944946289
# Reward/StdReward          7.695374488830566
# ------------------------  -------------------
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Epoch: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Reward/MeanReward: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Reward/StdReward: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Design/MeanDesign: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Design/StdDesign: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {ReplayBuffer/buffer_size: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# 2023-05-02 15:44:39 | [SIR] epoch #100 | log param_of_interest post after training: -0.8915373086929321
# 2023-05-02 15:44:40 | [SIR] epoch #100 | Total time 45.45 s
# 2023-05-02 15:44:40 | [SIR] epoch #100 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [2.7702643871307373]
# Design/StdDesign          [5.201104164123535]
# Epoch                     100
# ReplayBuffer/buffer_size  120000
# Reward/MeanReward         -0.9415521621704102
# Reward/StdReward          0.7259871363639832
# ------------------------  --------------------
# 2023-05-02 15:45:14 | [SIR] epoch #200 | log param_of_interest post after training: -0.7369477152824402
# 2023-05-02 15:45:14 | [SIR] epoch #200 | Total time 80.07 s
# 2023-05-02 15:45:14 | [SIR] epoch #200 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [7.160406112670898]
# Design/StdDesign          [13.313323020935059]
# Epoch                     200
# ReplayBuffer/buffer_size  220000
# Reward/MeanReward         -0.6680163741111755
# Reward/StdReward          0.40654048323631287
# ------------------------  --------------------
# 2023-05-02 15:45:49 | [SIR] epoch #300 | log param_of_interest post after training: -0.7071308493614197
# 2023-05-02 15:45:49 | [SIR] epoch #300 | Total time 114.64 s
# 2023-05-02 15:45:49 | [SIR] epoch #300 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [6.5187578201293945]
# Design/StdDesign          [12.743081092834473]
# Epoch                     300
# ReplayBuffer/buffer_size  320000
# Reward/MeanReward         -0.6633082628250122
# Reward/StdReward          0.34377554059028625
# ------------------------  --------------------
# 2023-05-02 15:46:23 | [SIR] epoch #400 | log param_of_interest post after training: -0.6425421833992004
# 2023-05-02 15:46:23 | [SIR] epoch #400 | Total time 149.11 s
# 2023-05-02 15:46:23 | [SIR] epoch #400 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [11.78846263885498]
# Design/StdDesign          [17.607940673828125]
# Epoch                     400
# ReplayBuffer/buffer_size  420000
# Reward/MeanReward         -0.6070742607116699
# Reward/StdReward          0.27869659662246704
# ------------------------  --------------------
# 2023-05-02 15:46:58 | [SIR] epoch #500 | log param_of_interest post after training: -0.6078755855560303
# 2023-05-02 15:46:58 | [SIR] epoch #500 | Total time 183.67 s
# 2023-05-02 15:46:58 | [SIR] epoch #500 | Epoch time 0.36 s
# ------------------------  --------------------
# Design/MeanDesign         [12.98829460144043]
# Design/StdDesign          [17.836854934692383]
# Epoch                     500
# ReplayBuffer/buffer_size  520000
# Reward/MeanReward         -0.5742142200469971
# Reward/StdReward          0.21919068694114685
# ------------------------  --------------------
# 2023-05-02 15:47:32 | [SIR] epoch #600 | log param_of_interest post after training: -0.5916739702224731
# 2023-05-02 15:47:32 | [SIR] epoch #600 | Total time 218.08 s
# 2023-05-02 15:47:32 | [SIR] epoch #600 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [15.048187255859375]
# Design/StdDesign          [21.55759048461914]
# Epoch                     600
# ReplayBuffer/buffer_size  620000
# Reward/MeanReward         -0.5391106009483337
# Reward/StdReward          0.197397843003273
# ------------------------  --------------------
# 2023-05-02 15:48:07 | [SIR] epoch #700 | log param_of_interest post after training: -0.5679778456687927
# 2023-05-02 15:48:07 | [SIR] epoch #700 | Total time 252.57 s
# 2023-05-02 15:48:07 | [SIR] epoch #700 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [16.86799430847168]
# Design/StdDesign          [24.257944107055664]
# Epoch                     700
# ReplayBuffer/buffer_size  720000
# Reward/MeanReward         -0.5522904396057129
# Reward/StdReward          0.18168246746063232
# ------------------------  --------------------
# 2023-05-02 15:48:41 | [SIR] epoch #800 | log param_of_interest post after training: -0.5595992803573608
# 2023-05-02 15:48:41 | [SIR] epoch #800 | Total time 287.08 s
# 2023-05-02 15:48:41 | [SIR] epoch #800 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [17.913389205932617]
# Design/StdDesign          [24.143007278442383]
# Epoch                     800
# ReplayBuffer/buffer_size  820000
# Reward/MeanReward         -0.5412582755088806
# Reward/StdReward          0.23025958240032196
# ------------------------  --------------------
# 2023-05-02 15:49:15 | [SIR] epoch #900 | log param_of_interest post after training: -0.5562224388122559
# 2023-05-02 15:49:16 | [SIR] epoch #900 | Total time 321.46 s
# 2023-05-02 15:49:16 | [SIR] epoch #900 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [16.204374313354492]
# Design/StdDesign          [22.83354377746582]
# Epoch                     900
# ReplayBuffer/buffer_size  920000
# Reward/MeanReward         -0.5284447073936462
# Reward/StdReward          0.17668311297893524
# ------------------------  --------------------
# 2023-05-02 15:49:50 | [SIR] epoch #1000 | log param_of_interest post after training: -0.5551300644874573
# 2023-05-02 15:49:50 | [SIR] epoch #1000 | Total time 355.97 s
# 2023-05-02 15:49:50 | [SIR] epoch #1000 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [15.059221267700195]
# Design/StdDesign          [22.77239227294922]
# Epoch                     1000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5628777742385864
# Reward/StdReward          0.1881064772605896
# ------------------------  --------------------
# 2023-05-02 15:50:24 | [SIR] epoch #1100 | log param_of_interest post after training: -0.5418902039527893
# 2023-05-02 15:50:25 | [SIR] epoch #1100 | Total time 390.46 s
# 2023-05-02 15:50:25 | [SIR] epoch #1100 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [17.08086585998535]
# Design/StdDesign          [22.487525939941406]
# Epoch                     1100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5337328910827637
# Reward/StdReward          0.3126101493835449
# ------------------------  --------------------
# 2023-05-02 15:50:59 | [SIR] epoch #1200 | log param_of_interest post after training: -0.5364320278167725
# 2023-05-02 15:50:59 | [SIR] epoch #1200 | Total time 424.82 s
# 2023-05-02 15:50:59 | [SIR] epoch #1200 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [16.499347686767578]
# Design/StdDesign          [23.574176788330078]
# Epoch                     1200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5172903537750244
# Reward/StdReward          0.14686763286590576
# ------------------------  --------------------
# 2023-05-02 15:51:33 | [SIR] epoch #1300 | log param_of_interest post after training: -0.5313177704811096
# 2023-05-02 15:51:33 | [SIR] epoch #1300 | Total time 459.27 s
# 2023-05-02 15:51:33 | [SIR] epoch #1300 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [16.785608291625977]
# Design/StdDesign          [23.789888381958008]
# Epoch                     1300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5233055949211121
# Reward/StdReward          0.1330733597278595
# ------------------------  --------------------
# 2023-05-02 15:52:08 | [SIR] epoch #1400 | log param_of_interest post after training: -0.5248631834983826
# 2023-05-02 15:52:08 | [SIR] epoch #1400 | Total time 493.78 s
# 2023-05-02 15:52:08 | [SIR] epoch #1400 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [15.627771377563477]
# Design/StdDesign          [22.600187301635742]
# Epoch                     1400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5174651145935059
# Reward/StdReward          0.11581577360630035
# ------------------------  --------------------
# 2023-05-02 15:52:42 | [SIR] epoch #1500 | log param_of_interest post after training: -0.5180681347846985
# 2023-05-02 15:52:42 | [SIR] epoch #1500 | Total time 528.31 s
# 2023-05-02 15:52:42 | [SIR] epoch #1500 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [17.417062759399414]
# Design/StdDesign          [24.56829071044922]
# Epoch                     1500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5110926628112793
# Reward/StdReward          0.13637837767601013
# ------------------------  --------------------
# 2023-05-02 15:53:17 | [SIR] epoch #1600 | log param_of_interest post after training: -0.5160720944404602
# 2023-05-02 15:53:17 | [SIR] epoch #1600 | Total time 562.78 s
# 2023-05-02 15:53:17 | [SIR] epoch #1600 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.998605728149414]
# Design/StdDesign          [23.371278762817383]
# Epoch                     1600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5238077640533447
# Reward/StdReward          0.1932719200849533
# ------------------------  --------------------
# 2023-05-02 15:53:51 | [SIR] epoch #1700 | log param_of_interest post after training: -0.5119891166687012
# 2023-05-02 15:53:51 | [SIR] epoch #1700 | Total time 597.27 s
# 2023-05-02 15:53:51 | [SIR] epoch #1700 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [16.748455047607422]
# Design/StdDesign          [23.198450088500977]
# Epoch                     1700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5034350752830505
# Reward/StdReward          0.08844880014657974
# ------------------------  --------------------
# 2023-05-02 15:54:26 | [SIR] epoch #1800 | log param_of_interest post after training: -0.5067521333694458
# 2023-05-02 15:54:26 | [SIR] epoch #1800 | Total time 631.78 s
# 2023-05-02 15:54:26 | [SIR] epoch #1800 | Epoch time 0.34 s
# ------------------------  --------------------
# Design/MeanDesign         [15.929821014404297]
# Design/StdDesign          [22.103809356689453]
# Epoch                     1800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5077525973320007
# Reward/StdReward          0.1779237538576126
# ------------------------  --------------------
# 2023-05-02 15:55:00 | [SIR] epoch #1900 | log param_of_interest post after training: -0.5172008872032166
# 2023-05-02 15:55:00 | [SIR] epoch #1900 | Total time 666.28 s
# 2023-05-02 15:55:00 | [SIR] epoch #1900 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.114706039428711]
# Design/StdDesign          [21.303272247314453]
# Epoch                     1900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5085029006004333
# Reward/StdReward          0.10355212539434433
# ------------------------  --------------------
# 2023-05-02 15:56:20 | [SIR] epoch #2100 | log param_of_interest post after training: -0.5026749968528748
# 2023-05-02 15:56:20 | [SIR] epoch #2100 | Total time 746.16 s
# 2023-05-02 15:56:20 | [SIR] epoch #2100 | Epoch time 0.35 s
# ------------------------  -------------------
# Design/MeanDesign         [15.91425895690918]
# Design/StdDesign          [22.1910343170166]
# Epoch                     2100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5074930191040039
# Reward/StdReward          0.13419847190380096
# ------------------------  -------------------
# 2023-05-02 15:56:55 | [SIR] epoch #2200 | log param_of_interest post after training: -0.5023968815803528
# 2023-05-02 15:56:55 | [SIR] epoch #2200 | Total time 781.28 s
# 2023-05-02 15:56:55 | [SIR] epoch #2200 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.607439994812012]
# Design/StdDesign          [21.787090301513672]
# Epoch                     2200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49724599719047546
# Reward/StdReward          0.080006904900074
# ------------------------  --------------------
# 2023-05-02 15:57:30 | [SIR] epoch #2300 | log param_of_interest post after training: -0.5018206238746643
# 2023-05-02 15:57:30 | [SIR] epoch #2300 | Total time 816.39 s
# 2023-05-02 15:57:30 | [SIR] epoch #2300 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.530770301818848]
# Design/StdDesign          [21.44965362548828]
# Epoch                     2300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5005863308906555
# Reward/StdReward          0.1203717291355133
# ------------------------  --------------------
# 2023-05-02 15:58:06 | [SIR] epoch #2400 | log param_of_interest post after training: -0.5026769638061523
# 2023-05-02 15:58:06 | [SIR] epoch #2400 | Total time 851.60 s
# 2023-05-02 15:58:06 | [SIR] epoch #2400 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.174816131591797]
# Design/StdDesign          [22.866003036499023]
# Epoch                     2400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.504477858543396
# Reward/StdReward          0.15266138315200806
# ------------------------  --------------------
# 2023-05-02 15:58:41 | [SIR] epoch #2500 | log param_of_interest post after training: -0.4984872043132782
# 2023-05-02 15:58:41 | [SIR] epoch #2500 | Total time 886.81 s
# 2023-05-02 15:58:41 | [SIR] epoch #2500 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.166126251220703]
# Design/StdDesign          [21.808082580566406]
# Epoch                     2500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5036555528640747
# Reward/StdReward          0.11792601644992828
# ------------------------  --------------------
# 2023-05-02 15:59:16 | [SIR] epoch #2600 | log param_of_interest post after training: -0.4979250729084015
# 2023-05-02 15:59:16 | [SIR] epoch #2600 | Total time 921.98 s
# 2023-05-02 15:59:16 | [SIR] epoch #2600 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.009252548217773]
# Design/StdDesign          [22.710643768310547]
# Epoch                     2600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4991266429424286
# Reward/StdReward          0.10389100015163422
# ------------------------  --------------------
# 2023-05-02 15:59:51 | [SIR] epoch #2700 | log param_of_interest post after training: -0.499816358089447
# 2023-05-02 15:59:51 | [SIR] epoch #2700 | Total time 957.15 s
# 2023-05-02 15:59:51 | [SIR] epoch #2700 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.496774673461914]
# Design/StdDesign          [22.894996643066406]
# Epoch                     2700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5004366040229797
# Reward/StdReward          0.11075973510742188
# ------------------------  --------------------
# 2023-05-02 16:00:26 | [SIR] epoch #2800 | log param_of_interest post after training: -0.4984869360923767
# 2023-05-02 16:00:26 | [SIR] epoch #2800 | Total time 992.28 s
# 2023-05-02 16:00:26 | [SIR] epoch #2800 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.309232711791992]
# Design/StdDesign          [22.191728591918945]
# Epoch                     2800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49793753027915955
# Reward/StdReward          0.09971517324447632
# ------------------------  --------------------
# 2023-05-02 16:01:01 | [SIR] epoch #2900 | log param_of_interest post after training: -0.5013932585716248
# 2023-05-02 16:01:01 | [SIR] epoch #2900 | Total time 1027.40 s
# 2023-05-02 16:01:01 | [SIR] epoch #2900 | Epoch time 0.35 s
# ------------------------  -------------------
# Design/MeanDesign         [15.7688570022583]
# Design/StdDesign          [22.70275115966797]
# Epoch                     2900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5040847659111023
# Reward/StdReward          0.10419835150241852
# ------------------------  -------------------
# 2023-05-02 16:01:37 | [SIR] epoch #3000 | log param_of_interest post after training: -0.4974192678928375
# 2023-05-02 16:01:37 | [SIR] epoch #3000 | Total time 1062.51 s
# 2023-05-02 16:01:37 | [SIR] epoch #3000 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.49608039855957]
# Design/StdDesign          [21.473827362060547]
# Epoch                     3000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5031895041465759
# Reward/StdReward          0.09858078509569168
# ------------------------  --------------------
# 2023-05-02 16:02:12 | [SIR] epoch #3100 | log param_of_interest post after training: -0.4997623860836029
# 2023-05-02 16:02:12 | [SIR] epoch #3100 | Total time 1097.68 s
# 2023-05-02 16:02:12 | [SIR] epoch #3100 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [14.887889862060547]
# Design/StdDesign          [21.071836471557617]
# Epoch                     3100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49960851669311523
# Reward/StdReward          0.10827255994081497
# ------------------------  --------------------
# 2023-05-02 16:02:47 | [SIR] epoch #3200 | log param_of_interest post after training: -0.4978795349597931
# 2023-05-02 16:02:47 | [SIR] epoch #3200 | Total time 1132.86 s
# 2023-05-02 16:02:47 | [SIR] epoch #3200 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.644453048706055]
# Design/StdDesign          [21.089048385620117]
# Epoch                     3200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5088804960250854
# Reward/StdReward          0.14487114548683167
# ------------------------  --------------------
# 2023-05-02 16:03:22 | [SIR] epoch #3300 | log param_of_interest post after training: -0.49755898118019104
# 2023-05-02 16:03:22 | [SIR] epoch #3300 | Total time 1168.02 s
# 2023-05-02 16:03:22 | [SIR] epoch #3300 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.08564567565918]
# Design/StdDesign          [21.104209899902344]
# Epoch                     3300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49469730257987976
# Reward/StdReward          0.0869164764881134
# ------------------------  --------------------
# 2023-05-02 16:03:57 | [SIR] epoch #3400 | log param_of_interest post after training: -0.4988562762737274
# 2023-05-02 16:03:57 | [SIR] epoch #3400 | Total time 1203.17 s
# 2023-05-02 16:03:57 | [SIR] epoch #3400 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [14.830424308776855]
# Design/StdDesign          [20.47380828857422]
# Epoch                     3400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5008894801139832
# Reward/StdReward          0.12058214843273163
# ------------------------  --------------------
# 2023-05-02 16:04:32 | [SIR] epoch #3500 | log param_of_interest post after training: -0.495973140001297
# 2023-05-02 16:04:32 | [SIR] epoch #3500 | Total time 1238.35 s
# 2023-05-02 16:04:32 | [SIR] epoch #3500 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.988188743591309]
# Design/StdDesign          [20.43136215209961]
# Epoch                     3500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4924674928188324
# Reward/StdReward          0.07449900358915329
# ------------------------  --------------------
# 2023-05-02 16:05:07 | [SIR] epoch #3600 | log param_of_interest post after training: -0.49792855978012085
# 2023-05-02 16:05:08 | [SIR] epoch #3600 | Total time 1273.47 s
# 2023-05-02 16:05:08 | [SIR] epoch #3600 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.44834041595459]
# Design/StdDesign          [20.59160041809082]
# Epoch                     3600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49225789308547974
# Reward/StdReward          0.0959635004401207
# ------------------------  --------------------
# 2023-05-02 16:05:43 | [SIR] epoch #3700 | log param_of_interest post after training: -0.4959780275821686
# 2023-05-02 16:05:43 | [SIR] epoch #3700 | Total time 1308.57 s
# 2023-05-02 16:05:43 | [SIR] epoch #3700 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.192943572998047]
# Design/StdDesign          [20.629222869873047]
# Epoch                     3700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4977308511734009
# Reward/StdReward          0.0927092507481575
# ------------------------  --------------------
# 2023-05-02 16:06:18 | [SIR] epoch #3800 | log param_of_interest post after training: -0.49660974740982056
# 2023-05-02 16:06:18 | [SIR] epoch #3800 | Total time 1343.69 s
# 2023-05-02 16:06:18 | [SIR] epoch #3800 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.150065422058105]
# Design/StdDesign          [19.45319938659668]
# Epoch                     3800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5028108358383179
# Reward/StdReward          0.10608891397714615
# ------------------------  --------------------
# 2023-05-02 16:06:53 | [SIR] epoch #3900 | log param_of_interest post after training: -0.49712079763412476
# 2023-05-02 16:06:53 | [SIR] epoch #3900 | Total time 1378.88 s
# 2023-05-02 16:06:53 | [SIR] epoch #3900 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.30444049835205]
# Design/StdDesign          [19.723426818847656]
# Epoch                     3900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49473127722740173
# Reward/StdReward          0.08578484505414963
# ------------------------  --------------------
# 2023-05-02 16:07:41 | [SIR] epoch #4000 | log param_of_interest post after training: -0.4954816699028015
# 2023-05-02 16:07:41 | [SIR] epoch #4000 | Total time 1427.29 s
# 2023-05-02 16:07:41 | [SIR] epoch #4000 | Epoch time 13.60 s
# ------------------------  --------------------
# Design/MeanDesign         [15.404228210449219]
# Design/StdDesign          [19.92823600769043]
# Epoch                     4000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4971446692943573
# Reward/StdReward          0.14287804067134857
# ------------------------  --------------------
# 2023-05-02 16:08:16 | [SIR] epoch #4100 | log param_of_interest post after training: -0.4938926100730896
# 2023-05-02 16:08:16 | [SIR] epoch #4100 | Total time 1462.11 s
# 2023-05-02 16:08:16 | [SIR] epoch #4100 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.090046882629395]
# Design/StdDesign          [20.491558074951172]
# Epoch                     4100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.496776282787323
# Reward/StdReward          0.07289887964725494
# ------------------------  --------------------
# 2023-05-02 16:08:51 | [SIR] epoch #4200 | log param_of_interest post after training: -0.49321800470352173
# 2023-05-02 16:08:51 | [SIR] epoch #4200 | Total time 1496.87 s
# 2023-05-02 16:08:51 | [SIR] epoch #4200 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.391371726989746]
# Design/StdDesign          [18.276275634765625]
# Epoch                     4200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49159571528434753
# Reward/StdReward          0.10348621010780334
# ------------------------  --------------------
# 2023-05-02 16:09:26 | [SIR] epoch #4300 | log param_of_interest post after training: -0.4957731366157532
# 2023-05-02 16:09:26 | [SIR] epoch #4300 | Total time 1531.62 s
# 2023-05-02 16:09:26 | [SIR] epoch #4300 | Epoch time 0.35 s
# ------------------------  -------------------
# Design/MeanDesign         [16.12471580505371]
# Design/StdDesign          [20.07586097717285]
# Epoch                     4300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4937591254711151
# Reward/StdReward          0.10750583559274673
# ------------------------  -------------------
# 2023-05-02 16:10:00 | [SIR] epoch #4400 | log param_of_interest post after training: -0.4925026297569275
# 2023-05-02 16:10:01 | [SIR] epoch #4400 | Total time 1566.42 s
# 2023-05-02 16:10:01 | [SIR] epoch #4400 | Epoch time 0.37 s
# ------------------------  --------------------
# Design/MeanDesign         [15.998115539550781]
# Design/StdDesign          [20.70460319519043]
# Epoch                     4400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4943309724330902
# Reward/StdReward          0.1344819962978363
# ------------------------  --------------------
# 2023-05-02 16:10:35 | [SIR] epoch #4500 | log param_of_interest post after training: -0.49274763464927673
# 2023-05-02 16:10:35 | [SIR] epoch #4500 | Total time 1601.20 s
# 2023-05-02 16:10:35 | [SIR] epoch #4500 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.951906204223633]
# Design/StdDesign          [19.19274139404297]
# Epoch                     4500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49852442741394043
# Reward/StdReward          0.11945555359125137
# ------------------------  --------------------
# 2023-05-02 16:11:10 | [SIR] epoch #4600 | log param_of_interest post after training: -0.4950333833694458
# 2023-05-02 16:11:10 | [SIR] epoch #4600 | Total time 1635.90 s
# 2023-05-02 16:11:10 | [SIR] epoch #4600 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.630147933959961]
# Design/StdDesign          [19.14012908935547]
# Epoch                     4600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4930212199687958
# Reward/StdReward          0.11744141578674316
# ------------------------  --------------------
# 2023-05-02 16:11:45 | [SIR] epoch #4700 | log param_of_interest post after training: -0.49220800399780273
# 2023-05-02 16:11:45 | [SIR] epoch #4700 | Total time 1670.62 s
# 2023-05-02 16:11:45 | [SIR] epoch #4700 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [17.206708908081055]
# Design/StdDesign          [20.925859451293945]
# Epoch                     4700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5001190304756165
# Reward/StdReward          0.1263183057308197
# ------------------------  --------------------
# 2023-05-02 16:12:19 | [SIR] epoch #4800 | log param_of_interest post after training: -0.4923260509967804
# 2023-05-02 16:12:19 | [SIR] epoch #4800 | Total time 1705.37 s
# 2023-05-02 16:12:19 | [SIR] epoch #4800 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.718225479125977]
# Design/StdDesign          [20.58301544189453]
# Epoch                     4800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4960598945617676
# Reward/StdReward          0.11514648795127869
# ------------------------  --------------------
# 2023-05-02 16:12:54 | [SIR] epoch #4900 | log param_of_interest post after training: -0.4919651746749878
# 2023-05-02 16:12:54 | [SIR] epoch #4900 | Total time 1740.13 s
# 2023-05-02 16:12:54 | [SIR] epoch #4900 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.977564811706543]
# Design/StdDesign          [20.654850006103516]
# Epoch                     4900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49424248933792114
# Reward/StdReward          0.11422788351774216
# ------------------------  --------------------
# 2023-05-02 16:13:29 | [SIR] epoch #5000 | log param_of_interest post after training: -0.49098098278045654
# 2023-05-02 16:13:29 | [SIR] epoch #5000 | Total time 1774.91 s
# 2023-05-02 16:13:29 | [SIR] epoch #5000 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [15.296518325805664]
# Design/StdDesign          [19.360958099365234]
# Epoch                     5000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.4936656355857849
# Reward/StdReward          0.08598162233829498
# ------------------------  --------------------
# 2023-05-02 16:14:04 | [SIR] epoch #5100 | log param_of_interest post after training: -0.49137595295906067
# 2023-05-02 16:14:04 | [SIR] epoch #5100 | Total time 1809.82 s
# 2023-05-02 16:14:04 | [SIR] epoch #5100 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.0605411529541]
# Design/StdDesign          [19.62796401977539]
# Epoch                     5100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.49065181612968445
# Reward/StdReward          0.10163770616054535
# ------------------------  --------------------
# 2023-05-02 16:14:39 | [SIR] epoch #5200 | log param_of_interest post after training: -0.4897918403148651
# 2023-05-02 16:14:39 | [SIR] epoch #5200 | Total time 1844.68 s
# 2023-05-02 16:14:39 | [SIR] epoch #5200 | Epoch time 0.35 s
# ------------------------  --------------------
# Design/MeanDesign         [16.390634536743164]
# Design/StdDesign          [20.038541793823242]
# Epoch                     5200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         -0.5003823637962341
# Reward/StdReward          0.15854649245738983
# ------------------------  --------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_531626/1865694861.py in <module>
#       5     pass
#       6 dowel.logger.push_prefix('[SIR] ')
# ----> 7 vsoed.train(**vsoed_train_params)
#
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py in train(self, n_update, n_newtraj, n_batch, n_buffer_init, n_buffer_max, buffer_device, discount, encoder_actor_optimizer, encoder_actor_lr_scheduler, encoder_critic_optimizer, encoder_critic_lr_scheduler, actor_optimizer, actor_lr_scheduler, n_critic_update, critic_optimizer, critic_lr_scheduler, n_post_approx_update, lr_target, design_noise_scale, design_noise_decay, on_policy, use_PCE, use_PCE_incre, n_contrastive_sample, transition, frozen, log_every, dowel, save_every, save_path, restart)
#     717         while self.update < self.n_update:
#     718             t1 = time.time()
# --> 719             self.asses(self.n_newtraj, self.design_noise_scale, True, self.use_PCE, self.use_PCE_incre, self.n_contrastive_sample)
#     720             self.dowel.logger.push_prefix(f'epoch #{self.update} | ')
#     721             self.dowel.tabular.clear()
#
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py in asses(self, n_traj, design_noise_scale, in_training, use_PCE, use_PCE_incre, n_contrastive_sample, return_nkld_rewards, return_all, param_samples, save_path, dowel)
#     988
#     989                 # Run the forward model to get observations.
# --> 990                 ys = self.m_f(k, params, ds, xps_hist[:, k, :])
#     991                 ys_hist[:, k, :] = ys
#     992
#
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/models.py in model(self, stage, theta, d, xp)
#     320             grid = self.grid(d, xp).reshape(-1) # (n_sample)
#     321             assert len(grid) == len(idxs)
# --> 322             ys = self.data['ys'][idxs.to('cpu')][torch.arange(len(grid)).to('cpu'),
#     323                                                  grid.to('cpu')].to(idxs.device).reshape(-1, 1)
#     324             # elif self.mode == 'eval':
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 4))
plt.plot(vsoed.update_hist[:])
plt.xlabel('update', fontsize=20)
plt.ylabel('averaged reward', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(linestyle='--')

# %%
from tqdm import trange
model.reset_test()
averaged_rewards = []
rewards = []
for i in trange(30):
    model.data = torch.load(data_folder + f'/test_data/sir_test_data_{i}.pt')
    ret = vsoed.asses(model.data['num_samples'], use_PCE=False, return_all=True)
    averaged_reward = ret['averaged_reward']
    params = ret['params']
    ds_hist = ret['ds_hist']
    ys_hist = ret['ys_hist']
    rewards_hist = ret['rewards_hist']
    averaged_rewards.append(averaged_reward)
    rewards += list(rewards_hist[:, -1])
averaged_rewards = np.array(averaged_rewards)
rewards = np.array(rewards)
# Out:
# 100%|██████████| 30/30 [01:30<00:00,  3.02s/it]

# %%
averaged_rewards.mean()
# Out:
# 0.8991613785425822

# %%
model.log_poi_prior(params).mean()
# Out:
# tensor(-1.3895, device='cuda:0')

# %%
averaged_reward
# Out:
# 9.131694793701172

# %%
torch.
# Out:
# tensor(22026.4668, device='cuda:0')

# %%
torch.logsumexp(torch.rand(1000, 10) + 10, -1)
# Out:
# tensor([12.8075, 12.8097, 12.9265, 12.6681, 12.8283, 12.9270, 12.6145, 12.7931,
#         12.8640, 12.9860, 12.7083, 12.8731, 12.9903, 12.8869, 12.8719, 12.6418,
#         12.6884, 12.7964, 12.9192, 12.9209, 12.9399, 12.6670, 12.8244, 12.9630,
#         12.9598, 12.7226, 12.6308, 12.6758, 12.8094, 12.7400, 12.9320, 12.8075,
#         12.9214, 12.9046, 12.8745, 12.7721, 12.8292, 12.8966, 12.8324, 12.8588,
#         12.8818, 12.7865, 12.9365, 12.6977, 12.9184, 12.9007, 12.8528, 12.9425,
#         12.8968, 12.8776, 12.9317, 12.8635, 12.8957, 12.7419, 12.7541, 12.7679,
#         12.9049, 12.8832, 13.0192, 12.8427, 12.9062, 12.7970, 12.8341, 12.6946,
#         12.7965, 12.9466, 12.9698, 12.7751, 12.9005, 12.8335, 12.8252, 12.7737,
#         12.8508, 12.7395, 12.6460, 12.7510, 12.7767, 13.0215, 12.7439, 12.8396,
#         12.8380, 12.8863, 12.9624, 12.7878, 12.8541, 12.8827, 12.8109, 12.6559,
#         12.7579, 12.8063, 12.9694, 12.8261, 12.8377, 12.6966, 12.7231, 12.7703,
#         12.6775, 12.8204, 12.7683, 12.9007, 12.6942, 12.7648, 12.7813, 13.0083,
#         12.8035, 12.8054, 12.7669, 12.8537, 12.7487, 12.6682, 12.8392, 12.7948,
#         12.6161, 12.7286, 12.8422, 12.8510, 12.9006, 12.8087, 12.8171, 12.8142,
#         12.8739, 12.8439, 12.9292, 12.8086, 12.8263, 12.7790, 12.8248, 12.7566,
#         12.9530, 12.8563, 12.9069, 12.6505, 12.8610, 12.8313, 12.8253, 12.9027,
#         12.7516, 12.7375, 12.8123, 12.7146, 12.7928, 12.9588, 12.7548, 12.8115,
#         12.8014, 12.9408, 12.7900, 12.8892, 12.7912, 12.7012, 12.8303, 12.8241,
#         12.9681, 12.8208, 12.8600, 12.8675, 12.8109, 12.5391, 12.8134, 12.8754,
#         12.9808, 12.9160, 12.8790, 12.8731, 12.9033, 12.7045, 12.8417, 12.8124,
#         12.9366, 12.8094, 12.9477, 12.8412, 12.8931, 12.8782, 12.8871, 12.8479,
#         12.7854, 12.9012, 12.8867, 12.6602, 12.9160, 12.7909, 12.9329, 12.8470,
#         13.0160, 12.7783, 12.7675, 12.7389, 12.8844, 12.7282, 12.8987, 12.6298,
#         12.8590, 12.9282, 12.7797, 12.8825, 12.9900, 12.9719, 12.7160, 12.9070,
#         12.7754, 12.8413, 12.7810, 12.9301, 12.7508, 12.7716, 12.8263, 12.8362,
#         12.9828, 12.9768, 12.8210, 12.9585, 12.7735, 12.8652, 12.7430, 12.8340,
#         12.7835, 12.8474, 12.9437, 12.7960, 12.9354, 12.8691, 13.0183, 12.7006,
#         12.7468, 12.9003, 12.8949, 12.9797, 12.8141, 13.0027, 12.9688, 12.8628,
#         12.9973, 12.7433, 12.7461, 12.7765, 13.0113, 12.8000, 12.8708, 12.9046],
#        device='cuda:0')

# %%
rewards_hist
# Out:
# tensor([[ 6.9315e-01,  0.0000e+00,  0.0000e+00, -5.9605e-08,  0.0000e+00,
#          -5.9605e-08,  0.0000e+00,  0.0000e+00, -5.9605e-08,  0.0000e+00,
#           0.0000e+00],
#         [ 6.9315e-01,  1.1921e-07,  0.0000e+00, -1.1921e-07,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -5.9605e-08,  0.0000e+00, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01,  0.0000e+00, -5.9605e-08,  0.0000e+00, -5.9605e-08,
#          -5.9605e-08,  0.0000e+00,  0.0000e+00,  0.0000e+00, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01, -5.9605e-08, -5.9605e-08,  1.1921e-07, -5.9605e-08,
#           0.0000e+00,  0.0000e+00,  1.1921e-07,  0.0000e+00, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01,  0.0000e+00, -5.9605e-08,  1.1921e-07,  0.0000e+00,
#          -1.7881e-07,  1.1921e-07,  1.1921e-07, -5.9605e-08, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -1.1921e-07, -5.9605e-08, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01, -5.9605e-08,  0.0000e+00, -5.9605e-08,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -1.1921e-07,  1.1921e-07, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01, -5.9605e-08,  1.1921e-07, -1.7881e-07,  0.0000e+00,
#           0.0000e+00,  0.0000e+00, -1.1921e-07,  1.1921e-07, -5.9605e-08,
#           0.0000e+00],
#         [ 6.9315e-01,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           1.1921e-07,  1.1921e-07, -5.9605e-08,  0.0000e+00, -1.1921e-07,
#           0.0000e+00],
#         [ 6.9315e-01, -5.9605e-08, -5.9605e-08,  1.1921e-07,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,        -inf,         nan,         nan,
#           0.0000e+00]], device='cuda:0')

# %%
ys_hist[9]
# Out:
# tensor([[-0.0001],
#         [-0.0001],
#         [-0.0002],
#         [-0.0002],
#         [-0.0002],
#         [-0.0002],
#         [-0.0002],
#         [-0.0002],
#         [-0.0002],
#         [-0.0003]], device='cuda:0')

# %%
ys_hist[5]
# Out:
# tensor([[-0.3773],
#         [-0.9212],
#         [-0.9566],
#         [-0.6134],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000]], device='cuda:0')

# %%
torch.nanmean(rewards_hist.sum(-1))
# Out:
# tensor(8.8126, device='cuda:0')

# %%
rewards_hist[5]
# Out:
# tensor([-1.0419e-01,  6.8577e+00,  1.3119e+00,  1.1293e+00, -8.5529e-03,
#         -1.6776e+01,         nan,         nan,         nan,         nan,
#          0.0000e+00], device='cuda:0')

# %%
params[5]
# Out:
# tensor([3.7016e-01, 1.7381e-03, 6.4873e-01, 3.8878e+00], device='cuda:0')

# %%
ys_hist[5]
# Out:
# tensor([[-0.3773],
#         [-0.9212],
#         [-0.9566],
#         [-0.6134],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000],
#         [-1.0000]], device='cuda:0')

# %%
ds_hist[30]
# Out:
# tensor([[-0.7289,  0.6698],
#         [ 0.8817,  1.2228],
#         [ 1.4341,  0.6463],
#         [ 1.0733, -1.2968],
#         [-0.8485, -0.9864],
#         [ 0.3985,  0.4226],
#         [ 0.2888, -0.5700],
#         [ 0.0655, -0.3715],
#         [-0.0392, -0.7437],
#         [ 0.2918, -0.7857]], device='cuda:0')

# %%
rewards_hist[:, :5].sum(-1).mean()
# Out:
# tensor(3.6108, device='cuda:0')

# %%
p_max = torch.arange(1, vsoed.n_buffer_max + 1).to(torch.float32)
l_buffer = 1000000
p = p_max[:l_buffer]
p /= p.sum()
idxs_pick = torch.multinomial(p, vsoed.n_batch, replacement=False)

# %%
plt.hist(idxs_pick.cpu().numpy())
# Out:
# (array([ 112.,  307.,  480.,  745.,  934., 1096., 1278., 1487., 1672.,
#         1889.]),
#  array([ 10025. , 109021.9, 208018.8, 307015.7, 406012.6, 505009.5,
#         604006.4, 703003.3, 802000.2, 900997.1, 999994. ]),
#  <BarContainer object of 10 artists>)

# %%
import joblib

# %%
joblib.dump(vsoed, folder + 'itr_0.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3852929/4165733059.py in <module>
# ----> 1 joblib.dump(vsoed, folder + 'itr_0.pkl')
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     480     elif is_filename:
#     481         with open(filename, 'wb') as f:
# --> 482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#     484         NumpyPickler(filename, protocol=protocol).dump(value)
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in dump(self, obj)
#     485         if self.proto >= 4:
#     486             self.framer.start_framing()
# --> 487         self.save(obj)
#     488         self.write(STOP)
#     489         self.framer.end_framing()
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690         else:
#     691             save(func)
# --> 692             save(args)
#     693             write(REDUCE)
#     694
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     576                 reduce = getattr(obj, "__reduce_ex__", None)
#     577                 if reduce is not None:
# --> 578                     rv = reduce(self.proto)
#     579                 else:
#     580                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'module' object

# %%
vsoed.nkld_rw_f
# Out:
# <function vsOED.vsoed.VSOED.__init__.<locals>.nkld_rw_f(*args, **kws)>

# %%
torch.tensor(())
# Out:
# tensor([])

# %%
{'a': 1}.update({'b': 5})

# %%
np.random.choice(int(1e10), 10)
# Out:
# array([6377791278, 7037998855, 7556092991, 8217385358, 8695645867,
#        1645853955, 1283211782, 8616980401, 3169416485, 1613878827])

# %%
dict().update

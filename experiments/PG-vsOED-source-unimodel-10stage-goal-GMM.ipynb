# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,inspect
# current_dir = '/home/jiayuand/seqOED_variational/examples/location'
# parent_dir = '/home/jiayuand/seqOED_variational'

# current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
# parent_dir = os.path.dirname(os.path.dirname(current_dir))
parent_dir = '/scratch/xhuan_root/xhuan1/wgshen/vsOED/'
sys.path.insert(0, parent_dir) 

import numpy as np
# from scipy.stats import norm, beta, dirichlet
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from   torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
if torch.cuda.is_available():  
    dev = "cuda:0" 
else:  
    dev = "cpu"  
device = torch.device(dev) 
torch.set_default_device(device)
dtype = torch.float32
torch.set_default_dtype(dtype)

from vsOED import VSOED, PGvsOED, GMM_NET, NFs, POST_APPROX
from vsOED.utils import *
from vsOED.models import *

import dowel

# %%
n_stage      = 10       # Number of stages.
n_design     = 2        # Number of design variables.
n_obs        = 1        # Number of observations.
n_pois       = [4]        # Number of parameters.
n_nuisps     = None
n_goals      = [1]
model_weight = 0
poi_weight   = 0
goal_weight  = 1

random_state  = TRAIN_SEEDS[0]
set_random_seed(random_state)

model = SOURCE(multimodel=False, include_nuisance=False, include_goal=True)
prior = model

mu_bounds = {}
mu_bounds['poi'] = []
for n_poi in n_pois:
    mu_bounds['poi'].append([[-6, 6]] * n_poi)
if n_goals is not None:
    mu_bounds['goal'] = []
    for n_goal in n_goals:
        mu_bounds['goal'].append([[-6, 6]] * n_goal)
max_sigmas = {}
max_sigmas['poi'] = []
for n_poi in n_pois:
    max_sigmas['poi'].append([1.0] * n_poi)
if n_goals is not None:
    max_sigmas['goal'] = []
    for n_goal in n_goals:
        max_sigmas['goal'].append([2.0] * n_goal)
truncnorm_info = {}
truncnorm_info['poi'] = [None] * len(n_pois)
# if n_goals is not None:
#     truncnorm_info['goal'] = []
#     for n_goal in n_goals:
#         info = []
#         for i in range(n_goal):
#             info.append([i, 0, 4])
#         truncnorm_info['goal'].append(info)
truncnorm_info['goal'] = [None] * len(n_goals)
        
            
n_incre = 1
share_interm_net = False

candidate_lrs = [[1e-3] * n_incre, [1e-4] * (n_incre - 1) + [1e-3]]
candidate_gammas = [[0.9999] * n_incre, [0.999999] * (n_incre - 1) + [0.9999]]
model_post_lrs = candidate_lrs[share_interm_net]
model_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]
poi_post_lrs = candidate_lrs[share_interm_net]
poi_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]
goal_post_lrs = candidate_lrs[share_interm_net]
goal_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]

use_NFs = False
n_mixture = 8
activate = nn.ReLU

log_every = 100
folder = parent_dir + f'experiments/source_{len(n_pois)}model_{model_weight}modelw_{poi_weight}poiw_{goal_weight}goalw_{n_stage}stage_{n_incre}incre_GMM/'
try:
    os.remove(folder + 'progress.csv')
except:
    pass
try:
    os.remove(folder + 'progress.txt')
except:
    pass
try:
    dowel.logger.remove_all()
except:
    pass
dowel.logger.add_output(dowel.StdOutput())
dowel.logger.add_output(dowel.CsvOutput(folder + 'progress.csv'))
dowel.logger.add_output(dowel.TextOutput(folder + 'progress.txt'))

try:
    for _ in range(100):
        dowel.logger.pop_prefix()
except:
    pass
dowel.logger.push_prefix('[SOURCE] ')
dowel.logger.log('Stored at ' + folder)
dowel.logger.log('Random seed:  ' + str(random_state))
dowel.logger.log('Device: ' + str(device))
dowel.logger.log('dtype: ' + str(dtype))

post_approx_params = {
    'n_stage': n_stage, 
    'n_design': n_design, 
    'n_obs': n_obs, 
    'n_pois': n_pois,
    'n_nuisps': n_nuisps,
    'n_goals': n_goals,
    'model_weight': model_weight,
    'poi_weight': poi_weight,
    'goal_weight': goal_weight,
    'mu_bounds': mu_bounds,
    'max_sigmas': max_sigmas,
    'truncnorm_info': truncnorm_info,
    'n_mixture': n_mixture,
    'activate': activate,
    'prior': prior,
    'n_incre': n_incre,
    'share_interm_net': share_interm_net,
    'model_post_lrs': model_post_lrs,
    'model_post_lr_scheduler_gammas': model_post_lr_scheduler_gammas,
    'poi_post_lrs': poi_post_lrs,
    'poi_post_lr_scheduler_gammas': poi_post_lr_scheduler_gammas,
    'goal_post_lrs': goal_post_lrs,
    'goal_post_lr_scheduler_gammas': goal_post_lr_scheduler_gammas,
    'use_NFs': use_NFs,
    'log_every': log_every,
    'dowel': dowel}

dowel.logger.log('Post_approx_params: ' + str(post_approx_params))

dowel.logger.dump_all()
# dowel.logger.remove_all()

post_approx = POST_APPROX(**post_approx_params)
dowel.logger.dump_all()
# Out:
# 2023-05-02 13:53:57 | [SOURCE] Stored at /scratch/xhuan_root/xhuan1/wgshen/vsOED/experiments/source_1model_0modelw_0poiw_1goalw_10stage_1incre_GMM/
# 2023-05-02 13:53:57 | [SOURCE] Random seed:  48563549
# 2023-05-02 13:53:57 | [SOURCE] Device: cuda:0
# 2023-05-02 13:53:57 | [SOURCE] dtype: torch.float32
# 2023-05-02 13:53:57 | [SOURCE] Post_approx_params: {'n_stage': 10, 'n_design': 2, 'n_obs': 1, 'n_pois': [4], 'n_nuisps': None, 'n_goals': [1], 'model_weight': 0, 'poi_weight': 0, 'goal_weight': 1, 'mu_bounds': {'poi': [[[-6, 6], [-6, 6], [-6, 6], [-6, 6]]], 'goal': [[[-6, 6]]]}, 'max_sigmas': {'poi': [[1.0, 1.0, 1.0, 1.0]], 'goal': [[2.0]]}, 'truncnorm_info': {'poi': [None], 'goal': [None]}, 'n_mixture': 8, 'activate': <class 'torch.nn.modules.activation.ReLU'>, 'prior': <vsOED.models.SOURCE object at 0x14dfb851c7f0>, 'n_incre': 1, 'share_interm_net': False, 'model_post_lrs': [0.001], 'model_post_lr_scheduler_gammas': [0.9999], 'poi_post_lrs': [0.001], 'poi_post_lr_scheduler_gammas': [0.9999], 'goal_post_lrs': [0.001], 'goal_post_lr_scheduler_gammas': [0.9999], 'use_NFs': False, 'log_every': 100, 'dowel': <module 'dowel' from '/home/wgshen/.local/lib/python3.9/site-packages/dowel/__init__.py'>}
# 2023-05-02 13:53:57 | [SOURCE] Learn the posterior approximator at stages: [9]

# %%
n_param = len(n_pois) > 1
try:
    n_param += max(n_pois)
except:
    pass
try:
    n_param += max(n_nuisps)
except:
    pass
try:
    n_param += max(n_goals)
except:
    pass

design_bounds = [(-4, 4), (-4, 4)] # lower and upper bounds of design variables.
def reward_fun(*args, **kws):
    return 0
nkld_reward_fun = model.reward_fun
kld_reward_fun = post_approx.reward_fun
phys_state_info = None
post_approx = post_approx
encoder_dimns = None
backend_dimns = None
actor_dimns = [256, 256, 256]
critic_dimns = [256, 256, 256]

vsoed_params = {
    'n_stage': n_stage,
    'n_param': n_param,
    'n_design': n_design,
    'n_obs': n_obs,
    'model': model,
    'prior': prior,
    'design_bounds': design_bounds,
    'nkld_reward_fun': nkld_reward_fun,
    'kld_reward_fun': kld_reward_fun,
    'phys_state_info': phys_state_info,
    'post_approx': post_approx,
    'encoder_dimns': encoder_dimns,
    'backend_dimns': backend_dimns,
    'actor_dimns': actor_dimns,
    'critic_dimns': critic_dimns,
    'activate': activate
}
dowel.logger.log('vsoed_params: ' + str(vsoed_params))

vsoed = PGvsOED(**vsoed_params)
# Out:
# 2023-05-02 13:53:59 | [SOURCE] vsoed_params: {'n_stage': 10, 'n_param': 5, 'n_design': 2, 'n_obs': 1, 'model': <vsOED.models.SOURCE object at 0x14dfb851c7f0>, 'prior': <vsOED.models.SOURCE object at 0x14dfb851c7f0>, 'design_bounds': [(-4, 4), (-4, 4)], 'nkld_reward_fun': <bound method SOURCE.reward_fun of <vsOED.models.SOURCE object at 0x14dfb851c7f0>>, 'kld_reward_fun': <bound method POST_APPROX.reward_fun of <vsOED.post_approx.POST_APPROX object at 0x14de61c31b80>>, 'phys_state_info': None, 'post_approx': <vsOED.post_approx.POST_APPROX object at 0x14de61c31b80>, 'encoder_dimns': None, 'backend_dimns': None, 'actor_dimns': [256, 256, 256], 'critic_dimns': [256, 256, 256], 'activate': <class 'torch.nn.modules.activation.ReLU'>}

# %%
actor_lr = 1e-3
actor_lr_scheduler_gamma = 0.9999
critic_lr = 1e-3
critic_lr_scheduler_gamma = 0.9999
    
n_update = 10001
n_newtraj = 1000
n_batch = 10000
n_buffer_init = n_batch * 2
n_buffer_max = int(1e6)
buffer_device = torch.device('cuda')
discount = 1 if n_incre == 1 else 0.9
encoder_actor_optimizer = None
encoder_actor_lr_scheduler = None
encoder_critic_optimizer = None
encoder_critic_lr_scheduler = None
actor_optimizer = optim.Adam(vsoed.actor_net.parameters(), lr=actor_lr)
actor_lr_scheduler = optim.lr_scheduler.ExponentialLR(actor_optimizer, gamma=actor_lr_scheduler_gamma)
n_critic_update = 5
critic_optimizer = optim.Adam(vsoed.critic_net.parameters(), lr=critic_lr)
critic_lr_scheduler = optim.lr_scheduler.ExponentialLR(critic_optimizer, gamma=critic_lr_scheduler_gamma)
n_post_approx_update = 5
lr_target = 0.1
design_noise_scale = 0.5
design_noise_decay = 0.9999
on_policy = False
use_PCE = False
use_PCE_incre = None
n_contrastive_sample = None
transition = 10000 if n_incre == 1 else 0
frozen = -1
log_every = 100
save_every = 1000
save_path = folder
restart = False

vsoed_train_params = {
    'n_update': n_update,
    'n_newtraj': n_newtraj,
    'n_batch': n_batch,
    'n_buffer_init': n_buffer_init,
    'n_buffer_max': n_buffer_max,
    'buffer_device': buffer_device,
    'discount': discount,
    'encoder_actor_optimizer': encoder_actor_optimizer,
    'encoder_actor_lr_scheduler': encoder_actor_lr_scheduler,
    'encoder_critic_optimizer': encoder_critic_optimizer,
    'encoder_critic_lr_scheduler': encoder_critic_lr_scheduler,
    'actor_lr': actor_lr,
    'actor_optimizer': actor_optimizer,
    'actor_lr_scheduler_gamma': actor_lr_scheduler_gamma, 
    'actor_lr_scheduler': actor_lr_scheduler,
    'n_critic_update': n_critic_update,
    'critic_lr': critic_lr,
    'critic_optimizer': critic_optimizer,
    'critic_lr_scheduler_gamma': critic_lr_scheduler_gamma,
    'critic_lr_scheduler': critic_lr_scheduler,
    'n_post_approx_update': n_post_approx_update,
    'lr_target': lr_target,
    'design_noise_scale': design_noise_scale,
    'design_noise_decay': design_noise_decay,
    'on_policy': on_policy,
    'use_PCE': use_PCE,
    'use_PCE_incre': use_PCE_incre,
    'n_contrastive_sample': n_contrastive_sample,
    'transition': transition,
    'frozen': frozen,
    'log_every': log_every,
    'dowel': dowel,
    'save_every': save_every,
    'save_path': save_path,
    'restart': restart
}

dowel.logger.log('vsoed_train_params: ' + str(vsoed_train_params))

del vsoed_train_params['actor_lr']
del vsoed_train_params['actor_lr_scheduler_gamma']
del vsoed_train_params['critic_lr']
del vsoed_train_params['critic_lr_scheduler_gamma']
# Out:
# 2023-05-02 13:53:59 | [SOURCE] vsoed_train_params: {'n_update': 10001, 'n_newtraj': 1000, 'n_batch': 10000, 'n_buffer_init': 20000, 'n_buffer_max': 1000000, 'buffer_device': device(type='cuda'), 'discount': 1, 'encoder_actor_optimizer': None, 'encoder_actor_lr_scheduler': None, 'encoder_critic_optimizer': None, 'encoder_critic_lr_scheduler': None, 'actor_lr': 0.001, 'actor_optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# ), 'actor_lr_scheduler_gamma': 0.9999, 'actor_lr_scheduler': <torch.optim.lr_scheduler.ExponentialLR object at 0x14dfb851c910>, 'n_critic_update': 5, 'critic_lr': 0.001, 'critic_optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# ), 'critic_lr_scheduler_gamma': 0.9999, 'critic_lr_scheduler': <torch.optim.lr_scheduler.ExponentialLR object at 0x14dfb851c5e0>, 'n_post_approx_update': 5, 'lr_target': 0.1, 'design_noise_scale': 0.5, 'design_noise_decay': 0.9999, 'on_policy': False, 'use_PCE': False, 'use_PCE_incre': None, 'n_contrastive_sample': None, 'transition': 10000, 'frozen': -1, 'log_every': 100, 'dowel': <module 'dowel' from '/home/wgshen/.local/lib/python3.9/site-packages/dowel/__init__.py'>, 'save_every': 1000, 'save_path': '/scratch/xhuan_root/xhuan1/wgshen/vsOED/experiments/source_1model_0modelw_0poiw_1goalw_10stage_1incre_GMM/', 'restart': False}

# %%
try:
    for _ in range(100):
        dowel.logger.pop_prefix()
except:
    pass
dowel.logger.push_prefix('[SOURCE] ')
vsoed.train(**vsoed_train_params)
# Out:
# 2023-05-01 19:03:51 | [SOURCE] epoch #0 | log goal post after training: -1.3514407873153687
# 2023-05-01 19:03:51 | [SOURCE] epoch #0 | Checkpoint saved
# 2023-05-01 19:03:51 | [SOURCE] epoch #0 | Total time 0.71 s
# 2023-05-01 19:03:51 | [SOURCE] epoch #0 | Epoch time 0.27 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.007706584874540567, -0.07174549996852875]
# Design/StdDesign          [0.030495809391140938, 0.02783171832561493]
# Epoch                     0
# ReplayBuffer/buffer_size  20000
# Reward/MeanReward         -2.400022029876709
# Reward/StdReward          0.41758865118026733
# ------------------------  --------------------------------------------
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Epoch: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Reward/MeanReward: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Reward/StdReward: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Design/MeanDesign: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {Design/StdDesign: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# /scratch/xhuan_root/xhuan1/wgshen/vsOED/vsOED/pg_vsoed.py:721: TabularInputWarning: TabularInput {ReplayBuffer/buffer_size: type(str)} was not accepted by any output
#   self.dowel.tabular.clear()
# 2023-05-01 19:04:08 | [SOURCE] epoch #100 | log goal post after training: 0.4429730474948883
# 2023-05-01 19:04:08 | [SOURCE] epoch #100 | Total time 17.69 s
# 2023-05-01 19:04:08 | [SOURCE] epoch #100 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [2.8192780017852783, -0.24101801216602325]
# Design/StdDesign          [1.7548847198486328, 0.9285467863082886]
# Epoch                     100
# ReplayBuffer/buffer_size  120000
# Reward/MeanReward         0.5344221591949463
# Reward/StdReward          0.7956714630126953
# ------------------------  ------------------------------------------
# 2023-05-01 19:04:25 | [SOURCE] epoch #200 | log goal post after training: 0.6093782186508179
# 2023-05-01 19:04:25 | [SOURCE] epoch #200 | Total time 34.64 s
# 2023-05-01 19:04:25 | [SOURCE] epoch #200 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [2.3432023525238037, -0.18994690477848053]
# Design/StdDesign          [1.470093011856079, 0.9715724587440491]
# Epoch                     200
# ReplayBuffer/buffer_size  220000
# Reward/MeanReward         0.5861539840698242
# Reward/StdReward          0.8578846454620361
# ------------------------  ------------------------------------------
# 2023-05-01 19:04:42 | [SOURCE] epoch #300 | log goal post after training: 0.6652811169624329
# 2023-05-01 19:04:42 | [SOURCE] epoch #300 | Total time 51.58 s
# 2023-05-01 19:04:42 | [SOURCE] epoch #300 | Epoch time 0.17 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [2.30678653717041, -0.161645770072937]
# Design/StdDesign          [1.1570618152618408, 0.9635607004165649]
# Epoch                     300
# ReplayBuffer/buffer_size  320000
# Reward/MeanReward         0.681244432926178
# Reward/StdReward          0.9376254081726074
# ------------------------  ----------------------------------------
# 2023-05-01 19:04:59 | [SOURCE] epoch #400 | log goal post after training: 0.7143951058387756
# 2023-05-01 19:04:59 | [SOURCE] epoch #400 | Total time 68.52 s
# 2023-05-01 19:04:59 | [SOURCE] epoch #400 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.820077657699585, -0.07095444202423096]
# Design/StdDesign          [1.4443309307098389, 1.055156946182251]
# Epoch                     400
# ReplayBuffer/buffer_size  420000
# Reward/MeanReward         0.770764172077179
# Reward/StdReward          0.8306967616081238
# ------------------------  -----------------------------------------
# 2023-05-01 19:05:16 | [SOURCE] epoch #500 | log goal post after training: 0.7829513549804688
# 2023-05-01 19:05:16 | [SOURCE] epoch #500 | Total time 85.46 s
# 2023-05-01 19:05:16 | [SOURCE] epoch #500 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.7021527290344238, -0.1249084323644638]
# Design/StdDesign          [1.204235553741455, 1.02729332447052]
# Epoch                     500
# ReplayBuffer/buffer_size  520000
# Reward/MeanReward         0.7610050439834595
# Reward/StdReward          1.0571153163909912
# ------------------------  -----------------------------------------
# 2023-05-01 19:05:33 | [SOURCE] epoch #600 | log goal post after training: 0.7750271558761597
# 2023-05-01 19:05:33 | [SOURCE] epoch #600 | Total time 102.43 s
# 2023-05-01 19:05:33 | [SOURCE] epoch #600 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.7225143909454346, -0.06052255630493164]
# Design/StdDesign          [1.299302339553833, 1.0763638019561768]
# Epoch                     600
# ReplayBuffer/buffer_size  620000
# Reward/MeanReward         0.7930101752281189
# Reward/StdReward          1.0369524955749512
# ------------------------  ------------------------------------------
# 2023-05-01 19:05:50 | [SOURCE] epoch #700 | log goal post after training: 0.8603038787841797
# 2023-05-01 19:05:50 | [SOURCE] epoch #700 | Total time 119.39 s
# 2023-05-01 19:05:50 | [SOURCE] epoch #700 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.6801947355270386, -0.030064012855291367]
# Design/StdDesign          [1.2183876037597656, 1.241357445716858]
# Epoch                     700
# ReplayBuffer/buffer_size  720000
# Reward/MeanReward         0.8558258414268494
# Reward/StdReward          0.9452509880065918
# ------------------------  -------------------------------------------
# 2023-05-01 19:06:07 | [SOURCE] epoch #800 | log goal post after training: 0.8634093403816223
# 2023-05-01 19:06:07 | [SOURCE] epoch #800 | Total time 136.34 s
# 2023-05-01 19:06:07 | [SOURCE] epoch #800 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.6092854738235474, 0.06874562799930573]
# Design/StdDesign          [1.2093697786331177, 1.040651798248291]
# Epoch                     800
# ReplayBuffer/buffer_size  820000
# Reward/MeanReward         0.8387359976768494
# Reward/StdReward          0.9500377774238586
# ------------------------  -----------------------------------------
# 2023-05-01 19:06:24 | [SOURCE] epoch #900 | log goal post after training: 0.8884814381599426
# 2023-05-01 19:06:24 | [SOURCE] epoch #900 | Total time 153.31 s
# 2023-05-01 19:06:24 | [SOURCE] epoch #900 | Epoch time 0.17 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [1.783515214920044, 0.14510126411914825]
# Design/StdDesign          [1.0087394714355469, 1.066738247871399]
# Epoch                     900
# ReplayBuffer/buffer_size  920000
# Reward/MeanReward         0.8811322450637817
# Reward/StdReward          1.056944727897644
# ------------------------  ----------------------------------------
# 2023-05-01 19:06:41 | [SOURCE] epoch #1000 | log goal post after training: 0.9267521500587463
# 2023-05-01 19:06:41 | [SOURCE] epoch #1000 | Checkpoint saved
# 2023-05-01 19:06:41 | [SOURCE] epoch #1000 | Total time 170.38 s
# 2023-05-01 19:06:41 | [SOURCE] epoch #1000 | Epoch time 0.29 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.8762247562408447, 0.11276591569185257]
# Design/StdDesign          [0.9857194423675537, 1.113024353981018]
# Epoch                     1000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9867351651191711
# Reward/StdReward          0.8827759027481079
# ------------------------  -----------------------------------------
# 2023-05-01 19:06:58 | [SOURCE] epoch #1100 | log goal post after training: 0.9396030902862549
# 2023-05-01 19:06:58 | [SOURCE] epoch #1100 | Total time 187.32 s
# 2023-05-01 19:06:58 | [SOURCE] epoch #1100 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.7863332033157349, 0.14683154225349426]
# Design/StdDesign          [1.0498100519180298, 1.1994632482528687]
# Epoch                     1100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9147805571556091
# Reward/StdReward          1.0135325193405151
# ------------------------  -----------------------------------------
# 2023-05-01 19:07:15 | [SOURCE] epoch #1200 | log goal post after training: 0.9597424268722534
# 2023-05-01 19:07:15 | [SOURCE] epoch #1200 | Total time 204.25 s
# 2023-05-01 19:07:15 | [SOURCE] epoch #1200 | Epoch time 0.17 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [1.7651175260543823, 0.2577219009399414]
# Design/StdDesign          [1.0106159448623657, 1.101245641708374]
# Epoch                     1200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9728099703788757
# Reward/StdReward          0.8898516893386841
# ------------------------  ----------------------------------------
# 2023-05-01 19:07:32 | [SOURCE] epoch #1300 | log goal post after training: 0.9950072169303894
# 2023-05-01 19:07:32 | [SOURCE] epoch #1300 | Total time 221.20 s
# 2023-05-01 19:07:32 | [SOURCE] epoch #1300 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.4121429920196533, 0.16981950402259827]
# Design/StdDesign          [1.0912376642227173, 1.1177024841308594]
# Epoch                     1300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.8839505314826965
# Reward/StdReward          1.125558614730835
# ------------------------  -----------------------------------------
# 2023-05-01 19:07:49 | [SOURCE] epoch #1400 | log goal post after training: 1.010466456413269
# 2023-05-01 19:07:49 | [SOURCE] epoch #1400 | Total time 238.16 s
# 2023-05-01 19:07:49 | [SOURCE] epoch #1400 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.5535069704055786, 0.06077241152524948]
# Design/StdDesign          [1.1180098056793213, 1.1525094509124756]
# Epoch                     1400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0001299381256104
# Reward/StdReward          0.8104158043861389
# ------------------------  -----------------------------------------
# 2023-05-01 19:08:06 | [SOURCE] epoch #1500 | log goal post after training: 1.0074383020401
# 2023-05-01 19:08:06 | [SOURCE] epoch #1500 | Total time 255.13 s
# 2023-05-01 19:08:06 | [SOURCE] epoch #1500 | Epoch time 0.17 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [1.472301959991455, 0.07138973474502563]
# Design/StdDesign          [1.095880389213562, 1.1210596561431885]
# Epoch                     1500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9104657173156738
# Reward/StdReward          1.0775012969970703
# ------------------------  ----------------------------------------
# 2023-05-01 19:08:23 | [SOURCE] epoch #1600 | log goal post after training: 1.0079847574234009
# 2023-05-01 19:08:23 | [SOURCE] epoch #1600 | Total time 272.12 s
# 2023-05-01 19:08:23 | [SOURCE] epoch #1600 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.3222469091415405, -0.051078829914331436]
# Design/StdDesign          [1.0206468105316162, 1.1787511110305786]
# Epoch                     1600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9827011227607727
# Reward/StdReward          0.9526733756065369
# ------------------------  -------------------------------------------
# 2023-05-01 19:08:40 | [SOURCE] epoch #1700 | log goal post after training: 1.0306336879730225
# 2023-05-01 19:08:40 | [SOURCE] epoch #1700 | Total time 289.10 s
# 2023-05-01 19:08:40 | [SOURCE] epoch #1700 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.4990688562393188, 0.08444355428218842]
# Design/StdDesign          [0.9521077871322632, 1.1946686506271362]
# Epoch                     1700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9849674701690674
# Reward/StdReward          1.0382869243621826
# ------------------------  -----------------------------------------
# 2023-05-01 19:08:57 | [SOURCE] epoch #1800 | log goal post after training: 1.0499744415283203
# 2023-05-01 19:08:57 | [SOURCE] epoch #1800 | Total time 306.05 s
# 2023-05-01 19:08:57 | [SOURCE] epoch #1800 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.4725265502929688, 0.037782687693834305]
# Design/StdDesign          [1.073766827583313, 1.1838833093643188]
# Epoch                     1800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0483819246292114
# Reward/StdReward          0.9342235326766968
# ------------------------  ------------------------------------------
# 2023-05-01 19:09:14 | [SOURCE] epoch #1900 | log goal post after training: 1.0565166473388672
# 2023-05-01 19:09:14 | [SOURCE] epoch #1900 | Total time 323.01 s
# 2023-05-01 19:09:14 | [SOURCE] epoch #1900 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.367034912109375, -0.0035484861582517624]
# Design/StdDesign          [0.9691242575645447, 1.0670493841171265]
# Epoch                     1900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9499382376670837
# Reward/StdReward          1.176225185394287
# ------------------------  -------------------------------------------
# 2023-05-01 19:09:31 | [SOURCE] epoch #2000 | log goal post after training: 1.0432595014572144
# 2023-05-01 19:09:31 | [SOURCE] epoch #2000 | Checkpoint saved
# 2023-05-01 19:09:31 | [SOURCE] epoch #2000 | Total time 340.13 s
# 2023-05-01 19:09:31 | [SOURCE] epoch #2000 | Epoch time 0.33 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.5298672914505005, 0.037489697337150574]
# Design/StdDesign          [1.006860375404358, 1.174649953842163]
# Epoch                     2000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0000745058059692
# Reward/StdReward          0.9723895192146301
# ------------------------  ------------------------------------------
# 2023-05-01 19:09:48 | [SOURCE] epoch #2100 | log goal post after training: 1.0607788562774658
# 2023-05-01 19:09:48 | [SOURCE] epoch #2100 | Total time 357.07 s
# 2023-05-01 19:09:48 | [SOURCE] epoch #2100 | Epoch time 0.17 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [1.331968903541565, 0.10093434900045395]
# Design/StdDesign          [1.1275421380996704, 1.2057002782821655]
# Epoch                     2100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0652120113372803
# Reward/StdReward          0.8593928217887878
# ------------------------  ----------------------------------------
# 2023-05-01 19:10:05 | [SOURCE] epoch #2200 | log goal post after training: 1.0520154237747192
# 2023-05-01 19:10:05 | [SOURCE] epoch #2200 | Total time 374.02 s
# 2023-05-01 19:10:05 | [SOURCE] epoch #2200 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.4774068593978882, -0.014425146393477917]
# Design/StdDesign          [1.0287566184997559, 1.2506358623504639]
# Epoch                     2200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9613675475120544
# Reward/StdReward          1.0289853811264038
# ------------------------  -------------------------------------------
# 2023-05-01 19:10:22 | [SOURCE] epoch #2300 | log goal post after training: 1.0710132122039795
# 2023-05-01 19:10:22 | [SOURCE] epoch #2300 | Total time 390.99 s
# 2023-05-01 19:10:22 | [SOURCE] epoch #2300 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.5801429748535156, 0.10025141388177872]
# Design/StdDesign          [0.8100729584693909, 1.1960875988006592]
# Epoch                     2300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0447278022766113
# Reward/StdReward          0.9277669191360474
# ------------------------  -----------------------------------------
# 2023-05-01 19:10:39 | [SOURCE] epoch #2400 | log goal post after training: 1.0720741748809814
# 2023-05-01 19:10:39 | [SOURCE] epoch #2400 | Total time 407.96 s
# 2023-05-01 19:10:39 | [SOURCE] epoch #2400 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.4663783311843872, 0.18677838146686554]
# Design/StdDesign          [1.0143619775772095, 1.0845990180969238]
# Epoch                     2400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9855427742004395
# Reward/StdReward          1.0309795141220093
# ------------------------  -----------------------------------------
# 2023-05-01 19:10:56 | [SOURCE] epoch #2500 | log goal post after training: 1.0732262134552002
# 2023-05-01 19:10:56 | [SOURCE] epoch #2500 | Total time 424.93 s
# 2023-05-01 19:10:56 | [SOURCE] epoch #2500 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.4414790868759155, 0.043187327682971954]
# Design/StdDesign          [0.958090603351593, 1.1323139667510986]
# Epoch                     2500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0305161476135254
# Reward/StdReward          1.0020790100097656
# ------------------------  ------------------------------------------
# 2023-05-01 19:11:13 | [SOURCE] epoch #2600 | log goal post after training: 1.0738366842269897
# 2023-05-01 19:11:13 | [SOURCE] epoch #2600 | Total time 441.89 s
# 2023-05-01 19:11:13 | [SOURCE] epoch #2600 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.5560939311981201, 0.02178950048983097]
# Design/StdDesign          [0.9590649008750916, 1.1374146938323975]
# Epoch                     2600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0156086683273315
# Reward/StdReward          1.0408360958099365
# ------------------------  -----------------------------------------
# 2023-05-01 19:11:29 | [SOURCE] epoch #2700 | log goal post after training: 1.0913621187210083
# 2023-05-01 19:11:30 | [SOURCE] epoch #2700 | Total time 458.85 s
# 2023-05-01 19:11:30 | [SOURCE] epoch #2700 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.536708950996399, 0.00021665038366336375]
# Design/StdDesign          [0.9639025330543518, 1.1345535516738892]
# Epoch                     2700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.034456729888916
# Reward/StdReward          0.9906004667282104
# ------------------------  -------------------------------------------
# 2023-05-01 19:11:46 | [SOURCE] epoch #2800 | log goal post after training: 1.0781893730163574
# 2023-05-01 19:11:47 | [SOURCE] epoch #2800 | Total time 475.81 s
# 2023-05-01 19:11:47 | [SOURCE] epoch #2800 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.4136542081832886, 0.026580004021525383]
# Design/StdDesign          [0.9533427357673645, 1.1248537302017212]
# Epoch                     2800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0154473781585693
# Reward/StdReward          1.0439348220825195
# ------------------------  ------------------------------------------
# 2023-05-01 19:12:03 | [SOURCE] epoch #2900 | log goal post after training: 1.0853238105773926
# 2023-05-01 19:12:04 | [SOURCE] epoch #2900 | Total time 492.77 s
# 2023-05-01 19:12:04 | [SOURCE] epoch #2900 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.4005323648452759, -0.029442382976412773]
# Design/StdDesign          [0.9113842248916626, 1.1343340873718262]
# Epoch                     2900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.044617772102356
# Reward/StdReward          0.9326022267341614
# ------------------------  -------------------------------------------
# 2023-05-01 19:12:20 | [SOURCE] epoch #3000 | log goal post after training: 1.0998461246490479
# 2023-05-01 19:12:21 | [SOURCE] epoch #3000 | Checkpoint saved
# 2023-05-01 19:12:21 | [SOURCE] epoch #3000 | Total time 509.83 s
# 2023-05-01 19:12:21 | [SOURCE] epoch #3000 | Epoch time 0.28 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [1.41948664188385, 0.025715501978993416]
# Design/StdDesign          [1.01438307762146, 1.1353384256362915]
# Epoch                     3000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9930154085159302
# Reward/StdReward          1.0214524269104004
# ------------------------  ----------------------------------------
# 2023-05-01 19:12:37 | [SOURCE] epoch #3100 | log goal post after training: 1.0923001766204834
# 2023-05-01 19:12:38 | [SOURCE] epoch #3100 | Total time 526.78 s
# 2023-05-01 19:12:38 | [SOURCE] epoch #3100 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.4006943702697754, -0.01920524798333645]
# Design/StdDesign          [0.9311277866363525, 1.166067361831665]
# Epoch                     3100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0553606748580933
# Reward/StdReward          0.9469326138496399
# ------------------------  ------------------------------------------
# 2023-05-01 19:12:54 | [SOURCE] epoch #3200 | log goal post after training: 1.0889990329742432
# 2023-05-01 19:12:54 | [SOURCE] epoch #3200 | Total time 543.76 s
# 2023-05-01 19:12:54 | [SOURCE] epoch #3200 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.4055914878845215, 0.013015136122703552]
# Design/StdDesign          [0.8328810334205627, 1.1568907499313354]
# Epoch                     3200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0845686197280884
# Reward/StdReward          1.0163824558258057
# ------------------------  ------------------------------------------
# 2023-05-01 19:13:11 | [SOURCE] epoch #3300 | log goal post after training: 1.092340350151062
# 2023-05-01 19:13:11 | [SOURCE] epoch #3300 | Total time 560.71 s
# 2023-05-01 19:13:11 | [SOURCE] epoch #3300 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.2369663715362549, 0.06494706869125366]
# Design/StdDesign          [1.0387799739837646, 1.1077218055725098]
# Epoch                     3300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0071253776550293
# Reward/StdReward          1.035786509513855
# ------------------------  -----------------------------------------
# 2023-05-01 19:13:28 | [SOURCE] epoch #3400 | log goal post after training: 1.1080855131149292
# 2023-05-01 19:13:28 | [SOURCE] epoch #3400 | Total time 577.67 s
# 2023-05-01 19:13:28 | [SOURCE] epoch #3400 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.1738697290420532, 0.04246355965733528]
# Design/StdDesign          [1.0222264528274536, 1.077130913734436]
# Epoch                     3400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0064011812210083
# Reward/StdReward          1.0637916326522827
# ------------------------  -----------------------------------------
# 2023-05-01 19:13:45 | [SOURCE] epoch #3500 | log goal post after training: 1.1055513620376587
# 2023-05-01 19:13:45 | [SOURCE] epoch #3500 | Total time 594.65 s
# 2023-05-01 19:13:45 | [SOURCE] epoch #3500 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.3160122632980347, 0.06064740940928459]
# Design/StdDesign          [1.0386804342269897, 1.1896262168884277]
# Epoch                     3500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0387837886810303
# Reward/StdReward          1.007785439491272
# ------------------------  -----------------------------------------
# 2023-05-01 19:14:02 | [SOURCE] epoch #3600 | log goal post after training: 1.089484691619873
# 2023-05-01 19:14:02 | [SOURCE] epoch #3600 | Total time 611.61 s
# 2023-05-01 19:14:02 | [SOURCE] epoch #3600 | Epoch time 0.17 s
# ------------------------  ---------------------------------------
# Design/MeanDesign         [1.042964220046997, 0.2204320728778839]
# Design/StdDesign          [1.1732338666915894, 1.126494288444519]
# Epoch                     3600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9757876992225647
# Reward/StdReward          1.0985432863235474
# ------------------------  ---------------------------------------
# 2023-05-01 19:14:19 | [SOURCE] epoch #3700 | log goal post after training: 1.1084046363830566
# 2023-05-01 19:14:19 | [SOURCE] epoch #3700 | Total time 628.58 s
# 2023-05-01 19:14:19 | [SOURCE] epoch #3700 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.4568086862564087, -0.05153732746839523]
# Design/StdDesign          [1.0235527753829956, 1.1808865070343018]
# Epoch                     3700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.09598708152771
# Reward/StdReward          0.8427858352661133
# ------------------------  ------------------------------------------
# 2023-05-01 19:14:36 | [SOURCE] epoch #3800 | log goal post after training: 1.1049360036849976
# 2023-05-01 19:14:36 | [SOURCE] epoch #3800 | Total time 645.55 s
# 2023-05-01 19:14:36 | [SOURCE] epoch #3800 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.2428535223007202, 0.03094504401087761]
# Design/StdDesign          [1.021236777305603, 1.0952552556991577]
# Epoch                     3800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9944394826889038
# Reward/StdReward          1.1165990829467773
# ------------------------  -----------------------------------------
# 2023-05-01 19:14:53 | [SOURCE] epoch #3900 | log goal post after training: 1.104691982269287
# 2023-05-01 19:14:53 | [SOURCE] epoch #3900 | Total time 662.52 s
# 2023-05-01 19:14:53 | [SOURCE] epoch #3900 | Epoch time 0.17 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [1.313332200050354, 0.22019828855991364]
# Design/StdDesign          [1.1256723403930664, 1.114532470703125]
# Epoch                     3900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.99995356798172
# Reward/StdReward          0.9463284015655518
# ------------------------  ----------------------------------------
# 2023-05-01 19:15:10 | [SOURCE] epoch #4000 | log goal post after training: 1.11592435836792
# 2023-05-01 19:15:10 | [SOURCE] epoch #4000 | Checkpoint saved
# 2023-05-01 19:15:10 | [SOURCE] epoch #4000 | Total time 679.58 s
# 2023-05-01 19:15:10 | [SOURCE] epoch #4000 | Epoch time 0.25 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.1744282245635986, -0.04797675833106041]
# Design/StdDesign          [1.1090067625045776, 1.1821972131729126]
# Epoch                     4000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0086191892623901
# Reward/StdReward          0.9846228957176208
# ------------------------  ------------------------------------------
# 2023-05-01 19:15:27 | [SOURCE] epoch #4100 | log goal post after training: 1.1218008995056152
# 2023-05-01 19:15:27 | [SOURCE] epoch #4100 | Total time 696.56 s
# 2023-05-01 19:15:27 | [SOURCE] epoch #4100 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.206776738166809, 0.028243407607078552]
# Design/StdDesign          [1.1054229736328125, 1.1843249797821045]
# Epoch                     4100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0179009437561035
# Reward/StdReward          1.0718834400177002
# ------------------------  -----------------------------------------
# 2023-05-01 19:15:44 | [SOURCE] epoch #4200 | log goal post after training: 1.1099281311035156
# 2023-05-01 19:15:44 | [SOURCE] epoch #4200 | Total time 713.53 s
# 2023-05-01 19:15:44 | [SOURCE] epoch #4200 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.3490246534347534, -0.010577734559774399]
# Design/StdDesign          [1.1056522130966187, 1.1303377151489258]
# Epoch                     4200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0878826379776
# Reward/StdReward          0.938083291053772
# ------------------------  -------------------------------------------
# 2023-05-01 19:16:01 | [SOURCE] epoch #4300 | log goal post after training: 1.1326195001602173
# 2023-05-01 19:16:01 | [SOURCE] epoch #4300 | Total time 730.49 s
# 2023-05-01 19:16:01 | [SOURCE] epoch #4300 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.2407974004745483, 0.10072638839483261]
# Design/StdDesign          [1.06752347946167, 1.1513904333114624]
# Epoch                     4300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0672392845153809
# Reward/StdReward          1.061463475227356
# ------------------------  -----------------------------------------
# 2023-05-01 19:16:18 | [SOURCE] epoch #4400 | log goal post after training: 1.1129674911499023
# 2023-05-01 19:16:18 | [SOURCE] epoch #4400 | Total time 747.45 s
# 2023-05-01 19:16:18 | [SOURCE] epoch #4400 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.0599688291549683, -0.028731152415275574]
# Design/StdDesign          [1.195410966873169, 1.143268346786499]
# Epoch                     4400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.080414891242981
# Reward/StdReward          1.0065550804138184
# ------------------------  -------------------------------------------
# 2023-05-01 19:16:35 | [SOURCE] epoch #4500 | log goal post after training: 1.1259620189666748
# 2023-05-01 19:16:35 | [SOURCE] epoch #4500 | Total time 764.42 s
# 2023-05-01 19:16:35 | [SOURCE] epoch #4500 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.101401448249817, 0.041096337139606476]
# Design/StdDesign          [1.1113239526748657, 1.1485884189605713]
# Epoch                     4500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0513031482696533
# Reward/StdReward          1.0454659461975098
# ------------------------  -----------------------------------------
# 2023-05-01 19:16:52 | [SOURCE] epoch #4600 | log goal post after training: 1.1193972826004028
# 2023-05-01 19:16:52 | [SOURCE] epoch #4600 | Total time 781.45 s
# 2023-05-01 19:16:52 | [SOURCE] epoch #4600 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.2017844915390015, 0.07712531834840775]
# Design/StdDesign          [1.0971078872680664, 1.1284013986587524]
# Epoch                     4600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.025687575340271
# Reward/StdReward          1.0780621767044067
# ------------------------  -----------------------------------------
# 2023-05-01 19:17:09 | [SOURCE] epoch #4700 | log goal post after training: 1.1412806510925293
# 2023-05-01 19:17:09 | [SOURCE] epoch #4700 | Total time 798.42 s
# 2023-05-01 19:17:09 | [SOURCE] epoch #4700 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.1553542613983154, -0.05823056399822235]
# Design/StdDesign          [1.1101858615875244, 1.1317880153656006]
# Epoch                     4700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1007713079452515
# Reward/StdReward          0.9658114314079285
# ------------------------  ------------------------------------------
# 2023-05-01 19:17:26 | [SOURCE] epoch #4800 | log goal post after training: 1.1186250448226929
# 2023-05-01 19:17:26 | [SOURCE] epoch #4800 | Total time 815.40 s
# 2023-05-01 19:17:26 | [SOURCE] epoch #4800 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.152683138847351, -0.13670361042022705]
# Design/StdDesign          [1.2667315006256104, 1.1321860551834106]
# Epoch                     4800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0895721912384033
# Reward/StdReward          0.9466034173965454
# ------------------------  -----------------------------------------
# 2023-05-01 19:17:43 | [SOURCE] epoch #4900 | log goal post after training: 1.1255422830581665
# 2023-05-01 19:17:43 | [SOURCE] epoch #4900 | Total time 832.38 s
# 2023-05-01 19:17:43 | [SOURCE] epoch #4900 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.9983132481575012, -0.062330834567546844]
# Design/StdDesign          [1.3555575609207153, 1.190298080444336]
# Epoch                     4900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0790205001831055
# Reward/StdReward          1.0097191333770752
# ------------------------  -------------------------------------------
# 2023-05-01 19:18:00 | [SOURCE] epoch #5000 | log goal post after training: 1.1326234340667725
# 2023-05-01 19:18:00 | [SOURCE] epoch #5000 | Checkpoint saved
# 2023-05-01 19:18:00 | [SOURCE] epoch #5000 | Total time 849.44 s
# 2023-05-01 19:18:00 | [SOURCE] epoch #5000 | Epoch time 0.25 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.0140089988708496, 0.07705119252204895]
# Design/StdDesign          [1.098642110824585, 1.1539191007614136]
# Epoch                     5000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         0.9767267107963562
# Reward/StdReward          1.1924186944961548
# ------------------------  -----------------------------------------
# 2023-05-01 19:18:17 | [SOURCE] epoch #5100 | log goal post after training: 1.1426554918289185
# 2023-05-01 19:18:17 | [SOURCE] epoch #5100 | Total time 866.42 s
# 2023-05-01 19:18:17 | [SOURCE] epoch #5100 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.9126388430595398, -0.03784522786736488]
# Design/StdDesign          [1.3416883945465088, 1.1732314825057983]
# Epoch                     5100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.044368028640747
# Reward/StdReward          1.1667598485946655
# ------------------------  ------------------------------------------
# 2023-05-01 19:18:34 | [SOURCE] epoch #5200 | log goal post after training: 1.1426279544830322
# 2023-05-01 19:18:34 | [SOURCE] epoch #5200 | Total time 883.40 s
# 2023-05-01 19:18:34 | [SOURCE] epoch #5200 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.1627134084701538, 0.04426372051239014]
# Design/StdDesign          [1.2384345531463623, 1.2086458206176758]
# Epoch                     5200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.061420202255249
# Reward/StdReward          1.0423694849014282
# ------------------------  -----------------------------------------
# 2023-05-01 19:18:51 | [SOURCE] epoch #5300 | log goal post after training: 1.140239953994751
# 2023-05-01 19:18:51 | [SOURCE] epoch #5300 | Total time 900.39 s
# 2023-05-01 19:18:51 | [SOURCE] epoch #5300 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.114661455154419, 0.011357568204402924]
# Design/StdDesign          [1.1545217037200928, 1.1189601421356201]
# Epoch                     5300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.051351547241211
# Reward/StdReward          1.090917706489563
# ------------------------  -----------------------------------------
# 2023-05-01 19:19:08 | [SOURCE] epoch #5400 | log goal post after training: 1.1589053869247437
# 2023-05-01 19:19:08 | [SOURCE] epoch #5400 | Total time 917.39 s
# 2023-05-01 19:19:08 | [SOURCE] epoch #5400 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [1.1759830713272095, -0.049382444471120834]
# Design/StdDesign          [1.1742981672286987, 1.1502758264541626]
# Epoch                     5400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.075223445892334
# Reward/StdReward          1.0495657920837402
# ------------------------  -------------------------------------------
# 2023-05-01 19:19:25 | [SOURCE] epoch #5500 | log goal post after training: 1.1467533111572266
# 2023-05-01 19:19:25 | [SOURCE] epoch #5500 | Total time 934.38 s
# 2023-05-01 19:19:25 | [SOURCE] epoch #5500 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.969543993473053, -0.03987990692257881]
# Design/StdDesign          [1.3578039407730103, 1.1705398559570312]
# Epoch                     5500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0339760780334473
# Reward/StdReward          1.1190036535263062
# ------------------------  -----------------------------------------
# 2023-05-01 19:19:42 | [SOURCE] epoch #5600 | log goal post after training: 1.1391319036483765
# 2023-05-01 19:19:42 | [SOURCE] epoch #5600 | Total time 951.35 s
# 2023-05-01 19:19:42 | [SOURCE] epoch #5600 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.1250163316726685, -0.0544465072453022]
# Design/StdDesign          [1.2864913940429688, 1.0877186059951782]
# Epoch                     5600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1165093183517456
# Reward/StdReward          0.9815778732299805
# ------------------------  -----------------------------------------
# 2023-05-01 19:19:59 | [SOURCE] epoch #5700 | log goal post after training: 1.1807445287704468
# 2023-05-01 19:19:59 | [SOURCE] epoch #5700 | Total time 968.30 s
# 2023-05-01 19:19:59 | [SOURCE] epoch #5700 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [1.0585423707962036, -0.04377846419811249]
# Design/StdDesign          [1.2663836479187012, 1.1263314485549927]
# Epoch                     5700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0759320259094238
# Reward/StdReward          1.047783374786377
# ------------------------  ------------------------------------------
# 2023-05-01 19:20:16 | [SOURCE] epoch #5800 | log goal post after training: 1.1745617389678955
# 2023-05-01 19:20:16 | [SOURCE] epoch #5800 | Total time 985.25 s
# 2023-05-01 19:20:16 | [SOURCE] epoch #5800 | Epoch time 0.17 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [1.0374927520751953, -0.00042727048275992274]
# Design/StdDesign          [1.2410862445831299, 1.085903525352478]
# Epoch                     5800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0903371572494507
# Reward/StdReward          1.0346033573150635
# ------------------------  ---------------------------------------------
# 2023-05-01 19:20:33 | [SOURCE] epoch #5900 | log goal post after training: 1.1709657907485962
# 2023-05-01 19:20:33 | [SOURCE] epoch #5900 | Total time 1002.22 s
# 2023-05-01 19:20:33 | [SOURCE] epoch #5900 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.9496281147003174, -0.016399512067437172]
# Design/StdDesign          [1.2186142206192017, 1.0988712310791016]
# Epoch                     5900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.117235779762268
# Reward/StdReward          0.9764998555183411
# ------------------------  -------------------------------------------
# 2023-05-01 19:20:50 | [SOURCE] epoch #6000 | log goal post after training: 1.1512014865875244
# 2023-05-01 19:20:50 | [SOURCE] epoch #6000 | Checkpoint saved
# 2023-05-01 19:20:50 | [SOURCE] epoch #6000 | Total time 1019.27 s
# 2023-05-01 19:20:50 | [SOURCE] epoch #6000 | Epoch time 0.26 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.9852578043937683, 0.06741151958703995]
# Design/StdDesign          [1.2700140476226807, 1.047966480255127]
# Epoch                     6000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1488819122314453
# Reward/StdReward          1.0650253295898438
# ------------------------  -----------------------------------------
# 2023-05-01 19:21:07 | [SOURCE] epoch #6100 | log goal post after training: 1.1761384010314941
# 2023-05-01 19:21:07 | [SOURCE] epoch #6100 | Total time 1036.24 s
# 2023-05-01 19:21:07 | [SOURCE] epoch #6100 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [1.0265227556228638, 0.02269783802330494]
# Design/StdDesign          [1.3124351501464844, 1.070104718208313]
# Epoch                     6100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0287911891937256
# Reward/StdReward          1.2468347549438477
# ------------------------  -----------------------------------------
# 2023-05-01 19:21:24 | [SOURCE] epoch #6200 | log goal post after training: 1.1658804416656494
# 2023-05-01 19:21:24 | [SOURCE] epoch #6200 | Total time 1053.19 s
# 2023-05-01 19:21:24 | [SOURCE] epoch #6200 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.9497780203819275, 0.009603869169950485]
# Design/StdDesign          [1.393916368484497, 1.075913429260254]
# Epoch                     6200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.131192922592163
# Reward/StdReward          1.0059765577316284
# ------------------------  ------------------------------------------
# 2023-05-01 19:21:41 | [SOURCE] epoch #6300 | log goal post after training: 1.1935425996780396
# 2023-05-01 19:21:41 | [SOURCE] epoch #6300 | Total time 1070.16 s
# 2023-05-01 19:21:41 | [SOURCE] epoch #6300 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.9324089884757996, -0.07173550873994827]
# Design/StdDesign          [1.3075307607650757, 1.0857046842575073]
# Epoch                     6300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1376616954803467
# Reward/StdReward          1.0982555150985718
# ------------------------  ------------------------------------------
# 2023-05-01 19:21:58 | [SOURCE] epoch #6400 | log goal post after training: 1.1762226819992065
# 2023-05-01 19:21:58 | [SOURCE] epoch #6400 | Total time 1087.13 s
# 2023-05-01 19:21:58 | [SOURCE] epoch #6400 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.7603999376296997, 0.06394262611865997]
# Design/StdDesign          [1.4000022411346436, 1.0297081470489502]
# Epoch                     6400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0998766422271729
# Reward/StdReward          1.1275923252105713
# ------------------------  -----------------------------------------
# 2023-05-01 19:22:15 | [SOURCE] epoch #6500 | log goal post after training: 1.1863734722137451
# 2023-05-01 19:22:15 | [SOURCE] epoch #6500 | Total time 1104.12 s
# 2023-05-01 19:22:15 | [SOURCE] epoch #6500 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.8681454658508301, -0.011371825821697712]
# Design/StdDesign          [1.3325697183609009, 1.0224226713180542]
# Epoch                     6500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.0890460014343262
# Reward/StdReward          1.093491792678833
# ------------------------  -------------------------------------------
# 2023-05-01 19:22:32 | [SOURCE] epoch #6600 | log goal post after training: 1.204174518585205
# 2023-05-01 19:22:32 | [SOURCE] epoch #6600 | Total time 1121.08 s
# 2023-05-01 19:22:32 | [SOURCE] epoch #6600 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.8708593249320984, -0.09149394184350967]
# Design/StdDesign          [1.3850607872009277, 1.0889379978179932]
# Epoch                     6600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1434885263442993
# Reward/StdReward          1.0293809175491333
# ------------------------  ------------------------------------------
# 2023-05-01 19:22:49 | [SOURCE] epoch #6700 | log goal post after training: 1.1934499740600586
# 2023-05-01 19:22:49 | [SOURCE] epoch #6700 | Total time 1138.03 s
# 2023-05-01 19:22:49 | [SOURCE] epoch #6700 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.9147859215736389, -0.05737553536891937]
# Design/StdDesign          [1.3699195384979248, 1.023385763168335]
# Epoch                     6700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1378161907196045
# Reward/StdReward          1.0603089332580566
# ------------------------  ------------------------------------------
# 2023-05-01 19:23:06 | [SOURCE] epoch #6800 | log goal post after training: 1.2077261209487915
# 2023-05-01 19:23:06 | [SOURCE] epoch #6800 | Total time 1154.98 s
# 2023-05-01 19:23:06 | [SOURCE] epoch #6800 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.8525833487510681, 0.011342626996338367]
# Design/StdDesign          [1.4012213945388794, 1.0165244340896606]
# Epoch                     6800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1207826137542725
# Reward/StdReward          0.9587079882621765
# ------------------------  ------------------------------------------
# 2023-05-01 19:23:23 | [SOURCE] epoch #6900 | log goal post after training: 1.2083665132522583
# 2023-05-01 19:23:23 | [SOURCE] epoch #6900 | Total time 1171.93 s
# 2023-05-01 19:23:23 | [SOURCE] epoch #6900 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.8151662349700928, -0.032176148146390915]
# Design/StdDesign          [1.4631441831588745, 0.9831693172454834]
# Epoch                     6900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1437737941741943
# Reward/StdReward          1.0489511489868164
# ------------------------  -------------------------------------------
# 2023-05-01 19:23:40 | [SOURCE] epoch #7000 | log goal post after training: 1.208370566368103
# 2023-05-01 19:23:40 | [SOURCE] epoch #7000 | Checkpoint saved
# 2023-05-01 19:23:40 | [SOURCE] epoch #7000 | Total time 1189.02 s
# 2023-05-01 19:23:40 | [SOURCE] epoch #7000 | Epoch time 0.30 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7812467813491821, 0.017841577529907227]
# Design/StdDesign          [1.43677818775177, 1.0296757221221924]
# Epoch                     7000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1446329355239868
# Reward/StdReward          1.0620673894882202
# ------------------------  ------------------------------------------
# 2023-05-01 19:23:57 | [SOURCE] epoch #7100 | log goal post after training: 1.2196396589279175
# 2023-05-01 19:23:57 | [SOURCE] epoch #7100 | Total time 1205.97 s
# 2023-05-01 19:23:57 | [SOURCE] epoch #7100 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.8523705005645752, -0.07441286742687225]
# ...
# Reward/MeanReward         1.2101794481277466
# Reward/StdReward          0.9579657316207886
# ------------------------  ------------------------------------------
# 2023-05-01 19:25:38 | [SOURCE] epoch #7700 | log goal post after training: 1.2430977821350098
# 2023-05-01 19:25:39 | [SOURCE] epoch #7700 | Total time 1307.84 s
# 2023-05-01 19:25:39 | [SOURCE] epoch #7700 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.815193772315979, -0.03578538820147514]
# Design/StdDesign          [1.4462392330169678, 0.9720146656036377]
# Epoch                     7700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1700916290283203
# Reward/StdReward          1.1212413311004639
# ------------------------  -----------------------------------------
# 2023-05-01 19:25:55 | [SOURCE] epoch #7800 | log goal post after training: 1.2510859966278076
# 2023-05-01 19:25:56 | [SOURCE] epoch #7800 | Total time 1324.80 s
# 2023-05-01 19:25:56 | [SOURCE] epoch #7800 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.8404265642166138, -0.037089526653289795]
# Design/StdDesign          [1.3317855596542358, 1.001569151878357]
# Epoch                     7800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.210418939590454
# Reward/StdReward          1.0891731977462769
# ------------------------  -------------------------------------------
# 2023-05-01 19:26:12 | [SOURCE] epoch #7900 | log goal post after training: 1.2632994651794434
# 2023-05-01 19:26:13 | [SOURCE] epoch #7900 | Total time 1341.79 s
# 2023-05-01 19:26:13 | [SOURCE] epoch #7900 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7848582863807678, -0.04756121709942818]
# Design/StdDesign          [1.401976227760315, 1.002191185951233]
# Epoch                     7900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1849355697631836
# Reward/StdReward          1.0298099517822266
# ------------------------  ------------------------------------------
# 2023-05-01 19:26:29 | [SOURCE] epoch #8000 | log goal post after training: 1.2518329620361328
# 2023-05-01 19:26:30 | [SOURCE] epoch #8000 | Checkpoint saved
# 2023-05-01 19:26:30 | [SOURCE] epoch #8000 | Total time 1359.03 s
# 2023-05-01 19:26:30 | [SOURCE] epoch #8000 | Epoch time 0.44 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.8460118174552917, -0.02140800654888153]
# Design/StdDesign          [1.475202202796936, 0.967921257019043]
# Epoch                     8000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1820638179779053
# Reward/StdReward          0.9774294495582581
# ------------------------  ------------------------------------------
# 2023-05-01 19:26:47 | [SOURCE] epoch #8100 | log goal post after training: 1.2643531560897827
# 2023-05-01 19:26:47 | [SOURCE] epoch #8100 | Total time 1376.00 s
# 2023-05-01 19:26:47 | [SOURCE] epoch #8100 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.7432664036750793, -0.022937694564461708]
# Design/StdDesign          [1.3699145317077637, 0.9729368090629578]
# Epoch                     8100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1937246322631836
# Reward/StdReward          1.016661524772644
# ------------------------  -------------------------------------------
# 2023-05-01 19:27:04 | [SOURCE] epoch #8200 | log goal post after training: 1.2540804147720337
# 2023-05-01 19:27:04 | [SOURCE] epoch #8200 | Total time 1392.98 s
# 2023-05-01 19:27:04 | [SOURCE] epoch #8200 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.8263052701950073, 0.04622851312160492]
# Design/StdDesign          [1.4576793909072876, 0.9919949769973755]
# Epoch                     8200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.176988959312439
# Reward/StdReward          1.09488844871521
# ------------------------  -----------------------------------------
# 2023-05-01 19:27:21 | [SOURCE] epoch #8300 | log goal post after training: 1.2668896913528442
# 2023-05-01 19:27:21 | [SOURCE] epoch #8300 | Total time 1409.95 s
# 2023-05-01 19:27:21 | [SOURCE] epoch #8300 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.7959864735603333, -0.004395470954477787]
# Design/StdDesign          [1.4568840265274048, 0.9798839688301086]
# Epoch                     8300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2386999130249023
# Reward/StdReward          1.0232644081115723
# ------------------------  -------------------------------------------
# 2023-05-01 19:27:38 | [SOURCE] epoch #8400 | log goal post after training: 1.277783989906311
# 2023-05-01 19:27:38 | [SOURCE] epoch #8400 | Total time 1426.93 s
# 2023-05-01 19:27:38 | [SOURCE] epoch #8400 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.8187438249588013, 0.04211282730102539]
# Design/StdDesign          [1.4025647640228271, 0.9616840481758118]
# Epoch                     8400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1983704566955566
# Reward/StdReward          1.0295844078063965
# ------------------------  -----------------------------------------
# 2023-05-01 19:27:54 | [SOURCE] epoch #8500 | log goal post after training: 1.2652621269226074
# 2023-05-01 19:27:55 | [SOURCE] epoch #8500 | Total time 1443.86 s
# 2023-05-01 19:27:55 | [SOURCE] epoch #8500 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.8104599118232727, -0.012608165852725506]
# Design/StdDesign          [1.37934148311615, 0.9675726890563965]
# Epoch                     8500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.23566734790802
# Reward/StdReward          0.996043860912323
# ------------------------  -------------------------------------------
# 2023-05-01 19:28:11 | [SOURCE] epoch #8600 | log goal post after training: 1.2748414278030396
# 2023-05-01 19:28:12 | [SOURCE] epoch #8600 | Total time 1460.79 s
# 2023-05-01 19:28:12 | [SOURCE] epoch #8600 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.8145366907119751, 0.04485301300883293]
# Design/StdDesign          [1.4208037853240967, 0.95829176902771]
# Epoch                     8600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2071123123168945
# Reward/StdReward          1.123899221420288
# ------------------------  -----------------------------------------
# 2023-05-01 19:28:28 | [SOURCE] epoch #8700 | log goal post after training: 1.285733938217163
# 2023-05-01 19:28:28 | [SOURCE] epoch #8700 | Total time 1477.71 s
# 2023-05-01 19:28:28 | [SOURCE] epoch #8700 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.7606332898139954, -0.010950439609587193]
# Design/StdDesign          [1.3740098476409912, 0.9881312847137451]
# Epoch                     8700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.179709792137146
# Reward/StdReward          1.215998649597168
# ------------------------  -------------------------------------------
# 2023-05-01 19:28:45 | [SOURCE] epoch #8800 | log goal post after training: 1.281172275543213
# 2023-05-01 19:28:45 | [SOURCE] epoch #8800 | Total time 1494.67 s
# 2023-05-01 19:28:45 | [SOURCE] epoch #8800 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7313830852508545, -0.03858714550733566]
# Design/StdDesign          [1.4492805004119873, 0.9659315347671509]
# Epoch                     8800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.252271056175232
# Reward/StdReward          1.0023828744888306
# ------------------------  ------------------------------------------
# 2023-05-01 19:29:02 | [SOURCE] epoch #8900 | log goal post after training: 1.279489278793335
# 2023-05-01 19:29:02 | [SOURCE] epoch #8900 | Total time 1511.65 s
# 2023-05-01 19:29:02 | [SOURCE] epoch #8900 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7805128693580627, -0.00333670643158257]
# Design/StdDesign          [1.4564775228500366, 0.9838320016860962]
# Epoch                     8900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2448885440826416
# Reward/StdReward          0.972571849822998
# ------------------------  ------------------------------------------
# 2023-05-01 19:29:19 | [SOURCE] epoch #9000 | log goal post after training: 1.2917358875274658
# 2023-05-01 19:29:19 | [SOURCE] epoch #9000 | Checkpoint saved
# 2023-05-01 19:29:19 | [SOURCE] epoch #9000 | Total time 1528.72 s
# 2023-05-01 19:29:19 | [SOURCE] epoch #9000 | Epoch time 0.26 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.747083842754364, 0.0008719726465642452]
# Design/StdDesign          [1.3155453205108643, 0.9564720392227173]
# Epoch                     9000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.1542097330093384
# Reward/StdReward          1.2939517498016357
# ------------------------  ------------------------------------------
# 2023-05-01 19:29:36 | [SOURCE] epoch #9100 | log goal post after training: 1.304300308227539
# 2023-05-01 19:29:36 | [SOURCE] epoch #9100 | Total time 1545.68 s
# 2023-05-01 19:29:36 | [SOURCE] epoch #9100 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7469627857208252, 0.039160218089818954]
# Design/StdDesign          [1.4397475719451904, 0.9669390916824341]
# Epoch                     9100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2147458791732788
# Reward/StdReward          1.1146900653839111
# ------------------------  ------------------------------------------
# 2023-05-01 19:29:53 | [SOURCE] epoch #9200 | log goal post after training: 1.2926512956619263
# 2023-05-01 19:29:53 | [SOURCE] epoch #9200 | Total time 1562.65 s
# 2023-05-01 19:29:53 | [SOURCE] epoch #9200 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7365943193435669, -0.03445102274417877]
# Design/StdDesign          [1.3802794218063354, 0.97523432970047]
# Epoch                     9200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2426615953445435
# Reward/StdReward          1.0872602462768555
# ------------------------  ------------------------------------------
# 2023-05-01 19:30:10 | [SOURCE] epoch #9300 | log goal post after training: 1.2786046266555786
# 2023-05-01 19:30:10 | [SOURCE] epoch #9300 | Total time 1579.61 s
# 2023-05-01 19:30:10 | [SOURCE] epoch #9300 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7726601958274841, -0.08588073402643204]
# Design/StdDesign          [1.4734169244766235, 0.9723758101463318]
# Epoch                     9300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.3022685050964355
# Reward/StdReward          0.9335442781448364
# ------------------------  ------------------------------------------
# 2023-05-01 19:30:27 | [SOURCE] epoch #9400 | log goal post after training: 1.298301100730896
# 2023-05-01 19:30:27 | [SOURCE] epoch #9400 | Total time 1596.57 s
# 2023-05-01 19:30:27 | [SOURCE] epoch #9400 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7837784886360168, -0.06273393332958221]
# Design/StdDesign          [1.4119832515716553, 0.9820228219032288]
# Epoch                     9400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2300482988357544
# Reward/StdReward          1.017500877380371
# ------------------------  ------------------------------------------
# 2023-05-01 19:30:44 | [SOURCE] epoch #9500 | log goal post after training: 1.2981536388397217
# 2023-05-01 19:30:44 | [SOURCE] epoch #9500 | Total time 1613.51 s
# 2023-05-01 19:30:44 | [SOURCE] epoch #9500 | Epoch time 0.17 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.811498761177063, -0.06959036737680435]
# Design/StdDesign          [1.3900221586227417, 0.9575625061988831]
# Epoch                     9500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.220166563987732
# Reward/StdReward          1.1259418725967407
# ------------------------  -----------------------------------------
# 2023-05-01 19:31:01 | [SOURCE] epoch #9600 | log goal post after training: 1.3005424737930298
# 2023-05-01 19:31:01 | [SOURCE] epoch #9600 | Total time 1630.43 s
# 2023-05-01 19:31:01 | [SOURCE] epoch #9600 | Epoch time 0.17 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.7315984964370728, -0.011662316508591175]
# Design/StdDesign          [1.4432733058929443, 0.9710915088653564]
# Epoch                     9600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2764705419540405
# Reward/StdReward          1.0024417638778687
# ------------------------  -------------------------------------------
# 2023-05-01 19:31:18 | [SOURCE] epoch #9700 | log goal post after training: 1.2965067625045776
# 2023-05-01 19:31:18 | [SOURCE] epoch #9700 | Total time 1647.35 s
# 2023-05-01 19:31:18 | [SOURCE] epoch #9700 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7279926538467407, 0.005996765103191137]
# Design/StdDesign          [1.4230297803878784, 0.9582812786102295]
# Epoch                     9700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.212586760520935
# Reward/StdReward          1.0963152647018433
# ------------------------  ------------------------------------------
# 2023-05-01 19:31:35 | [SOURCE] epoch #9800 | log goal post after training: 1.2934932708740234
# 2023-05-01 19:31:35 | [SOURCE] epoch #9800 | Total time 1664.30 s
# 2023-05-01 19:31:35 | [SOURCE] epoch #9800 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7448337078094482, 0.018952051177620888]
# Design/StdDesign          [1.4529047012329102, 0.9610514640808105]
# Epoch                     9800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2256306409835815
# Reward/StdReward          1.1320534944534302
# ------------------------  ------------------------------------------
# 2023-05-01 19:31:52 | [SOURCE] epoch #9900 | log goal post after training: 1.3069982528686523
# 2023-05-01 19:31:52 | [SOURCE] epoch #9900 | Total time 1681.26 s
# 2023-05-01 19:31:52 | [SOURCE] epoch #9900 | Epoch time 0.17 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7854606509208679, 0.009993554092943668]
# Design/StdDesign          [1.4082051515579224, 0.9718153476715088]
# Epoch                     9900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2264436483383179
# Reward/StdReward          1.1052154302597046
# ------------------------  ------------------------------------------
# 2023-05-01 19:32:09 | [SOURCE] epoch #10000 | log goal post after training: 1.3074971437454224
# 2023-05-01 19:32:09 | [SOURCE] epoch #10000 | Checkpoint saved
# 2023-05-01 19:32:09 | [SOURCE] epoch #10000 | Total time 1698.32 s
# 2023-05-01 19:32:09 | [SOURCE] epoch #10000 | Epoch time 0.27 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.7051575779914856, 0.056666478514671326]
# Design/StdDesign          [1.4615087509155273, 0.9810526967048645]
# Epoch                     10000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         1.2353053092956543
# Reward/StdReward          1.0990959405899048
# ------------------------  ------------------------------------------

# %%
plt.figure(figsize=(10, 4))
plt.plot(vsoed.update_hist[:])
plt.xlabel('update', fontsize=20)
plt.ylabel('averaged reward', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(linestyle='--')

# %%
set_random_seed(EVAL_SEEDS[0])
ret = vsoed.asses(2000, n_contrastive_sample=int(1e6), return_all=True)
averaged_reward = ret['averaged_reward']
params = ret['params'].cpu().numpy()
ds_hist = ret['ds_hist'].cpu().numpy()
ys_hist = ret['ys_hist'].cpu().numpy()
rewards_hist = ret['rewards_hist'].cpu().numpy()
averaged_reward
# Out:
# 100%|██████████| 2000/2000 [00:21<00:00, 94.83it/s]
# 4.673610210418701

# %%
import joblib
vsoed = joblib.load(folder + 'itr_10000.pkl')

# %%
idxs = np.random.choice(len(params), 10, replace=False)
plt.figure(figsize=(30, 8))
for i, idx in enumerate(idxs):
    plt.subplot(2, 5, i + 1)
    theta = params[idx][:4]
    d_hist = ds_hist[idx]
    y_hist = ys_hist[idx]
    for i in range(2):
        plt.scatter(theta[i*2], theta[i*2+1], c='orangered', s=100, marker='*', zorder=10)
    d_old = None
    for d in d_hist:
        plt.scatter(d[0], d[1], c='navy', s=50)
        if d_old is not None:
            plt.arrow(d_old[0], d_old[1], d[0] - d_old[0], d[1] - d_old[1], alpha=0.5, color='navy', head_width=0.2, length_includes_head=True)
        d_old = d
    plt.xlim(-4, 4)
    plt.ylim(-4, 4)

# %%
plt.hist(params[:, -1])
# Out:
# (array([  6.,  70., 315., 570., 545., 309., 130.,  35.,  16.,   4.]),
#  array([-2.465985  , -2.2787888 , -2.0915928 , -1.9043967 , -1.7172005 ,
#         -1.5300043 , -1.3428081 , -1.155612  , -0.96841586, -0.7812197 ,
#         -0.5940236 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
def extract_params(params):
    base_signal = 0.1
    max_signal  = 1e-4
    theta1 = params[:, 0:1]
    theta2 = params[:, 1:2]
    theta3 = params[:, 2:3]
    theta4 = params[:, 3:4]
    theta5 = None
    theta6 = None
    model_idxs = None
    return (base_signal, max_signal, model_idxs, 
        theta1, theta2, theta3, theta4, theta5, theta6)

# %%
def flux(params):
    d1 = 6.0
    (base_signal, max_signal, _,
    theta1, theta2, theta3, theta4, _, _) = extract_params(params)

    tmp = max_signal + (theta1 - d1) ** 2
    flux_1 = -(theta1 - d1) * math.pi * torch.sqrt(tmp) / tmp ** 2 
    tmp = max_signal + (theta3 - d1) ** 2
    flux_2 = -(theta3 - d1) * math.pi * torch.sqrt(tmp) / tmp ** 2 
    flux = flux_1 + flux_2
    return torch.log(flux)

# %%
f = flux(prior.rvs(1000000))

# %%
plt.hist(f.cpu().numpy())
# Out:
# (array([2.25500e+03, 1.32686e+05, 4.98031e+05, 3.02187e+05, 5.78580e+04,
#         6.22400e+03, 6.52000e+02, 8.40000e+01, 2.00000e+01, 3.00000e+00]),
#  array([-2.6502109 , -2.3067834 , -1.963356  , -1.6199286 , -1.2765012 ,
#         -0.93307376, -0.58964634, -0.24621892,  0.0972085 ,  0.44063592,
#          0.78406334], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
params[30]
# Out:
# tensor([-1.4932,  0.9510, -0.7655, -1.2224,  0.0757], device='cuda:0')

# %%
rewards_hist[:, :5].sum(-1).mean()
# Out:
# tensor(3.6108, device='cuda:0')

# %%
p_max = torch.arange(1, vsoed.n_buffer_max + 1).to(torch.float32)
l_buffer = 1000000
p = p_max[:l_buffer]
p /= p.sum()
idxs_pick = torch.multinomial(p, vsoed.n_batch, replacement=False)

# %%
plt.hist(idxs_pick.cpu().numpy())
# Out:
# (array([ 112.,  307.,  480.,  745.,  934., 1096., 1278., 1487., 1672.,
#         1889.]),
#  array([ 10025. , 109021.9, 208018.8, 307015.7, 406012.6, 505009.5,
#         604006.4, 703003.3, 802000.2, 900997.1, 999994. ]),
#  <BarContainer object of 10 artists>)

# %%
import joblib

# %%
joblib.dump(vsoed, folder + 'itr_0.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3852929/4165733059.py in <module>
# ----> 1 joblib.dump(vsoed, folder + 'itr_0.pkl')
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     480     elif is_filename:
#     481         with open(filename, 'wb') as f:
# --> 482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#     484         NumpyPickler(filename, protocol=protocol).dump(value)
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in dump(self, obj)
#     485         if self.proto >= 4:
#     486             self.framer.start_framing()
# --> 487         self.save(obj)
#     488         self.write(STOP)
#     489         self.framer.end_framing()
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690         else:
#     691             save(func)
# --> 692             save(args)
#     693             write(REDUCE)
#     694
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     576                 reduce = getattr(obj, "__reduce_ex__", None)
#     577                 if reduce is not None:
# --> 578                     rv = reduce(self.proto)
#     579                 else:
#     580                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'module' object

# %%
vsoed.nkld_rw_f
# Out:
# <function vsOED.vsoed.VSOED.__init__.<locals>.nkld_rw_f(*args, **kws)>

# %%
torch.tensor(())
# Out:
# tensor([])

# %%
{'a': 1}.update({'b': 5})

# %%
np.random.choice(int(1e10), 10)
# Out:
# array([6377791278, 7037998855, 7556092991, 8217385358, 8695645867,
#        1645853955, 1283211782, 8616980401, 3169416485, 1613878827])

# %%
dict().update

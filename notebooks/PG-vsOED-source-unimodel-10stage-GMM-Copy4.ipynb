# %%
# %load_ext autoreload
# %autoreload 2

import os,sys,inspect
# current_dir = '/home/jiayuand/seqOED_variational/examples/location'
# parent_dir = '/home/jiayuand/seqOED_variational'

# current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
# parent_dir = os.path.dirname(os.path.dirname(current_dir))
parent_dir = '/scratch/xhuan_root/xhuan1/wgshen/vsOED/'
sys.path.insert(0, parent_dir) 

import numpy as np
# from scipy.stats import norm, beta, dirichlet
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from   torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
if torch.cuda.is_available():  
    dev = "cuda:0" 
else:  
    dev = "cpu"  
device = torch.device(dev) 
torch.set_default_device(device)
dtype = torch.float32
torch.set_default_dtype(dtype)

from vsOED import VSOED, PGvsOED#, GMM_NET, NFs, POST_APPROX
from vsOED.utils import *
from vsOED.models import *

import dowel
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class SOURCE(object):
    def __init__(self, **kws):
        pass
    
    def deterministic(self, theta, d, xp=None):
        base_signal = 0.1
        max_signal  = 1e-4

        # m = theta[:, 0:1]
        theta1 = theta[:, 0:1]
        theta2 = theta[:, 1:2]
        theta3 = theta[:, 2:3]
        theta4 = theta[:, 3:4]
        # theta5 = theta[:, 5:6]
        # theta6 = theta[:, 6:7]

        d1     = d[:, 0:1]
        d2     = d[:, 1:2]
        G      = (base_signal 
                  + 1/( (theta1-d1)**2 + (theta2-d2)**2 + max_signal) 
                  + ( 1/( (theta3-d1)**2 + (theta4-d2)**2 + max_signal ) ) )

        return torch.log(G), torch.tensor(0.5)
        
    def model(self, stage, theta, d,  xp=None):
        try:
            theta = torch.from_numpy(theta).to(device)
            d = torch.from_numpy(d).to(device)
        except:
            pass
        with torch.no_grad():
            mu_eta, sigma_eta = self.deterministic(theta, d, xp)
            eta = np.random.normal(mu_eta.cpu().numpy(), sigma_eta.cpu().numpy())

        return torch.from_numpy(eta).to(device, dtype)
    
    def loglikeli(self, stage, y, theta, d, xp=None, true_theta=None):
        """
        y : (n or 1, n_obs)
        theta : (n or 1, n_param)
        d : (n or 1, n_design)
        """
        with torch.no_grad():
            mu_eta, sigma_eta = self.deterministic(theta, d, xp)
            if len(y) == 1:
                y = y.expand((len(theta), -1))
            normal = torch.distributions.Normal(mu_eta, sigma_eta)
            log_prob = normal.log_prob(y)
            log_prob = log_prob.sum(-1)
        return log_prob
    
    def logevid(self, *args, **kws):
        return math.log(1 / 3.0)
    
    def log_poi_prior(self, prior_samples):
        # m = prior_samples[:, 0]
        theta = prior_samples.reshape(-1, 2, 2)
        log_probs = norm_logpdf(theta, 0, 1)
        # log_prob = np.zeros(len(log_probs))
        # log_prob[m == 1] = log_probs[m == 1][:, 0]
        # log_prob[m == 2] = log_probs[m == 2][:, :2].sum(-1)
        # log_prob[m == 3] = log_probs[m == 3].sum(-1)
        return log_probs.sum(-1)
    
    def rvs(self, n_sample):
        # m = np.random.randint(3, size=n_sample) + 1
        theta = np.random.randn(n_sample, 4)
        # theta[m < 3, -2:] = 0
        # theta[m < 2, -4:] = 0
        # theta = np.c_[m.reshape(-1, 1), theta]
        return torch.from_numpy(theta).to(device, dtype)

# %%
class GMM_NET(nn.Module):
    def __init__(self, n_d, n_y, n_theta, n_mixture, activate):
        super().__init__()
        self.n_d = n_d
        self.n_y = n_y
        self.n_theta = n_theta
        self.n_mixture = n_mixture
        activate = activate
        feature_dimns = [n_d + n_y, 256, 256]
        weight_dimns = [256, 256, 256, n_mixture + 1]
        mu_dimns = [256, 256, 256, n_mixture * n_theta]
        sigma_dimns = [256, 256, 256, n_mixture * n_theta]
        feature_layers = []
        weight_layers = []
        mu_layers = []
        sigma_layers = []
        for i in range(len(feature_dimns) - 1):
            feature_layers.append(nn.Linear(feature_dimns[i], feature_dimns[i + 1]))
#             feature_layers.append(nn.BatchNorm1d(feature_dimns[i + 1]))
            feature_layers.append(activate())
        for i in range(len(weight_dimns) - 1):
            weight_layers.append(nn.Linear(weight_dimns[i], weight_dimns[i + 1]))
            if i < len(weight_dimns) - 2:
#                 weight_layers.append(nn.BatchNorm1d(weight_dimns[i + 1]))
                weight_layers.append(activate())
        weight_layers.append(nn.Softmax(dim=1))
        for i in range(len(mu_dimns) - 1):
            mu_layers.append(nn.Linear(mu_dimns[i], mu_dimns[i + 1]))
            if i < len(mu_dimns) - 2:
#                 mu_layers.append(nn.BatchNorm1d(mu_dimns[i + 1]))
                mu_layers.append(activate())
        for i in range(len(sigma_dimns) - 1):
            sigma_layers.append(nn.Linear(sigma_dimns[i], sigma_dimns[i + 1]))
            if i < len(sigma_dimns) - 2:
#                 sigma_layers.append(nn.BatchNorm1d(sigma_dimns[i + 1]))
                sigma_layers.append(activate())
        self.feature_net = nn.Sequential(*feature_layers)
        self.weight_net = nn.Sequential(*weight_layers)
        self.mu_net = nn.Sequential(*mu_layers)
        self.sigma_net = nn.Sequential(*sigma_layers)
        self.param_bounds = torch.tensor([-20, 20]).reshape(-1, 2).to(device)

    def forward(self, x):
        thetas = x[:, self.n_d+self.n_y:self.n_d+self.n_y+self.n_theta] # (N, n_theta)
        thetas = thetas.reshape(-1, 1, self.n_theta)
        x = x[:, :self.n_d + self.n_y]
        # x = inputs
        features = self.feature_net(x)
        weights = self.weight_net(features) # (N, n_mixture)
        mus = self.mu_net(features) # (N, n_mixture*n_theta)
        mus = torch.sigmoid(mus)
        sigmas = self.sigma_net(features)

        sigmas = torch.sigmoid(sigmas)

        mus = mus.reshape(-1, self.n_mixture, self.n_theta) # (N, n_mixture, n_theta)

        mus   = mus * 12 - 6
        sigmas = sigmas.reshape(-1, self.n_mixture, self.n_theta) # (N, n_mixture, n_theta)
        # sigmas = sigmas * torch.tensor([3, 3, 3, 3]).to(device)
        sigmas = sigmas + 0.00001 
        # truncnorm = TruncatedNormal(mus[..., :3], sigmas[..., :3], 0, 1)
        normal = torch.distributions.Normal(mus, sigmas)
        # logprob_mixture_truncnorm = truncnorm.log_prob(thetas[..., :3])
        # logprob_mixture_normal = normal.log_prob(thetas[..., 3:4])
#         print(logprob_mixture_truncnorm.shape, logprob_mixture_normal.shape)
        # logprob_mixture = logprob_mixture_truncnorm.sum(-1) + logprob_mixture_normal.sum(-1)
        logprob_mixture = normal.log_prob(thetas).sum(-1)
        prob_mixture = torch.exp(logprob_mixture)
        
#         prob_mixture = 1 / np.sqrt(2*np.pi) / sigmas * torch.exp(-(thetas - mus)**2 / 2 / sigmas**2) # (N, n_mixture, n_theta)
#         prob_mixture = prob_mixture.prod(-1) # (N, n_mixture)
        probs = (prob_mixture * weights[:, :-1]).sum(-1) # (N)
        thetas = thetas.reshape(-1, self.n_theta) # (N, n_theta)
        in_bounds = ((thetas > self.param_bounds[:, 0]) * (thetas < self.param_bounds[:, 1])).prod(-1)
        uniform_probs = in_bounds / 40 ** 4
        probs = probs + uniform_probs * weights[:,-1]
        probs += 1e-27
        logprobs = torch.log(probs)
        return logprobs

# %%
class Post_approx(object):
    def __init__(self,  n_stage, n_d, n_y, n_thetas, n_mixture, activate=None, prior=None, evid_weight=1, post_weight=1, n_incre=1):
        evid_lr_initial = 1e-3
        post_lr_initial = 1e-3
        evid_scheduler_gamma = 0.9999
        post_scheduler_gamma = 0.9999
        assert evid_weight > 0 or post_weight > 0
        if activate is None:
            activate = nn.ReLU
        self.prior = prior
        
        if isinstance(n_thetas, int):
            n_thetas = [n_thetas]
        if len(n_thetas) == 1:
            evid_weight = 0
        self.n_thetas = n_thetas
        
        assert n_incre <= n_stage
        stages_incre = [int(n_stage * (i + 1) / n_incre) - 1 for i in range(n_incre)]
        print(stages_incre)
        
        if evid_weight > 0:
            self.evid_nets = {}
            self.evid_optimizer = {}
            self.evid_scheduler = {}
            for stage in stages_incre:
                evid_dimns = [(stage + 1) * (n_d + n_y), 256, 256, 256, len(self.n_thetas)]
                evid_layers = []
                for i in range(len(evid_dimns) - 1):
                    evid_layers.append(nn.Linear(evid_dimns[i], evid_dimns[i + 1]))
        #             feature_layers.append(nn.BatchNorm1d(feature_dimns[i + 1]))
                    evid_layers.append(activate())
                evid_layers.append(nn.LogSoftmax(dim=1))
                evid_net = nn.Sequential(*evid_layers).float().to(device)
                evid_optimizer = optim.Adam(evid_net.parameters(), lr=evid_lr_initial)
                evid_scheduler = torch.optim.lr_scheduler.ExponentialLR(self.evid_optimizer, gamma=evid_scheduler_gamma)
                self.evid_nets[stage] = evid_net
                self.evid_optimizers[stage] = evid_optimizer
                self.evid_schedulers[stage] = evid_scheduler
            
        self.post_nets = {}
        self.post_optimizers = {}
        self.post_schedulers = {}
        if post_weight > 0:
            for stage in stages_incre:
                self.post_nets[stage] = []
                self.post_optimizers[stage] = []
                self.post_schedulers[stage] = []
                for n_theta in n_thetas:
                    post_net = GMM_NET((stage + 1) * n_d, (stage + 1) * n_y, n_theta, n_mixture, activate).float().to(device)
                    optimizer = optim.Adam(post_net.parameters(), lr=post_lr_initial)
                    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=post_scheduler_gamma)
                    self.post_nets[stage].append(post_net)
                    self.post_optimizers[stage].append(optimizer)
                    self.post_schedulers[stage].append(scheduler)
        self.evid_weight = evid_weight
        self.post_weight = post_weight
        self.stages_incre = stages_incre
        self.n_stage = n_stage
        self.n_d = n_d
        self.n_y = n_y
        self.n_thetas = n_thetas
                
    def logevid(self, stage, ds, ys):
        assert self.evid_weight > 0
        with torch.no_grad():
            X = torch.cat([ds.reshape(len(ds), -1), ys.reshape(len(ys), -1)], dim=-1)
            logevid = self.evid_net[stage](X)
        return logevid
                
    def logpdf(self, stage, ds, ys, thetas):
        assert self.post_weight > 0
        with torch.no_grad():
            if isinstance(ds, torch.Tensor):
                X = torch.cat([ds.reshape(len(ds), -1), ys.reshape(len(ys), -1)], dim=-1)
            else:
                X = np.c_[ds.reshape(len(ds), -1), ys.reshape(len(ys), -1)]
            if len(self.n_thetas) > 1:
                m = thetas[:, 0]
                thetas = thetas[:, 1:]
            else:
                m = np.ones(len(thetas))
            if isinstance(ds, torch.Tensor):
                X = torch.cat([X, thetas], dim=-1)
            else:
                X = np.c_[X, thetas]
                X = torch.from_numpy(X).to(device, dtype)
            logpdf = torch.zeros(len(X)) - np.inf
            for m_idx, n_theta in enumerate(self.n_thetas):
                idxs = m == (m_idx + 1)
                logpdf[idxs] = self.post_nets[stage][m_idx](X[idxs])          ##### When use GMM, only one output (logpdf)
            # logpdf[logpdf == -np.inf] = 0
            # logpdf[np.isnan(logpdf)] = 0
            return logpdf
    
    def train(self, ds, ys, xps, thetas, l, n_update=3):

        for stage in self.stages_incre:
            if isinstance(ds, torch.Tensor):
                X_evid = torch.cat([ds[:, :stage+1].reshape(len(ds), -1), ys[:, :stage+1].reshape(len(ys), -1)], dim=-1)
                if len(self.n_thetas) > 1:
                    X = torch.cat([X_evid, thetas[:, 1:]], dim=-1)
                else:
                    X = torch.cat([X_evid, thetas], dim=-1) 
            else:
                X_evid = np.c_[ds[:, :stage+1].reshape(len(ds), -1), ys[:, :stage+1].reshape(len(ys), -1)]
                if len(self.n_thetas) > 1:
                    X = np.c_[X_evid, thetas[:, 1:]]
                else:
                    X = np.c_[X_evid, thetas]
                X_evid = torch.from_numpy(X_evid).to(device, dtype)
                X = torch.from_numpy(X).to(device, dtype)
                
            for t in range(n_update):
                # train evid net
                if self.evid_weight > 0:
                    m = thetas[:, 0]
                    logevids = self.evid_nets[stage](X_evid)
                    logevids = logevids[torch.arange(len(logevids)).to(device), m - 1]
                    loss = torch.mean(-logevids)
                    self.evid_optimizers[stage].zero_grad()
                    loss.backward()
                    self.evid_optimizers[stage].step()
                if self.post_weight > 0:
                    if len(self.n_thetas) > 1:
                        m = thetas[:, 0]
                    else:
                        m = torch.ones(len(thetas))
                    logposts = torch.zeros(len(thetas)).to(device)
                    # logposts.requires_grad = True
                    for m_idx in range(len(self.n_thetas)):
                        idxs = m == (m_idx + 1)
                        idxs = idxs.to(device)
                        logposts[idxs] = self.post_nets[stage][m_idx](X[idxs])
                        # logposts = logposts[logposts > -np.inf]
                        # logposts = logposts[~torch.isnan(logposts)]
                    loss = torch.mean(-logposts)
                    for optimizer in self.post_optimizers[stage]:
                        optimizer.zero_grad()
                    loss.backward()  
                    for post_net in self.post_nets[stage]:
                        for param in post_net.parameters():
                            if torch.isnan(param.grad).any():
                                stop
                    for optimizer in self.post_optimizers[stage]:
                        optimizer.step()
            if self.evid_weight > 0:
                self.evid_schedulers[stage].step()
            if self.post_weight > 0:
                for scheduler in self.post_schedulers[stage]:
                    scheduler.step()
            if l % 100 == 0 and stage == self.stages_incre[-1]:
                if self.evid_weight > 0:
                    print('logevids', logevids.mean())
                if self.post_weight > 0:
                    print('logposts', logposts.mean())
        
    def reward_fun(self, stage, ds_hist, ys_hist, xps, thetas):
        if stage == 0:
            if self.evid_weight > 0:
                if self.prior is None:
                    self.logevid_prior = 0
                else:
                    self.logevid_prior = self.prior.log_model_prior()
            if self.post_weight > 0:
                if self.prior is None:
                    self.logpdf_prior = 0
                else:
                    self.logpdf_prior = self.prior.log_poi_prior(thetas)
        if stage in self.stages_incre:
            if self.evid_weight > 0:
                m = thetas[:, 0].astype(int)
                logevid_post = self.logevid(stage, ds_hist, ys_hist)[np.arange(len(ds_hist)), m - 1]
                evid_kld = logevid_post - self.logevid_prior
                self.logevid_prior = logevid_post
            else:
                evid_kld = 0
            if self.post_weight > 0:
                logpdf_post = self.logpdf(stage, ds_hist, ys_hist, thetas)
                post_kld = logpdf_post - self.logpdf_prior
                self.logpdf_prior = logpdf_post
            else:
                post_kld = 0
            return self.evid_weight * evid_kld + self.post_weight * post_kld
        else:
            return 0
    
    def terminal_reward_fun(self, ds_hist, ys_hist, xps, thetas):
        return 0
#         if self.evid_weight > 0:
#             m = thetas[:, 0].astype(int)
#             logevid_post = self.logevid(ds_hist, ys_hist)[np.arange(len(ds_hist)), m - 1]
#             if self.prior is None:
#                 logevid_prior = 0
#             else:
#                 logevid_prior = self.prior.logevid()
#             evid_kld = logevid_post - logevid_prior
#         else:
#             evid_kld = 0
            
#         if self.post_weight > 0:
#             m = thetas[:, 0]
#             logpdf_post = self.logpdf(ds_hist, ys_hist, thetas)
#             if self.prior is None:
#                 logpdf_prior = 0
#             else:
#                 logpdf_prior = self.prior.logpdf(thetas)
#             # print('logpdf_post: ', logpdf_post)
#             # print('logpdf_prior: ', logpdf_prior)
#             post_kld = logpdf_post - logpdf_prior
#         else:
#             post_kld = 0
            
#         return self.evid_weight * evid_kld + self.post_weight * post_kld
        
    def return_network(self, X):
        return self.post_net(X)

# %%
n_stage      = 10       # Number of stages.
n_design     = 2        # Number of design variables.
n_obs        = 1        # Number of observations.
n_pois       = [4]        # Number of parameters.
n_nuisps     = None
n_goals      = None
model_weight = 0
poi_weight   = 1
goal_weight  = 0

random_state  = 56789
set_random_seed(random_state)

model = SOURCE(multimodel=False, include_nuisance=False, include_goal=False)
prior = model

mu_bounds = {}
mu_bounds['poi'] = []
for n_poi in n_pois:
    mu_bounds['poi'].append([[-6, 6]] * n_poi)
if n_goals is not None:
    mu_bounds['goal'] = []
    for n_goal in n_goals:
        mu_bounds['goal'].append([[0, 3]] * n_goal)
max_sigmas = {}
max_sigmas['poi'] = []
for n_poi in n_pois:
    max_sigmas['poi'].append([1.0] * n_poi)
if n_goals is not None:
    max_sigmas['goal'] = []
    for n_goal in n_goals:
        max_sigmas['goal'].append([1.0] * n_goal)
truncnorm_info = {}
truncnorm_info['poi'] = [None] * len(n_pois)
if n_goals is not None:
    truncnorm_info['goal'] = []
    for n_goal in n_goals:
        info = []
        for i in range(n_goal):
            info.append([i, 0, 4])
            
n_incre = 1
share_interm_net = False

candidate_lrs = [[1e-3] * n_incre, [1e-4] * (n_incre - 1) + [1e-3]]
candidate_gammas = [[0.9999] * n_incre, [0.999999] * (n_incre - 1) + [0.9999]]
model_post_lrs = candidate_lrs[share_interm_net]
model_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]
poi_post_lrs = candidate_lrs[share_interm_net]
poi_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]
goal_post_lrs = candidate_lrs[share_interm_net]
goal_post_lr_scheduler_gammas = candidate_gammas[share_interm_net]

use_NFs = False
n_mixture = 8
activate = nn.ReLU

log_every = 100
folder = parent_dir + f'experiments/source_{len(n_pois)}model_{n_stage}stage_{n_incre}incre_GMM/'
try:
    os.remove(folder + 'progress.csv')
except:
    pass
try:
    os.remove(folder + 'progress.txt')
except:
    pass
try:
    dowel.logger.remove_all()
except:
    pass
dowel.logger.add_output(dowel.StdOutput())
dowel.logger.add_output(dowel.CsvOutput(folder + 'progress.csv'))
dowel.logger.add_output(dowel.TextOutput(folder + 'progress.txt'))

try:
    for _ in range(100):
        dowel.logger.pop_prefix()
except:
    pass
dowel.logger.push_prefix('[SOURCE] ')
dowel.logger.log('Stored at ' + folder)
dowel.logger.log('Random seed:  ' + str(random_state))
dowel.logger.log('Device: ' + str(device))
dowel.logger.log('dtype: ' + str(dtype))

post_approx_params = {
    'n_stage': n_stage, 
    'n_design': n_design, 
    'n_obs': n_obs, 
    'n_pois': n_pois,
    'n_nuisps': n_nuisps,
    'n_goals': n_goals,
    'model_weight': model_weight,
    'poi_weight': poi_weight,
    'goal_weight': goal_weight,
    'mu_bounds': mu_bounds,
    'max_sigmas': max_sigmas,
    'truncnorm_info': truncnorm_info,
    'n_mixture': n_mixture,
    'activate': activate,
    'prior': prior,
    'n_incre': n_incre,
    'share_interm_net': share_interm_net,
    'model_post_lrs': model_post_lrs,
    'model_post_lr_scheduler_gammas': model_post_lr_scheduler_gammas,
    'poi_post_lrs': poi_post_lrs,
    'poi_post_lr_scheduler_gammas': poi_post_lr_scheduler_gammas,
    'goal_post_lrs': goal_post_lrs,
    'goal_post_lr_scheduler_gammas': goal_post_lr_scheduler_gammas,
    'use_NFs': use_NFs,
    'log_every': log_every,
    'dowel': dowel}

dowel.logger.log('Post_approx_params: ' + str(post_approx_params))

dowel.logger.dump_all()
# dowel.logger.remove_all()

# post_approx = POST_APPROX(**post_approx_params)
post_approx = Post_approx(n_stage, n_design, n_obs, n_pois, 8, activate, prior, evid_weight=0, post_weight=1, n_incre=1)
dowel.logger.dump_all()
# Out:
# 2023-05-01 12:28:03 | [SOURCE] Stored at /scratch/xhuan_root/xhuan1/wgshen/vsOED/experiments/source_1model_10stage_1incre_GMM/
# 2023-05-01 12:28:03 | [SOURCE] Random seed:  56789
# 2023-05-01 12:28:03 | [SOURCE] Device: cuda:0
# 2023-05-01 12:28:03 | [SOURCE] dtype: torch.float32
# 2023-05-01 12:28:03 | [SOURCE] Post_approx_params: {'n_stage': 10, 'n_design': 2, 'n_obs': 1, 'n_pois': [4], 'n_nuisps': None, 'n_goals': None, 'model_weight': 0, 'poi_weight': 1, 'goal_weight': 0, 'mu_bounds': {'poi': [[[-6, 6], [-6, 6], [-6, 6], [-6, 6]]]}, 'max_sigmas': {'poi': [[1.0, 1.0, 1.0, 1.0]]}, 'truncnorm_info': {'poi': [None]}, 'n_mixture': 8, 'activate': <class 'torch.nn.modules.activation.ReLU'>, 'prior': <__main__.SOURCE object at 0x15443d87f310>, 'n_incre': 1, 'share_interm_net': False, 'model_post_lrs': [0.001], 'model_post_lr_scheduler_gammas': [0.9999], 'poi_post_lrs': [0.001], 'poi_post_lr_scheduler_gammas': [0.9999], 'goal_post_lrs': [0.001], 'goal_post_lr_scheduler_gammas': [0.9999], 'use_NFs': False, 'log_every': 100, 'dowel': <module 'dowel' from '/home/wgshen/.local/lib/python3.9/site-packages/dowel/__init__.py'>}
# [9]

# %%
n_param = len(n_pois) > 1
try:
    n_param += max(n_pois)
except:
    pass
try:
    n_param += max(n_nuisps)
except:
    pass
try:
    n_param += max(n_goals)
except:
    pass

design_bounds = [(-4, 4), (-4, 4)] # lower and upper bounds of design variables.
def reward_fun(*args, **kws):
    return 0
nkld_reward_fun = reward_fun
kld_reward_fun = post_approx.reward_fun
phys_state_info = None
post_approx = post_approx
encoder_dimns = None
backend_dimns = None
actor_dimns = [256, 256, 256]
critic_dimns = [256, 256, 256]

vsoed_params = {
    'n_stage': n_stage,
    'n_param': n_param,
    'n_design': n_design,
    'n_obs': n_obs,
    'model': model,
    'prior': prior,
    'design_bounds': design_bounds,
    'nkld_reward_fun': nkld_reward_fun,
    'kld_reward_fun': kld_reward_fun,
    'phys_state_info': phys_state_info,
    'post_approx': post_approx,
    'encoder_dimns': encoder_dimns,
    'backend_dimns': backend_dimns,
    'actor_dimns': actor_dimns,
    'critic_dimns': critic_dimns,
    'activate': activate
}
dowel.logger.log('vsoed_params: ' + str(vsoed_params))

set_random_seed(random_state)
vsoed = PGvsOED(**vsoed_params)
# Out:
# 2023-05-01 12:28:03 | [SOURCE] vsoed_params: {'n_stage': 10, 'n_param': 4, 'n_design': 2, 'n_obs': 1, 'model': <__main__.SOURCE object at 0x15443d87f310>, 'prior': <__main__.SOURCE object at 0x15443d87f310>, 'design_bounds': [(-4, 4), (-4, 4)], 'nkld_reward_fun': <function reward_fun at 0x15443d8f0280>, 'kld_reward_fun': <bound method Post_approx.reward_fun of <__main__.Post_approx object at 0x15443d87fdc0>>, 'phys_state_info': None, 'post_approx': <__main__.Post_approx object at 0x15443d87fdc0>, 'encoder_dimns': None, 'backend_dimns': None, 'actor_dimns': [256, 256, 256], 'critic_dimns': [256, 256, 256], 'activate': <class 'torch.nn.modules.activation.ReLU'>}

# %%
actor_lr = 1e-3
actor_lr_scheduler_gamma = 0.9999
critic_lr = 1e-3
critic_lr_scheduler_gamma = 0.9999
    
n_update = 10001
n_newtraj = 1000
n_batch = 10000
n_buffer_init = n_batch * 2
n_buffer_max = int(1e6)
buffer_device = torch.device('cuda')
discount = 1 if n_incre == 1 else 0.9
encoder_actor_optimizer = None
encoder_actor_lr_scheduler = None
encoder_critic_optimizer = None
encoder_critic_lr_scheduler = None
actor_optimizer = optim.Adam(vsoed.actor_net.parameters(), lr=actor_lr)
actor_lr_scheduler = optim.lr_scheduler.ExponentialLR(actor_optimizer, gamma=actor_lr_scheduler_gamma)
n_critic_update = 5
critic_optimizer = optim.Adam(vsoed.critic_net.parameters(), lr=critic_lr)
critic_lr_scheduler = optim.lr_scheduler.ExponentialLR(critic_optimizer, gamma=critic_lr_scheduler_gamma)
n_post_approx_update = 5
lr_target = 0.1
design_noise_scale = 0.5
design_noise_decay = 0.9999
on_policy = False
use_PCE = False
use_PCE_incre = None
n_contrastive_sample = None
transition = 10000 if n_incre == 1 else 0
frozen = -1
save_every = 1000
save_path = folder
restart = False

vsoed_train_params = {
    'n_update': n_update,
    'n_newtraj': n_newtraj,
    'n_batch': n_batch,
    'n_buffer_init': n_buffer_init,
    'n_buffer_max': n_buffer_max,
    'buffer_device': buffer_device,
    'discount': discount,
    'encoder_actor_optimizer': encoder_actor_optimizer,
    'encoder_actor_lr_scheduler': encoder_actor_lr_scheduler,
    'encoder_critic_optimizer': encoder_critic_optimizer,
    'encoder_critic_lr_scheduler': encoder_critic_lr_scheduler,
    'actor_lr': actor_lr,
    'actor_optimizer': actor_optimizer,
    'actor_lr_scheduler_gamma': actor_lr_scheduler_gamma, 
    'actor_lr_scheduler': actor_lr_scheduler,
    'n_critic_update': n_critic_update,
    'critic_lr': critic_lr,
    'critic_optimizer': critic_optimizer,
    'critic_lr_scheduler_gamma': critic_lr_scheduler_gamma,
    'critic_lr_scheduler': critic_lr_scheduler,
    'n_post_approx_update': n_post_approx_update,
    'lr_target': lr_target,
    'design_noise_scale': design_noise_scale,
    'design_noise_decay': design_noise_decay,
    'on_policy': on_policy,
    'use_PCE': use_PCE,
    'use_PCE_incre': use_PCE_incre,
    'n_contrastive_sample': n_contrastive_sample,
    'transition': transition,
    'frozen': frozen,
    'log_every': log_every,
    'dowel': dowel,
    'save_every': save_every,
    'save_path': save_path,
    'restart': restart
}

dowel.logger.log('vsoed_train_params: ' + str(vsoed_train_params))

del vsoed_train_params['actor_lr']
del vsoed_train_params['actor_lr_scheduler_gamma']
del vsoed_train_params['critic_lr']
del vsoed_train_params['critic_lr_scheduler_gamma']
# Out:
# 2023-05-01 12:28:03 | [SOURCE] vsoed_train_params: {'n_update': 10001, 'n_newtraj': 1000, 'n_batch': 10000, 'n_buffer_init': 20000, 'n_buffer_max': 1000000, 'buffer_device': device(type='cuda'), 'discount': 1, 'encoder_actor_optimizer': None, 'encoder_actor_lr_scheduler': None, 'encoder_critic_optimizer': None, 'encoder_critic_lr_scheduler': None, 'actor_lr': 0.001, 'actor_optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# ), 'actor_lr_scheduler_gamma': 0.9999, 'actor_lr_scheduler': <torch.optim.lr_scheduler.ExponentialLR object at 0x15443d9da430>, 'n_critic_update': 5, 'critic_lr': 0.001, 'critic_optimizer': Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     initial_lr: 0.001
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# ), 'critic_lr_scheduler_gamma': 0.9999, 'critic_lr_scheduler': <torch.optim.lr_scheduler.ExponentialLR object at 0x15443d9da340>, 'n_post_approx_update': 5, 'lr_target': 0.1, 'design_noise_scale': 0.5, 'design_noise_decay': 0.9999, 'on_policy': False, 'use_PCE': False, 'use_PCE_incre': None, 'n_contrastive_sample': None, 'transition': 10000, 'frozen': -1, 'log_every': 100, 'dowel': <module 'dowel' from '/home/wgshen/.local/lib/python3.9/site-packages/dowel/__init__.py'>, 'save_every': 1000, 'save_path': '/scratch/xhuan_root/xhuan1/wgshen/vsOED/experiments/source_1model_10stage_1incre_GMM/', 'restart': False}

# %%
try:
    for _ in range(100):
        dowel.logger.pop_prefix()
except:
    pass
dowel.logger.push_prefix('[SOURCE] ')
set_random_seed(random_state)
vsoed.train(**vsoed_train_params)
# Out:
# logposts tensor(-7.0174, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:28:04 | [SOURCE] epoch #0 | Total time 0.24 s
# 2023-05-01 12:28:04 | [SOURCE] epoch #0 | Epoch time 0.20 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.07776777446269989, 0.04187110438942909]
# Design/StdDesign          [0.0229748897254467, 0.027477284893393517]
# Epoch                     0
# ReplayBuffer/buffer_size  20000
# Reward/MeanReward         -2.5750226974487305
# Reward/StdReward          3.0332999229431152
# ------------------------  -------------------------------------------
# logposts tensor(-5.3296, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:28:22 | [SOURCE] epoch #100 | Total time 18.61 s
# 2023-05-01 12:28:22 | [SOURCE] epoch #100 | Epoch time 0.18 s
# ------------------------  ----------------------------------------
# Design/MeanDesign         [3.5814566612243652, 3.939265251159668]
# Design/StdDesign          [0.6352999806404114, 0.1556810438632965]
# Epoch                     100
# ReplayBuffer/buffer_size  120000
# Reward/MeanReward         0.23427610099315643
# Reward/StdReward          0.5618321895599365
# ------------------------  ----------------------------------------
# logposts tensor(-4.3473, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:28:40 | [SOURCE] epoch #200 | Total time 36.93 s
# 2023-05-01 12:28:40 | [SOURCE] epoch #200 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.17878393828868866, -0.6431918740272522]
# Design/StdDesign          [0.1570562720298767, 0.605045735836029]
# Epoch                     200
# ReplayBuffer/buffer_size  220000
# Reward/MeanReward         1.562289834022522
# Reward/StdReward          1.3848053216934204
# ------------------------  -------------------------------------------
# logposts tensor(-3.6914, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:28:59 | [SOURCE] epoch #300 | Total time 55.25 s
# 2023-05-01 12:28:59 | [SOURCE] epoch #300 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.6272374987602234, -0.21758314967155457]
# Design/StdDesign          [0.8228003978729248, 0.938579797744751]
# Epoch                     300
# ReplayBuffer/buffer_size  320000
# Reward/MeanReward         1.9830108880996704
# Reward/StdReward          1.6767864227294922
# ------------------------  -------------------------------------------
# logposts tensor(-3.2693, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:29:17 | [SOURCE] epoch #400 | Total time 73.56 s
# 2023-05-01 12:29:17 | [SOURCE] epoch #400 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.6602829098701477, -0.23912948369979858]
# Design/StdDesign          [0.8434973359107971, 0.724420428276062]
# Epoch                     400
# ReplayBuffer/buffer_size  420000
# Reward/MeanReward         2.505814552307129
# Reward/StdReward          1.601189374923706
# ------------------------  -------------------------------------------
# logposts tensor(-2.9907, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:29:35 | [SOURCE] epoch #500 | Total time 91.89 s
# 2023-05-01 12:29:35 | [SOURCE] epoch #500 | Epoch time 0.18 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [-0.6180241703987122, -0.202201709151268]
# Design/StdDesign          [0.8694411516189575, 0.835829496383667]
# Epoch                     500
# ReplayBuffer/buffer_size  520000
# Reward/MeanReward         2.6157286167144775
# Reward/StdReward          1.746689796447754
# ------------------------  -----------------------------------------
# logposts tensor(-2.8300, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:29:54 | [SOURCE] epoch #600 | Total time 110.23 s
# 2023-05-01 12:29:54 | [SOURCE] epoch #600 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.5049201846122742, -0.16567657887935638]
# Design/StdDesign          [0.8571078777313232, 0.8259233832359314]
# Epoch                     600
# ReplayBuffer/buffer_size  620000
# Reward/MeanReward         2.9554030895233154
# Reward/StdReward          1.72150456905365
# ------------------------  -------------------------------------------
# logposts tensor(-2.6726, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:30:12 | [SOURCE] epoch #700 | Total time 128.60 s
# 2023-05-01 12:30:12 | [SOURCE] epoch #700 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.37512829899787903, -0.13659518957138062]
# Design/StdDesign          [0.8750947713851929, 0.8129115700721741]
# Epoch                     700
# ReplayBuffer/buffer_size  720000
# Reward/MeanReward         2.998162031173706
# Reward/StdReward          1.7235023975372314
# ------------------------  --------------------------------------------
# logposts tensor(-2.5320, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:30:30 | [SOURCE] epoch #800 | Total time 147.00 s
# 2023-05-01 12:30:30 | [SOURCE] epoch #800 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.34010985493659973, -0.22826552391052246]
# Design/StdDesign          [0.8797304630279541, 0.8296586871147156]
# Epoch                     800
# ReplayBuffer/buffer_size  820000
# Reward/MeanReward         3.23115873336792
# Reward/StdReward          1.8119219541549683
# ------------------------  --------------------------------------------
# logposts tensor(-2.4219, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:30:49 | [SOURCE] epoch #900 | Total time 165.40 s
# 2023-05-01 12:30:49 | [SOURCE] epoch #900 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.29247909784317017, -0.20043563842773438]
# Design/StdDesign          [0.8872897028923035, 0.8756360411643982]
# Epoch                     900
# ReplayBuffer/buffer_size  920000
# Reward/MeanReward         3.237398624420166
# Reward/StdReward          1.9030731916427612
# ------------------------  --------------------------------------------
# logposts tensor(-2.3318, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:31:07 | [SOURCE] epoch #1000 | Total time 183.81 s
# 2023-05-01 12:31:07 | [SOURCE] epoch #1000 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.19006791710853577, -0.18305766582489014]
# Design/StdDesign          [0.8501113057136536, 0.9088549613952637]
# Epoch                     1000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.3417487144470215
# Reward/StdReward          2.054638385772705
# ------------------------  --------------------------------------------
# logposts tensor(-2.2138, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:31:26 | [SOURCE] epoch #1100 | Total time 202.21 s
# 2023-05-01 12:31:26 | [SOURCE] epoch #1100 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.16773934662342072, -0.002513265237212181]
# Design/StdDesign          [0.9130945801734924, 0.8028910160064697]
# Epoch                     1100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.312105178833008
# Reward/StdReward          2.013526201248169
# ------------------------  ---------------------------------------------
# logposts tensor(-2.1038, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:31:44 | [SOURCE] epoch #1200 | Total time 220.62 s
# 2023-05-01 12:31:44 | [SOURCE] epoch #1200 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.2033843845129013, -0.03452759608626366]
# Design/StdDesign          [0.8720596432685852, 0.8551102876663208]
# Epoch                     1200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.399982213973999
# Reward/StdReward          1.964943766593933
# ------------------------  -------------------------------------------
# logposts tensor(-2.0303, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:32:02 | [SOURCE] epoch #1300 | Total time 239.05 s
# 2023-05-01 12:32:02 | [SOURCE] epoch #1300 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.1330547034740448, -0.07002090662717819]
# Design/StdDesign          [0.9112679362297058, 0.8598490357398987]
# Epoch                     1300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.540123224258423
# Reward/StdReward          1.92921781539917
# ------------------------  -------------------------------------------
# logposts tensor(-1.9077, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:32:21 | [SOURCE] epoch #1400 | Total time 257.46 s
# 2023-05-01 12:32:21 | [SOURCE] epoch #1400 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.25329816341400146, 0.04894207790493965]
# Design/StdDesign          [0.9624555706977844, 0.8537960052490234]
# Epoch                     1400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.4914298057556152
# Reward/StdReward          1.998653531074524
# ------------------------  -------------------------------------------
# logposts tensor(-1.8686, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:32:39 | [SOURCE] epoch #1500 | Total time 275.88 s
# 2023-05-01 12:32:39 | [SOURCE] epoch #1500 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.02989780157804489, -0.05051518976688385]
# Design/StdDesign          [0.8607624173164368, 0.8481508493423462]
# Epoch                     1500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.5665407180786133
# Reward/StdReward          2.111799955368042
# ------------------------  --------------------------------------------
# logposts tensor(-1.7999, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:32:58 | [SOURCE] epoch #1600 | Total time 294.30 s
# 2023-05-01 12:32:58 | [SOURCE] epoch #1600 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.24330133199691772, 0.028070421889424324]
# Design/StdDesign          [0.9496572017669678, 0.8905659914016724]
# Epoch                     1600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.6742141246795654
# Reward/StdReward          1.9922186136245728
# ------------------------  --------------------------------------------
# logposts tensor(-1.7406, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:33:16 | [SOURCE] epoch #1700 | Total time 312.73 s
# 2023-05-01 12:33:16 | [SOURCE] epoch #1700 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.05727970972657204, -0.01795469969511032]
# Design/StdDesign          [0.9293627738952637, 0.8416581153869629]
# Epoch                     1700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.6559643745422363
# Reward/StdReward          2.2086637020111084
# ------------------------  --------------------------------------------
# logposts tensor(-1.7165, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:33:35 | [SOURCE] epoch #1800 | Total time 331.11 s
# 2023-05-01 12:33:35 | [SOURCE] epoch #1800 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.041866522282361984, -0.030565569177269936]
# Design/StdDesign          [0.8565351963043213, 0.8459417223930359]
# Epoch                     1800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.6592795848846436
# Reward/StdReward          2.001155376434326
# ------------------------  ----------------------------------------------
# logposts tensor(-1.6589, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:33:53 | [SOURCE] epoch #1900 | Total time 349.53 s
# 2023-05-01 12:33:53 | [SOURCE] epoch #1900 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.09919455647468567, 0.011369912885129452]
# Design/StdDesign          [0.8556716442108154, 0.8640544414520264]
# Epoch                     1900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.915762186050415
# Reward/StdReward          2.082035541534424
# ------------------------  --------------------------------------------
# logposts tensor(-1.5699, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:34:11 | [SOURCE] epoch #2000 | Total time 367.92 s
# 2023-05-01 12:34:11 | [SOURCE] epoch #2000 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.016138961538672447, -0.07181428372859955]
# Design/StdDesign          [0.9081436991691589, 0.887639582157135]
# Epoch                     2000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.873394727706909
# Reward/StdReward          2.171870708465576
# ------------------------  ---------------------------------------------
# logposts tensor(-1.5589, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:34:30 | [SOURCE] epoch #2100 | Total time 386.33 s
# 2023-05-01 12:34:30 | [SOURCE] epoch #2100 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.11054942011833191, -0.04768829047679901]
# Design/StdDesign          [0.9468095302581787, 0.94481360912323]
# Epoch                     2100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.936034917831421
# Reward/StdReward          2.144967794418335
# ------------------------  --------------------------------------------
# logposts tensor(-1.5267, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:34:48 | [SOURCE] epoch #2200 | Total time 404.71 s
# 2023-05-01 12:34:48 | [SOURCE] epoch #2200 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.07988821715116501, -0.015511266887187958]
# Design/StdDesign          [0.9456736445426941, 0.8894290328025818]
# Epoch                     2200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.041698932647705
# Reward/StdReward          2.0525968074798584
# ------------------------  ---------------------------------------------
# logposts tensor(-1.4954, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:35:07 | [SOURCE] epoch #2300 | Total time 423.11 s
# 2023-05-01 12:35:07 | [SOURCE] epoch #2300 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.09002122282981873, -0.09556076675653458]
# Design/StdDesign          [0.9559059739112854, 0.8896504044532776]
# Epoch                     2300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.901820421218872
# Reward/StdReward          2.1583144664764404
# ------------------------  --------------------------------------------
# logposts tensor(-1.4584, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:35:25 | [SOURCE] epoch #2400 | Total time 441.48 s
# 2023-05-01 12:35:25 | [SOURCE] epoch #2400 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.05149083212018013, 0.006911547854542732]
# Design/StdDesign          [0.8901159763336182, 0.8714045286178589]
# Epoch                     2400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.036675453186035
# Reward/StdReward          2.1485705375671387
# ------------------------  --------------------------------------------
# logposts tensor(-1.4614, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:35:43 | [SOURCE] epoch #2500 | Total time 459.92 s
# 2023-05-01 12:35:43 | [SOURCE] epoch #2500 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.0246077012270689, -0.04781121015548706]
# Design/StdDesign          [0.9227716326713562, 0.8659184575080872]
# Epoch                     2500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.070545196533203
# Reward/StdReward          2.1761369705200195
# ------------------------  -------------------------------------------
# logposts tensor(-1.3769, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:36:02 | [SOURCE] epoch #2600 | Total time 478.27 s
# 2023-05-01 12:36:02 | [SOURCE] epoch #2600 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.002581322332844138, 0.010399004444479942]
# Design/StdDesign          [0.9000079035758972, 0.8613229990005493]
# Epoch                     2600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         3.968738555908203
# Reward/StdReward          2.1876981258392334
# ------------------------  ---------------------------------------------
# logposts tensor(-1.3860, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:36:20 | [SOURCE] epoch #2700 | Total time 496.62 s
# 2023-05-01 12:36:20 | [SOURCE] epoch #2700 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.06666771322488785, 0.02543466165661812]
# Design/StdDesign          [0.9519906640052795, 0.8712102174758911]
# Epoch                     2700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.184853553771973
# Reward/StdReward          2.1570751667022705
# ------------------------  -------------------------------------------
# logposts tensor(-1.3545, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:36:39 | [SOURCE] epoch #2800 | Total time 515.25 s
# 2023-05-01 12:36:39 | [SOURCE] epoch #2800 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.016660548746585846, -0.10834191739559174]
# Design/StdDesign          [0.958967924118042, 0.8815397620201111]
# Epoch                     2800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.063290596008301
# Reward/StdReward          2.192270278930664
# ------------------------  ---------------------------------------------
# logposts tensor(-1.3177, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:36:57 | [SOURCE] epoch #2900 | Total time 533.63 s
# 2023-05-01 12:36:57 | [SOURCE] epoch #2900 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.05857332795858383, -0.07299210876226425]
# Design/StdDesign          [0.9146808385848999, 0.8917434215545654]
# Epoch                     2900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.1754279136657715
# Reward/StdReward          2.107675790786743
# ------------------------  --------------------------------------------
# logposts tensor(-1.2491, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:37:15 | [SOURCE] epoch #3000 | Total time 552.00 s
# 2023-05-01 12:37:15 | [SOURCE] epoch #3000 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.05088233947753906, -0.06262645125389099]
# Design/StdDesign          [0.8939120173454285, 0.8567792773246765]
# Epoch                     3000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.165106773376465
# Reward/StdReward          2.2016749382019043
# ------------------------  -------------------------------------------
# logposts tensor(-1.2318, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:37:34 | [SOURCE] epoch #3100 | Total time 570.37 s
# 2023-05-01 12:37:34 | [SOURCE] epoch #3100 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.005115351639688015, -0.02308850735425949]
# Design/StdDesign          [0.8676244020462036, 0.8809177875518799]
# Epoch                     3100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.28716516494751
# Reward/StdReward          2.170029401779175
# ------------------------  --------------------------------------------
# logposts tensor(-1.2147, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:37:52 | [SOURCE] epoch #3200 | Total time 588.78 s
# 2023-05-01 12:37:52 | [SOURCE] epoch #3200 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.049710214138031006, -0.11514594405889511]
# Design/StdDesign          [0.905006468296051, 0.8302584886550903]
# Epoch                     3200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.1400465965271
# Reward/StdReward          2.1133337020874023
# ------------------------  ---------------------------------------------
# logposts tensor(-1.1893, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:38:11 | [SOURCE] epoch #3300 | Total time 607.18 s
# 2023-05-01 12:38:11 | [SOURCE] epoch #3300 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.10398679226636887, -0.09866281598806381]
# Design/StdDesign          [0.9250417947769165, 0.8603224754333496]
# Epoch                     3300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.311249256134033
# Reward/StdReward          2.215895175933838
# ------------------------  --------------------------------------------
# logposts tensor(-1.1774, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:38:29 | [SOURCE] epoch #3400 | Total time 625.58 s
# 2023-05-01 12:38:29 | [SOURCE] epoch #3400 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.04487461969256401, -0.03748474642634392]
# Design/StdDesign          [0.912164568901062, 0.8938606381416321]
# Epoch                     3400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.313838005065918
# Reward/StdReward          2.194483995437622
# ------------------------  --------------------------------------------
# logposts tensor(-1.1718, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:38:47 | [SOURCE] epoch #3500 | Total time 643.99 s
# 2023-05-01 12:38:47 | [SOURCE] epoch #3500 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.07761016488075256, -0.05987650156021118]
# Design/StdDesign          [0.917312502861023, 0.8515286445617676]
# Epoch                     3500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.199319362640381
# Reward/StdReward          2.191300630569458
# ------------------------  --------------------------------------------
# logposts tensor(-1.1215, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:39:06 | [SOURCE] epoch #3600 | Total time 662.38 s
# 2023-05-01 12:39:06 | [SOURCE] epoch #3600 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.07044447213411331, -0.05908505618572235]
# Design/StdDesign          [0.9349575042724609, 0.8785764575004578]
# Epoch                     3600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.420186519622803
# Reward/StdReward          2.214653491973877
# ------------------------  --------------------------------------------
# logposts tensor(-1.0566, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:39:24 | [SOURCE] epoch #3700 | Total time 680.77 s
# 2023-05-01 12:39:24 | [SOURCE] epoch #3700 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.1167859360575676, -0.08760253340005875]
# Design/StdDesign          [0.9051337838172913, 0.8554600477218628]
# Epoch                     3700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.305568695068359
# Reward/StdReward          2.1653246879577637
# ------------------------  -------------------------------------------
# logposts tensor(-1.0835, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:39:43 | [SOURCE] epoch #3800 | Total time 699.18 s
# 2023-05-01 12:39:43 | [SOURCE] epoch #3800 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.040014103055000305, -0.07326241582632065]
# Design/StdDesign          [0.8915898203849792, 0.8826960921287537]
# Epoch                     3800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.326635837554932
# Reward/StdReward          2.28922176361084
# ------------------------  ---------------------------------------------
# logposts tensor(-1.0510, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:40:01 | [SOURCE] epoch #3900 | Total time 717.60 s
# 2023-05-01 12:40:01 | [SOURCE] epoch #3900 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.03903869912028313, -0.10142825543880463]
# Design/StdDesign          [0.9184476137161255, 0.8834344744682312]
# Epoch                     3900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.357285499572754
# Reward/StdReward          2.1589298248291016
# ------------------------  --------------------------------------------
# logposts tensor(-1.0420, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:40:19 | [SOURCE] epoch #4000 | Total time 736.01 s
# 2023-05-01 12:40:19 | [SOURCE] epoch #4000 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [-0.02734416350722313, 0.00912107527256012]
# Design/StdDesign          [0.9123433232307434, 0.8737764954566956]
# Epoch                     4000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.431082248687744
# Reward/StdReward          2.189952850341797
# ------------------------  -------------------------------------------
# logposts tensor(-1.0062, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:40:38 | [SOURCE] epoch #4100 | Total time 754.43 s
# 2023-05-01 12:40:38 | [SOURCE] epoch #4100 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.08052583783864975, -0.07636170089244843]
# Design/StdDesign          [0.9238322973251343, 0.8885890245437622]
# Epoch                     4100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.388423919677734
# Reward/StdReward          2.3259191513061523
# ------------------------  --------------------------------------------
# logposts tensor(-1.0120, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:40:56 | [SOURCE] epoch #4200 | Total time 772.84 s
# 2023-05-01 12:40:56 | [SOURCE] epoch #4200 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.08386463671922684, -0.14202380180358887]
# Design/StdDesign          [0.9446582794189453, 0.8717030882835388]
# Epoch                     4200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.451409816741943
# Reward/StdReward          2.263524055480957
# ------------------------  --------------------------------------------
# logposts tensor(-0.9698, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:41:15 | [SOURCE] epoch #4300 | Total time 791.24 s
# 2023-05-01 12:41:15 | [SOURCE] epoch #4300 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.04994450509548187, -0.06562630832195282]
# Design/StdDesign          [0.9099128842353821, 0.8685281872749329]
# Epoch                     4300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.451300144195557
# Reward/StdReward          2.3146438598632812
# ------------------------  --------------------------------------------
# logposts tensor(-0.9693, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:41:33 | [SOURCE] epoch #4400 | Total time 809.61 s
# 2023-05-01 12:41:33 | [SOURCE] epoch #4400 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.03199004381895065, -0.07348223030567169]
# Design/StdDesign          [0.9794925451278687, 0.8856685757637024]
# Epoch                     4400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.534206390380859
# Reward/StdReward          2.208245038986206
# ------------------------  -------------------------------------------
# logposts tensor(-0.9073, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:41:51 | [SOURCE] epoch #4500 | Total time 827.99 s
# 2023-05-01 12:41:51 | [SOURCE] epoch #4500 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.060526903718709946, -0.15779542922973633]
# Design/StdDesign          [0.9210190773010254, 0.8617284893989563]
# Epoch                     4500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.361063003540039
# Reward/StdReward          2.310648202896118
# ------------------------  --------------------------------------------
# logposts tensor(-0.9517, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:42:10 | [SOURCE] epoch #4600 | Total time 846.35 s
# 2023-05-01 12:42:10 | [SOURCE] epoch #4600 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.02919788658618927, 0.0023761962074786425]
# Design/StdDesign          [0.9449720978736877, 0.8926163911819458]
# Epoch                     4600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.556922435760498
# Reward/StdReward          2.234380006790161
# ------------------------  ---------------------------------------------
# logposts tensor(-0.8933, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:42:28 | [SOURCE] epoch #4700 | Total time 864.76 s
# 2023-05-01 12:42:28 | [SOURCE] epoch #4700 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.032530248165130615, -0.045996349304914474]
# Design/StdDesign          [0.9323087930679321, 0.8717856407165527]
# Epoch                     4700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.505502223968506
# Reward/StdReward          2.3173470497131348
# ------------------------  ----------------------------------------------
# logposts tensor(-0.8666, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:42:47 | [SOURCE] epoch #4800 | Total time 883.16 s
# 2023-05-01 12:42:47 | [SOURCE] epoch #4800 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.035589296370744705, -0.08011648058891296]
# Design/StdDesign          [0.9134525060653687, 0.8808287978172302]
# Epoch                     4800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.523138046264648
# Reward/StdReward          2.2356722354888916
# ------------------------  ---------------------------------------------
# logposts tensor(-0.9026, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:43:05 | [SOURCE] epoch #4900 | Total time 901.56 s
# 2023-05-01 12:43:05 | [SOURCE] epoch #4900 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.03559454530477524, -0.025857677683234215]
# Design/StdDesign          [0.9291768074035645, 0.9176559448242188]
# Epoch                     4900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.562575340270996
# Reward/StdReward          2.286807060241699
# ------------------------  --------------------------------------------
# logposts tensor(-0.8465, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:43:23 | [SOURCE] epoch #5000 | Total time 919.97 s
# 2023-05-01 12:43:23 | [SOURCE] epoch #5000 | Epoch time 0.18 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.02662249654531479, -0.0416862778365612]
# Design/StdDesign          [0.8760853409767151, 0.908406674861908]
# Epoch                     5000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.563750267028809
# Reward/StdReward          2.322504758834839
# ------------------------  ------------------------------------------
# logposts tensor(-0.8525, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:43:42 | [SOURCE] epoch #5100 | Total time 938.37 s
# 2023-05-01 12:43:42 | [SOURCE] epoch #5100 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.033746734261512756, -0.05794822424650192]
# Design/StdDesign          [0.9774113297462463, 0.9190226793289185]
# Epoch                     5100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.508247375488281
# Reward/StdReward          2.4245572090148926
# ------------------------  ---------------------------------------------
# logposts tensor(-0.8099, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:44:00 | [SOURCE] epoch #5200 | Total time 956.80 s
# 2023-05-01 12:44:00 | [SOURCE] epoch #5200 | Epoch time 0.20 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.049855928868055344, -0.05417521670460701]
# Design/StdDesign          [0.9496458172798157, 0.8964533805847168]
# Epoch                     5200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.609630107879639
# Reward/StdReward          2.3245813846588135
# ------------------------  --------------------------------------------
# logposts tensor(-0.7795, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:44:19 | [SOURCE] epoch #5300 | Total time 975.15 s
# 2023-05-01 12:44:19 | [SOURCE] epoch #5300 | Epoch time 0.18 s
# ------------------------  -----------------------------------------------
# Design/MeanDesign         [-0.0061871628277003765, -0.045468855649232864]
# Design/StdDesign          [0.9315294027328491, 0.9204774498939514]
# Epoch                     5300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.682562828063965
# Reward/StdReward          2.4267077445983887
# ------------------------  -----------------------------------------------
# logposts tensor(-0.7939, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:44:37 | [SOURCE] epoch #5400 | Total time 993.51 s
# 2023-05-01 12:44:37 | [SOURCE] epoch #5400 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.007315038237720728, -0.13106630742549896]
# Design/StdDesign          [0.9287558794021606, 0.8777194619178772]
# Epoch                     5400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.75514030456543
# Reward/StdReward          2.27959942817688
# ------------------------  ---------------------------------------------
# logposts tensor(-0.7782, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:44:55 | [SOURCE] epoch #5500 | Total time 1011.88 s
# 2023-05-01 12:44:55 | [SOURCE] epoch #5500 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.005175055004656315, 0.004946551285684109]
# Design/StdDesign          [0.8774393796920776, 0.9077150225639343]
# Epoch                     5500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.622580528259277
# Reward/StdReward          2.331453323364258
# ------------------------  --------------------------------------------
# logposts tensor(-0.7220, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:45:14 | [SOURCE] epoch #5600 | Total time 1030.23 s
# 2023-05-01 12:45:14 | [SOURCE] epoch #5600 | Epoch time 0.18 s
# ------------------------  -----------------------------------------
# Design/MeanDesign         [0.049244225025177, -0.05876634269952774]
# Design/StdDesign          [0.907040536403656, 0.9032360315322876]
# Epoch                     5600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.710864067077637
# Reward/StdReward          2.365135669708252
# ------------------------  -----------------------------------------
# logposts tensor(-0.7549, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:45:32 | [SOURCE] epoch #5700 | Total time 1048.60 s
# 2023-05-01 12:45:32 | [SOURCE] epoch #5700 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.02958240918815136, -0.08368659019470215]
# Design/StdDesign          [0.9189023971557617, 0.9074504971504211]
# Epoch                     5700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.623718738555908
# Reward/StdReward          2.354789972305298
# ------------------------  --------------------------------------------
# logposts tensor(-0.6831, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:45:50 | [SOURCE] epoch #5800 | Total time 1066.96 s
# 2023-05-01 12:45:50 | [SOURCE] epoch #5800 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.008080710656940937, -0.05394510179758072]
# Design/StdDesign          [0.8742659687995911, 0.8763933181762695]
# Epoch                     5800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.812519073486328
# Reward/StdReward          2.240217685699463
# ------------------------  --------------------------------------------
# logposts tensor(-0.6531, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:46:09 | [SOURCE] epoch #5900 | Total time 1085.35 s
# 2023-05-01 12:46:09 | [SOURCE] epoch #5900 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.00946659967303276, -0.028199834749102592]
# Design/StdDesign          [0.8997995853424072, 0.9060488939285278]
# Epoch                     5900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.834360599517822
# Reward/StdReward          2.3628945350646973
# ------------------------  --------------------------------------------
# logposts tensor(-0.6594, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:46:27 | [SOURCE] epoch #6000 | Total time 1103.73 s
# 2023-05-01 12:46:27 | [SOURCE] epoch #6000 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.025352369993925095, 0.004110107198357582]
# Design/StdDesign          [0.8737062215805054, 0.9183415770530701]
# Epoch                     6000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.81436014175415
# Reward/StdReward          2.371387481689453
# ------------------------  ---------------------------------------------
# logposts tensor(-0.6796, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:46:46 | [SOURCE] epoch #6100 | Total time 1122.11 s
# 2023-05-01 12:46:46 | [SOURCE] epoch #6100 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.028704049065709114, -0.04200391843914986]
# Design/StdDesign          [0.913791835308075, 0.8732749223709106]
# Epoch                     6100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.726620197296143
# Reward/StdReward          2.3047757148742676
# ------------------------  --------------------------------------------
# logposts tensor(-0.6040, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:47:04 | [SOURCE] epoch #6200 | Total time 1140.50 s
# 2023-05-01 12:47:04 | [SOURCE] epoch #6200 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.025930220261216164, -0.05831276252865791]
# Design/StdDesign          [0.8608651757240295, 0.9092115759849548]
# Epoch                     6200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.822625637054443
# Reward/StdReward          2.392388105392456
# ------------------------  --------------------------------------------
# logposts tensor(-0.6047, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:47:22 | [SOURCE] epoch #6300 | Total time 1158.87 s
# 2023-05-01 12:47:22 | [SOURCE] epoch #6300 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.009108118712902069, -0.0683717355132103]
# Design/StdDesign          [0.9002108573913574, 0.9127428531646729]
# Epoch                     6300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.832580089569092
# Reward/StdReward          2.3762712478637695
# ------------------------  -------------------------------------------
# logposts tensor(-0.6010, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:47:41 | [SOURCE] epoch #6400 | Total time 1177.27 s
# 2023-05-01 12:47:41 | [SOURCE] epoch #6400 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.007083498872816563, -0.09250593185424805]
# Design/StdDesign          [0.922126829624176, 0.883198082447052]
# Epoch                     6400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.8715434074401855
# Reward/StdReward          2.3759236335754395
# ------------------------  --------------------------------------------
# logposts tensor(-0.6101, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:47:59 | [SOURCE] epoch #6500 | Total time 1195.67 s
# 2023-05-01 12:47:59 | [SOURCE] epoch #6500 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.0015123733319342136, -0.06865344196557999]
# Design/StdDesign          [0.9047450423240662, 0.9080024361610413]
# Epoch                     6500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.920260906219482
# Reward/StdReward          2.3090715408325195
# ------------------------  ----------------------------------------------
# logposts tensor(-0.5649, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:48:18 | [SOURCE] epoch #6600 | Total time 1214.08 s
# 2023-05-01 12:48:18 | [SOURCE] epoch #6600 | Epoch time 0.19 s
# ------------------------  ------------------------------------------
# Design/MeanDesign         [0.013025845400989056, 0.0114281065762043]
# Design/StdDesign          [0.8999752402305603, 0.9116837382316589]
# Epoch                     6600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.9846930503845215
# Reward/StdReward          2.2869009971618652
# ------------------------  ------------------------------------------
# logposts tensor(-0.4965, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:48:36 | [SOURCE] epoch #6700 | Total time 1232.48 s
# 2023-05-01 12:48:36 | [SOURCE] epoch #6700 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.022727850824594498, -0.04688055440783501]
# Design/StdDesign          [0.9146969318389893, 0.9020403027534485]
# Epoch                     6700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.801945209503174
# Reward/StdReward          2.349155902862549
# ------------------------  ---------------------------------------------
# logposts tensor(-0.4690, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:48:54 | [SOURCE] epoch #6800 | Total time 1250.88 s
# 2023-05-01 12:48:54 | [SOURCE] epoch #6800 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.050524745136499405, -0.012698955833911896]
# Design/StdDesign          [0.8948329091072083, 0.8927064538002014]
# Epoch                     6800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.946346282958984
# Reward/StdReward          2.4440674781799316
# ------------------------  ----------------------------------------------
# logposts tensor(-0.4983, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:49:13 | [SOURCE] epoch #6900 | Total time 1269.29 s
# 2023-05-01 12:49:13 | [SOURCE] epoch #6900 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.06729580461978912, 0.00034948118263855577]
# Design/StdDesign          [0.905683696269989, 0.9061065316200256]
# Epoch                     6900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         4.80332088470459
# Reward/StdReward          2.4092841148376465
# ------------------------  ----------------------------------------------
# logposts tensor(-0.4682, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:49:31 | [SOURCE] epoch #7000 | Total time 1287.65 s
# 2023-05-01 12:49:31 | [SOURCE] epoch #7000 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.02412787638604641, -0.012970996089279652]
# Design/StdDesign          [0.89943528175354, 0.9009500741958618]
# Epoch                     7000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.049342155456543
# Reward/StdReward          2.465064525604248
# ------------------------  ---------------------------------------------
# logposts tensor(-0.4394, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:49:50 | [SOURCE] epoch #7100 | Total time 1306.08 s
# 2023-05-01 12:49:50 | [SOURCE] epoch #7100 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.10366176813840866, -0.059212975203990936]
# Design/StdDesign          [0.9272130727767944, 0.8820931315422058]
# Epoch                     7100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.124893665313721
# Reward/StdReward          2.4402313232421875
# ------------------------  ---------------------------------------------
# logposts tensor(-0.4388, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:50:08 | [SOURCE] epoch #7200 | Total time 1324.46 s
# 2023-05-01 12:50:08 | [SOURCE] epoch #7200 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.04049130156636238, -0.037810660898685455]
# Design/StdDesign          [0.8746617436408997, 0.8812723755836487]
# Epoch                     7200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.013974666595459
# Reward/StdReward          2.3606321811676025
# ------------------------  --------------------------------------------
# logposts tensor(-0.4491, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:50:26 | [SOURCE] epoch #7300 | Total time 1342.84 s
# 2023-05-01 12:50:26 | [SOURCE] epoch #7300 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.017879748716950417, -0.06108638271689415]
# Design/StdDesign          [0.9067996740341187, 0.9073209762573242]
# Epoch                     7300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.143112659454346
# Reward/StdReward          2.411707639694214
# ------------------------  --------------------------------------------
# logposts tensor(-0.3875, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:50:45 | [SOURCE] epoch #7400 | Total time 1361.22 s
# 2023-05-01 12:50:45 | [SOURCE] epoch #7400 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.014816846698522568, -0.11237261444330215]
# Design/StdDesign          [0.915799081325531, 0.9022802114486694]
# Epoch                     7400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.012217998504639
# Reward/StdReward          2.5663743019104004
# ------------------------  --------------------------------------------
# logposts tensor(-0.3844, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:51:03 | [SOURCE] epoch #7500 | Total time 1379.62 s
# 2023-05-01 12:51:03 | [SOURCE] epoch #7500 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.008514990098774433, -0.019982287660241127]
# Design/StdDesign          [0.9188278913497925, 0.8963665962219238]
# Epoch                     7500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.116408348083496
# Reward/StdReward          2.3832290172576904
# ------------------------  ----------------------------------------------
# logposts tensor(-0.3352, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:51:21 | [SOURCE] epoch #7600 | Total time 1398.03 s
# 2023-05-01 12:51:21 | [SOURCE] epoch #7600 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.07083678990602493, -0.03720565885305405]
# Design/StdDesign          [0.9188540577888489, 0.9092406034469604]
# Epoch                     7600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.090609550476074
# Reward/StdReward          2.362511396408081
# ------------------------  -------------------------------------------
# logposts tensor(-0.3318, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:51:40 | [SOURCE] epoch #7700 | Total time 1416.44 s
# 2023-05-01 12:51:40 | [SOURCE] epoch #7700 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.03369952738285065, -0.09222515672445297]
# Design/StdDesign          [0.9121410250663757, 0.9089621901512146]
# Epoch                     7700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.263487815856934
# Reward/StdReward          2.3446435928344727
# ------------------------  -------------------------------------------
# logposts tensor(-0.2972, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:51:58 | [SOURCE] epoch #7800 | Total time 1434.83 s
# 2023-05-01 12:51:58 | [SOURCE] epoch #7800 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.04357403516769409, -0.028823155909776688]
# Design/StdDesign          [0.9088415503501892, 0.8889830112457275]
# Epoch                     7800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.107761383056641
# Reward/StdReward          2.5020382404327393
# ------------------------  --------------------------------------------
# logposts tensor(-0.3055, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:52:17 | [SOURCE] epoch #7900 | Total time 1453.19 s
# 2023-05-01 12:52:17 | [SOURCE] epoch #7900 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.010721671395003796, -0.07117944955825806]
# Design/StdDesign          [0.9277980327606201, 0.8865340948104858]
# Epoch                     7900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.142241477966309
# Reward/StdReward          2.4474740028381348
# ------------------------  --------------------------------------------
# logposts tensor(-0.2459, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:52:35 | [SOURCE] epoch #8000 | Total time 1471.55 s
# 2023-05-01 12:52:35 | [SOURCE] epoch #8000 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.028814898803830147, -0.03388787806034088]
# Design/StdDesign          [0.928173303604126, 0.8776140809059143]
# Epoch                     8000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.255215167999268
# Reward/StdReward          2.4556357860565186
# ------------------------  --------------------------------------------
# logposts tensor(-0.3012, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:52:53 | [SOURCE] epoch #8100 | Total time 1489.92 s
# 2023-05-01 12:52:53 | [SOURCE] epoch #8100 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.04797104001045227, -0.05306980386376381]
# Design/StdDesign          [0.9473562836647034, 0.9098466634750366]
# Epoch                     8100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.2849812507629395
# Reward/StdReward          2.4353439807891846
# ------------------------  --------------------------------------------
# logposts tensor(-0.2869, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:53:12 | [SOURCE] epoch #8200 | Total time 1508.36 s
# 2023-05-01 12:53:12 | [SOURCE] epoch #8200 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.0684489980340004, -0.011429241858422756]
# Design/StdDesign          [0.9482325911521912, 0.9050679802894592]
# Epoch                     8200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.293778419494629
# Reward/StdReward          2.53216552734375
# ------------------------  -------------------------------------------
# logposts tensor(-0.2285, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:53:30 | [SOURCE] epoch #8300 | Total time 1526.79 s
# 2023-05-01 12:53:30 | [SOURCE] epoch #8300 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.0245214831084013, -0.048354387283325195]
# Design/StdDesign          [0.9650623798370361, 0.9343435168266296]
# Epoch                     8300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.0708441734313965
# Reward/StdReward          2.6209042072296143
# ------------------------  --------------------------------------------
# logposts tensor(-0.2164, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:53:49 | [SOURCE] epoch #8400 | Total time 1545.17 s
# 2023-05-01 12:53:49 | [SOURCE] epoch #8400 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.04647524282336235, -0.015739087015390396]
# Design/StdDesign          [0.944456934928894, 0.901637852191925]
# Epoch                     8400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.291658401489258
# Reward/StdReward          2.5798420906066895
# ------------------------  --------------------------------------------
# logposts tensor(-0.2222, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:54:07 | [SOURCE] epoch #8500 | Total time 1563.53 s
# 2023-05-01 12:54:07 | [SOURCE] epoch #8500 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [0.018520601093769073, -0.013034338131546974]
# Design/StdDesign          [0.9226967096328735, 0.8724967837333679]
# Epoch                     8500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.231899261474609
# Reward/StdReward          2.473144769668579
# ------------------------  ---------------------------------------------
# logposts tensor(-0.1861, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:54:25 | [SOURCE] epoch #8600 | Total time 1581.88 s
# 2023-05-01 12:54:25 | [SOURCE] epoch #8600 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [0.019715221598744392, -0.050836171954870224]
# Design/StdDesign          [0.9213350415229797, 0.8875096440315247]
# Epoch                     8600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.0828938484191895
# Reward/StdReward          2.52154803276062
# ------------------------  ---------------------------------------------
# logposts tensor(-0.1855, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:54:44 | [SOURCE] epoch #8700 | Total time 1600.24 s
# 2023-05-01 12:54:44 | [SOURCE] epoch #8700 | Epoch time 0.18 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [0.0016727508045732975, -0.04291071370244026]
# Design/StdDesign          [0.9395835995674133, 0.8669276237487793]
# Epoch                     8700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.348691463470459
# Reward/StdReward          2.5564701557159424
# ------------------------  ---------------------------------------------
# logposts tensor(-0.1495, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:55:02 | [SOURCE] epoch #8800 | Total time 1618.64 s
# 2023-05-01 12:55:02 | [SOURCE] epoch #8800 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.045441996306180954, -0.0445866584777832]
# Design/StdDesign          [0.9250624775886536, 0.9056189656257629]
# Epoch                     8800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.4178266525268555
# Reward/StdReward          2.558987617492676
# ------------------------  -------------------------------------------
# logposts tensor(-0.1475, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:55:20 | [SOURCE] epoch #8900 | Total time 1637.02 s
# 2023-05-01 12:55:20 | [SOURCE] epoch #8900 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.022337747737765312, -0.08517767488956451]
# Design/StdDesign          [0.9296107292175293, 0.893315315246582]
# Epoch                     8900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.240694522857666
# Reward/StdReward          2.5358409881591797
# ------------------------  --------------------------------------------
# logposts tensor(-0.1012, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:55:39 | [SOURCE] epoch #9000 | Total time 1655.45 s
# 2023-05-01 12:55:39 | [SOURCE] epoch #9000 | Epoch time 0.19 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.06718762218952179, -0.06590177118778229]
# Design/StdDesign          [0.9301127195358276, 0.8889808654785156]
# Epoch                     9000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.485586643218994
# Reward/StdReward          2.376232385635376
# ------------------------  -------------------------------------------
# logposts tensor(-0.0827, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:55:57 | [SOURCE] epoch #9100 | Total time 1673.85 s
# 2023-05-01 12:55:57 | [SOURCE] epoch #9100 | Epoch time 0.18 s
# ------------------------  -------------------------------------------
# Design/MeanDesign         [0.03364402800798416, -0.11974404007196426]
# Design/StdDesign          [0.923547625541687, 0.8860886693000793]
# Epoch                     9100
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.232239723205566
# Reward/StdReward          2.544386625289917
# ------------------------  -------------------------------------------
# logposts tensor(-0.0917, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:56:16 | [SOURCE] epoch #9200 | Total time 1692.24 s
# 2023-05-01 12:56:16 | [SOURCE] epoch #9200 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.013646377250552177, -0.0365389883518219]
# Design/StdDesign          [0.9478598237037659, 0.9103127717971802]
# Epoch                     9200
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.372409820556641
# Reward/StdReward          2.6184496879577637
# ------------------------  --------------------------------------------
# logposts tensor(-0.0663, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:56:34 | [SOURCE] epoch #9300 | Total time 1710.65 s
# 2023-05-01 12:56:34 | [SOURCE] epoch #9300 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [-0.01912670210003853, -0.07229062169790268]
# Design/StdDesign          [0.9107805490493774, 0.8745433688163757]
# Epoch                     9300
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.503350257873535
# Reward/StdReward          2.460632085800171
# ------------------------  --------------------------------------------
# logposts tensor(-0.0501, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:56:52 | [SOURCE] epoch #9400 | Total time 1729.04 s
# 2023-05-01 12:56:52 | [SOURCE] epoch #9400 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.058299362659454346, -0.07435613125562668]
# Design/StdDesign          [0.9705483317375183, 0.90139240026474]
# Epoch                     9400
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.324292182922363
# Reward/StdReward          2.5497655868530273
# ------------------------  ---------------------------------------------
# logposts tensor(-0.0887, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:57:11 | [SOURCE] epoch #9500 | Total time 1747.47 s
# 2023-05-01 12:57:11 | [SOURCE] epoch #9500 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.002804331947118044, -0.03110099397599697]
# Design/StdDesign          [0.9609615802764893, 0.9099835753440857]
# Epoch                     9500
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.528684139251709
# Reward/StdReward          2.663982629776001
# ------------------------  ---------------------------------------------
# logposts tensor(-0.0306, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:57:29 | [SOURCE] epoch #9600 | Total time 1765.91 s
# 2023-05-01 12:57:29 | [SOURCE] epoch #9600 | Epoch time 0.19 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.03599545359611511, -0.053177572786808014]
# Design/StdDesign          [0.9017305970191956, 0.8839998245239258]
# Epoch                     9600
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.44127893447876
# Reward/StdReward          2.4897687435150146
# ------------------------  --------------------------------------------
# logposts tensor(0.0009, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:57:48 | [SOURCE] epoch #9700 | Total time 1784.33 s
# 2023-05-01 12:57:48 | [SOURCE] epoch #9700 | Epoch time 0.19 s
# ------------------------  ---------------------------------------------
# Design/MeanDesign         [-0.004628527909517288, -0.10360788553953171]
# Design/StdDesign          [0.9107708930969238, 0.8903883099555969]
# Epoch                     9700
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.510024547576904
# Reward/StdReward          2.641104221343994
# ------------------------  ---------------------------------------------
# logposts tensor(-1.1249e-05, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:58:06 | [SOURCE] epoch #9800 | Total time 1802.73 s
# 2023-05-01 12:58:06 | [SOURCE] epoch #9800 | Epoch time 0.18 s
# ------------------------  --------------------------------------------
# Design/MeanDesign         [0.01433920580893755, -0.014329138211905956]
# Design/StdDesign          [0.9250912070274353, 0.898478627204895]
# Epoch                     9800
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.4944748878479
# Reward/StdReward          2.4222793579101562
# ------------------------  --------------------------------------------
# logposts tensor(0.0178, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:58:25 | [SOURCE] epoch #9900 | Total time 1821.13 s
# 2023-05-01 12:58:25 | [SOURCE] epoch #9900 | Epoch time 0.19 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.00016981505905278027, -0.0807129293680191]
# Design/StdDesign          [0.9465141892433167, 0.9063433408737183]
# Epoch                     9900
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.510712623596191
# Reward/StdReward          2.5513882637023926
# ------------------------  ----------------------------------------------
# logposts tensor(0.0563, device='cuda:0', grad_fn=<MeanBackward0>)
# 2023-05-01 12:58:43 | [SOURCE] epoch #10000 | Total time 1839.52 s
# 2023-05-01 12:58:43 | [SOURCE] epoch #10000 | Epoch time 0.18 s
# ------------------------  ----------------------------------------------
# Design/MeanDesign         [-0.001354263280518353, -0.030605699867010117]
# Design/StdDesign          [0.9551798701286316, 0.9144515991210938]
# Epoch                     10000
# ReplayBuffer/buffer_size  1000000
# Reward/MeanReward         5.426624298095703
# Reward/StdReward          2.551719903945923
# ------------------------  ----------------------------------------------

# %%
plt.figure(figsize=(10, 4))
plt.plot(vsoed.update_hist[:])
plt.xlabel('update', fontsize=20)
plt.ylabel('averaged reward', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.grid(linestyle='--')

# %%
set_random_seed(42)
ret = vsoed.asses(2000, n_contrastive_sample=int(1e6), return_all=True)
averaged_reward = ret['averaged_reward']
params = ret['params']
ds_hist = ret['ds_hist']
ys_hist = ret['ys_hist']
rewards_hist = ret['rewards_hist']
averaged_reward
# Out:
# 100%|██████████| 2000/2000 [00:20<00:00, 96.15it/s]
# 7.403656482696533

# %%
ds_hist[30]
# Out:
# tensor([[-0.7289,  0.6698],
#         [ 0.8817,  1.2228],
#         [ 1.4341,  0.6463],
#         [ 1.0733, -1.2968],
#         [-0.8485, -0.9864],
#         [ 0.3985,  0.4226],
#         [ 0.2888, -0.5700],
#         [ 0.0655, -0.3715],
#         [-0.0392, -0.7437],
#         [ 0.2918, -0.7857]], device='cuda:0')

# %%
rewards_hist[:, :5].sum(-1).mean()
# Out:
# tensor(3.6108, device='cuda:0')

# %%
p_max = torch.arange(1, vsoed.n_buffer_max + 1).to(torch.float32)
l_buffer = 1000000
p = p_max[:l_buffer]
p /= p.sum()
idxs_pick = torch.multinomial(p, vsoed.n_batch, replacement=False)

# %%
plt.hist(idxs_pick.cpu().numpy())
# Out:
# (array([ 112.,  307.,  480.,  745.,  934., 1096., 1278., 1487., 1672.,
#         1889.]),
#  array([ 10025. , 109021.9, 208018.8, 307015.7, 406012.6, 505009.5,
#         604006.4, 703003.3, 802000.2, 900997.1, 999994. ]),
#  <BarContainer object of 10 artists>)

# %%
import joblib

# %%
joblib.dump(vsoed, folder + 'itr_0.pkl')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_503473/4165733059.py in <module>
# ----> 1 joblib.dump(vsoed, folder + 'itr_0.pkl')
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     480     elif is_filename:
#     481         with open(filename, 'wb') as f:
# --> 482             NumpyPickler(f, protocol=protocol).dump(value)
#     483     else:
#     484         NumpyPickler(filename, protocol=protocol).dump(value)
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in dump(self, obj)
#     485         if self.proto >= 4:
#     486             self.framer.start_framing()
# --> 487         self.save(obj)
#     488         self.write(STOP)
#     489         self.framer.end_framing()
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     690         else:
#     691             save(func)
# --> 692             save(args)
#     693             write(REDUCE)
#     694
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_tuple(self, obj)
#     884         if n <= 3 and self.proto >= 2:
#     885             for element in obj:
# --> 886                 save(element)
#     887             # Subtle.  Same as in the big comment below.
#     888             if id(obj) in memo:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     601
#     602         # Save the reduce() output and finally memoize the object
# --> 603         self.save_reduce(obj=obj, *rv)
#     604
#     605     def persistent_id(self, obj):
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, state_setter, obj)
#     715         if state is not None:
#     716             if state_setter is None:
# --> 717                 save(state)
#     718                 write(BUILD)
#     719             else:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     558             f = self.dispatch.get(t)
#     559             if f is not None:
# --> 560                 f(self, obj)  # Call unbound method with explicit self
#     561                 return
#     562
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save_dict(self, obj)
#     969
#     970         self.memoize(obj)
# --> 971         self._batch_setitems(obj.items())
#     972
#     973     dispatch[dict] = save_dict
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in _batch_setitems(self, items)
#     995                 for k, v in tmp:
#     996                     save(k)
# --> 997                     save(v)
#     998                 write(SETITEMS)
#     999             elif n:
#
# ~/.local/lib/python3.9/site-packages/joblib/numpy_pickle.py in save(self, obj)
#     282             return
#     283
# --> 284         return Pickler.save(self, obj)
#     285
#     286
#
# /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/pickle.py in save(self, obj, save_persistent_id)
#     576                 reduce = getattr(obj, "__reduce_ex__", None)
#     577                 if reduce is not None:
# --> 578                     rv = reduce(self.proto)
#     579                 else:
#     580                     reduce = getattr(obj, "__reduce__", None)
#
# TypeError: cannot pickle 'module' object

# %%
vsoed.nkld_rw_f
# Out:
# <function vsOED.vsoed.VSOED.__init__.<locals>.nkld_rw_f(*args, **kws)>

# %%
torch.tensor(())
# Out:
# tensor([])

# %%
{'a': 1}.update({'b': 5})

# %%
dict().update
